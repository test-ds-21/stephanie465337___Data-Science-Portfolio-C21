# %% [markdown]
# # Python Exercises - Numpy, Pandas & Plotting

# %% [markdown]
# ## Setup: import libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Problem 1

# %% [markdown]
# Create a pandas dataframe that contains the following columns:
#
# Column Name | Values
# --- | ---
# A | 500 random numbers drawn from a normal distribution with mean 15 and standard deviation 5
# B | 500 equally spaced numbers between 1 and 50 (inclusive)
# C | 500 random integers drawn between 10 and 30 (inclusive)

# %%
df = pd.DataFrame({
    'A': np.random.normal(15,5,500),
    'B': np.linspace(1,50,500),
    'C': np.random.randint(10,30,500)
})

df
# Out:
#              A          B   C
# 0    15.562551   1.000000  25
# 1    13.229413   1.098196  16
# 2    18.577987   1.196393  10
# 3    18.206748   1.294589  23
# 4    15.865983   1.392786  19
# ..         ...        ...  ..
# 495   9.990956  49.607214  22
# 496  13.228035  49.705411  17
# 497  18.663583  49.803607  19
# 498  20.871088  49.901804  12
# 499  18.430638  50.000000  16
#
# [500 rows x 3 columns]

# %% [markdown]
# ## Problem 2

# %% [markdown]
# Calculate the mean of column A.

# %%
mean_a = df['A'].mean()

# %% [markdown]
# ## Problem 3

# %% [markdown]
# Plot a histogram of column A. It should contain a vertical line at the mean. Make the figure size (10,5). Make sure to add axis labels and a legend for the mean.

# %%
n = int(500**(1/2))

plt.figure(figsize = (10,5))

plt.hist(df['A'], bins=n, edgecolor='black')

plt.axvline(mean_a, color='red', label='Mean')

plt.xlabel('Column A')
plt.xlabel('Frequency')
plt.legend()

plt.show()

# %% [markdown]
# ## Problem 4

# %% [markdown]
# Create a line plot of the first 100 values in column C. Make sure to add axis labels.

# %%
plt.plot(df['C'].iloc[:100])

plt.xlabel('Index')
plt.ylabel('Column C')

plt.show()

# %% [markdown]
# ## Problem 5

# %% [markdown]
# Create a new column, `D`, that contains 3 times the values in column `B` plus some random noise (`np.random.normal(0,10,500`).

# %%
df['D'] = 3 * df['B'] + np.random.normal(0,10,500)
df
# Out:
#              A          B   C           D
# 0    15.562551   1.000000  25   -0.265457
# 1    13.229413   1.098196  16    1.749723
# 2    18.577987   1.196393  10   -2.606755
# 3    18.206748   1.294589  23    0.520051
# 4    15.865983   1.392786  19   -9.055812
# ..         ...        ...  ..         ...
# 495   9.990956  49.607214  22  160.282117
# 496  13.228035  49.705411  17  152.716861
# 497  18.663583  49.803607  19  154.402768
# 498  20.871088  49.901804  12  145.083793
# 499  18.430638  50.000000  16  140.893013
#
# [500 rows x 4 columns]

# %% [markdown]
# ## Problem 6

# %% [markdown]
# Create a scatter plot with column `B` on the x-axis and column `D` on the y-axis.  Make sure to add axis labels.

# %%
plt.scatter(df['B'], df['D'])

plt.xlabel('Column B')
plt.ylabel('Column D')

plt.show()

# %% [markdown]
# ## **BONUS** (only if you have time)

# %% [markdown]
# Create a new column, `E`, that that contains 3 times the values in column `B` plus some random noise with a smaller standard deviation (`np.random.normal(0,3,500`).  Add the points you generated for column `E` to the scatterplot you created in #5. Use a different color and marker for these points and add a legend.

# %%
df['E'] = 3 * df['B'] + np.random.normal(0,3,500)
df
# Out:
#              A          B   C           D           E
# 0    15.562551   1.000000  25   -0.265457    2.641296
# 1    13.229413   1.098196  16    1.749723    3.564756
# 2    18.577987   1.196393  10   -2.606755    4.300752
# 3    18.206748   1.294589  23    0.520051    3.708919
# 4    15.865983   1.392786  19   -9.055812    2.602785
# ..         ...        ...  ..         ...         ...
# 495   9.990956  49.607214  22  160.282117  150.173662
# 496  13.228035  49.705411  17  152.716861  145.825929
# 497  18.663583  49.803607  19  154.402768  155.423399
# 498  20.871088  49.901804  12  145.083793  146.428187
# 499  18.430638  50.000000  16  140.893013  147.208331
#
# [500 rows x 5 columns]

# %%
plt.scatter(df['B'], df['D'], label = 'Column D')
plt.scatter(df['B'], df['E'], color = 'pink', label = 'Column E')

plt.xlabel('Column B')
plt.ylabel('Column D & E')
plt.title('BONUS')
plt.legend()

plt.show()
