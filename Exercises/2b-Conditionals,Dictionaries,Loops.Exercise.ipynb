# %% [markdown]
# # Python Exercises - Conditionals, Dictionaries, & Loops

# %% [markdown]
# 1. Create a dictionary to store information about a famous person. Store their first name, last name, age, and what they are famous for. You should have keys ‘first_name’, ‘last_name’, ‘age’, and ‘famous_for’. Print each piece of information stored in your dictionary. **BONUS**: Use a for loop to print the information.

# %%
users = {
  'Samantha':{
    'first_name':'Samantha',
    'last_name':'Holder',
    'age':34,
    'famous_for':'Changing clothes three times a day.',
    },
  'Ruby':{
      'first_name':'Ruby',
      'last_name':'Gomez',
      'age':32,
      'famous_for':'Being a paramedic.',
      },
  'Jane':{
      'first_name':'Jane',
      'last_name':'Parra',
      'age':35,
      'famous_for':'Keeping her plants alive.',
      },
  'Vany':{
      'first_name':'Vanessa',
      'last_name':'Orozco',
      'age':32,
      'famous_for':'Moving away.',
      },
}
users
# Out:
# {'Samantha': {'first_name': 'Samantha',
#   'last_name': 'Holder',
#   'age': 34,
#   'famous_for': 'Changing clothes three times a day.'},
#  'Ruby': {'first_name': 'Ruby',
#   'last_name': 'Gomez',
#   'age': 32,
#   'famous_for': 'Being a paramedic.'},
#  'Jane': {'first_name': 'Jane',
#   'last_name': 'Parra',
#   'age': 35,
#   'famous_for': 'Keeping her plants alive.'},
#  'Vany': {'first_name': 'Vanessa',
#   'last_name': 'Orozco',
#   'age': 32,
#   'famous_for': 'Moving away.'}}

# %%
#used users? and Gemini
for name, details in users.items():
  print(f'Name:{details['first_name']} {details['last_name']}')
  print(f'Age: {details['age']}')
  print(f'Famous for: {details['famous_for']}')
# Out:
# Name:Samantha Holder
# Age: 34
# Famous for: Changing clothes three times a day.
# Name:Ruby Gomez
# Age: 32
# Famous for: Being a paramedic.
# Name:Jane Parra
# Age: 35
# Famous for: Keeping her plants alive.
# Name:Vanessa Orozco
# Age: 32
# Famous for: Moving away.

# %% [markdown]
# 2. Add the famous person's place of birth to the dictionary you created in #1.

# %%
users['Amanda'] = {
    'first_name':'Amanda',
    'last_name':'Alano',
    'age':38,
    'famous_for':'Being Late.',
    }
for name, details in users.items():
  print(f'Name:{details['first_name']} {details['last_name']}')
  print(f'Age: {details['age']}')
  print(f'Famous for: {details['famous_for']}')
# Out:
# Name:Samantha Holder
# Age: 34
# Famous for: Changing clothes three times a day.
# Name:Ruby Gomez
# Age: 32
# Famous for: Being a paramedic.
# Name:Jane Parra
# Age: 35
# Famous for: Keeping her plants alive.
# Name:Vanessa Orozco
# Age: 32
# Famous for: Moving away.
# Name:Amanda Alano
# Age: 38
# Famous for: Being Late.

# %% [markdown]
# 3. A number raised to the second power is called a square (e.g., $ 3^2 $ is the square of 3). Use a for loop to print out the square of each integer from 1 to 15.

# %%
for number in range(1,15):
  print(number**2)
# Out:
# 1
# 4
# 9
# 16
# 25
# 36
# 49
# 64
# 81
# 100
# 121
# 144
# 169
# 196

# %% [markdown]
# 4. Write a python program that will take a word and print a message stating whether that word starts with a vowel or a consonant. Test it out with several words.
#
# Example input:
#
# ```
# popcorn
# ```
#
# Example output:
# ```
# This word starts with a consonant.
# ```

# %%
word = ('6black')
first_letter = word[0]

consonant = ('bcdfghjklmnpqrstvwxyzBCDFGHJKLMNPQRSTVWXYZ')
vowel = ('aeiouAEIOU')

if first_letter in consonant:
  print('This word starts with a consonant.')
elif first_letter in vowel:
  print('This word starts with a vowel.')
else:
  print('This is not a word.')
# Out:
# This is not a word.

# %% [markdown]
# 5. Write a python program that will loop through the following list:
# `pets = ['Muffin', 'Kiki', 'Moe', 'Daisy']`. If the length of the pet's name is less than 5 characters, print out the name.

# %%
pets = ['Muffin', 'Kiki', 'Moe', 'Daisy']

for pet in pets:
  if len(pet) < 5:
    print(pet)
# Out:
# Kiki
# Moe

# %% [markdown]
# ## **Bonus** (only if you have time)

# %% [markdown]
# 1. Create the following two lists of numbers:
#
# ```
# list_1 = [1,2,3,4,5,6,7,8]
# list_2 = [9,10,11,12,13,14]
# ```
#
# Write a program to create a new list such that the new list should contain odd numbers from the first list and even numbers from the second list.

# %%
list_1 = [1,2,3,4,5,6,7,8]

for number in list_1:
  if (number % 2 == 0):
    list_1.remove(number)
print(list_1)
# Out:
# [1, 3, 5, 7]

# %%
list_2 = [9,10,11,12,13,14]

for number in list_2:
  if (number % 2 != 0):
    list_2.remove(number)
print(list_2)
# Out:
# [10, 12, 14]

# %%
new_list = list_1 + list_2
new_list
# Out:
# [1, 3, 5, 7, 10, 12, 14]

# %% [markdown]
# 2. Write a program that will check to see if a user's password contains at least one of the following:

# %% [markdown]
# *   A number
# *   A letter
# *   A symbol ($, %, ! or ?)
#
# It should print out 'Good password' if it meets the above requirements and 'Bad password' otherwise.
#
# Example input: 'Hello5?'
#
# Example output: 'Good password'
#
# Hint: `import string` and then use `list(string.ascii_lowercase)` to get a list of all lowercase letters

# %%
import string #Toolbox

password = 'ABDC3&'

#Why do I have to include these?
#If int = False why cant I just use False?
#because of import string?
letter = False
number = False
symbol = False
#This causes the loop if its not a letter it moves on.
#When it = True it saves that count and moves on to the next character.

for character in password:
#Cannot assign to function call here. Maybe you meant '==' instead of '='?
  if character.isdigit():
    letter = True
  if character.isalpha():
    number = True
  if character in string.punctuation:
    symbol = True

if letter and number and symbol:
#Cannot combine 'and(letter, number, symbol)'.
#Must separate with 'and'
  print('Good password')
else:
    print('Bad password')

#Using .isalnum() did not work.
# Out:
# Good password

# %%
import string

password = 'ABDC3&'
password = password.upper()

alnum = False

for character in password:
  if character.isalnum():
    letter = True

if alnum:
  print('Good password')
else:
    print('Bad password')
#Does not work
# Out:
# Bad password
