# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/2f_Intro%20to%20Stats.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Example from stats lecture

# %%
samples = [85, 90, 92, 73, 95, 60, 89, 78, 99, 90]
samples
# Out:
# [85, 90, 92, 73, 95, 60, 89, 78, 99, 90]

# %% [markdown]
# Sum ( add up )

# %%
summation = 0
for value in samples:
  summation += value

summation
# Out:
# 851

# %%
sum(samples)
# Out:
# 851

# %% [markdown]
# Count ( len of data set )

# %%
len(samples)
# Out:
# 10

# %%
count = len
count(samples)
# Out:
# 10

# %% [markdown]
# Mean ( average )

# %%
summation/len(samples)
# Out:
# 85.1

# %%
summation/count(samples)
# Out:
# 85.1

# %% [markdown]
# Median ( mid-point )

# %%
sorted(samples)
# Out:
# [60, 73, 78, 85, 89, 90, 90, 92, 95, 99]

# %%
sum(sorted(samples)[4:6])/2
# Out:
# 89.5

# %% [markdown]
# Range

# %%
{
"min": sorted(samples)[0],
"max": sorted(samples)[-1]
}
# Out:
# {'min': 60, 'max': 99}

# %%
sorted(samples)[3:8]
# Out:
# [85, 89, 90, 90, 92]

# %%
min(samples), max(samples)
# Out:
# (60, 99)

# %%
max(samples) - min(samples)
# Out:
# 39

# %%
import numpy as np
#numpy said as num - pie

# %%
np.median(samples)
# Out:
# np.float64(89.5)
