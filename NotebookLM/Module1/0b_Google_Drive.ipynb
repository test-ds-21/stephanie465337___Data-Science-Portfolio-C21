# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module1/0b_Google_Drive.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Getting set up in Google Drive

# %% [markdown]
# `NN` is your cohort number.
#
# - Navigate to `My Drive`
# - Create a folder called `ddds-cohort-NN.read-only` in your `My Drive`.
# - Navigate to `Shared with Me`
# - Add the `Admin` shortcut to the `ddds-cohort-NN.read-only` folder. ( Right click on `Admin` > Organize > Add shortcut )
# - Add the `Modules` shortcut to the `ddds-cohort-NN.read-only` folder. ( Right click on `Modules` > Organize > Add shortcut )

# %% [markdown]
# The following code will verify that everything works.

# %%
# %%capture
# %%bash
apt-get update
apt-get install -y tree jq vim

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !ls -la /content/
# Out:
# total 20
# drwxr-xr-x 1 root root 4096 Jun  1 15:58 .
# drwxr-xr-x 1 root root 4096 Jun  1 15:53 ..
# drwxr-xr-x 4 root root 4096 May 26 13:25 .config
# drwx------ 5 root root 4096 Jun  1 15:58 drive
# drwxr-xr-x 1 root root 4096 May 26 13:25 sample_data

# %%
# !ls -la /content/drive/MyDrive/ddds-cohort-21.read-only/*/
# Out:
# /content/drive/MyDrive/ddds-cohort-21.read-only/Admin/:
# total 12
# drwx------ 2 root root 4096 Jun  1 06:53 Class.Policies
# drwx------ 2 root root 4096 Jun  1 06:08 Grading.Rubrics
# drwx------ 2 root root 4096 Jan 16  2025 Resources
#
# /content/drive/MyDrive/ddds-cohort-21.read-only/Modules/:
# total 4
# drwx------ 2 root root 4096 Jun  1 06:29 Module_1_Intro_to_DS_and_Naive_Bayes

# %%
# !ls -la /content/drive/MyDrive/ddds-cohort-21/*/
# Out:
# ls: cannot access '/content/drive/MyDrive/ddds-cohort-21/*/': No such file or directory

# %% [markdown]
# Create and share the `ddds-cohort-NN` with your private Gmail account.
#
# - Navigate to `My Drive`
# - Create a folder called `ddds-cohort-NN` in your `My Drive`.
# - Right click on `ddds-cohort-NN` > Share > Share
# - Enter your private Gmail account
# - Select Editor
# - Uncheck notify
# - Click Share

# %% [markdown]
# Copy over folder structure.

# %%
# %%bash
#
# rsync -vaR -f"+ */" -f"- *" --chmod=ugo=rwX \
#   /content/drive/MyDrive/ddds-cohort-21.read-only/./*/ \
#   /content/drive/MyDrive/ddds-cohort-21/
# Out:
# sending incremental file list
# Admin/
# Admin/Class.Policies/
# Admin/Grading.Rubrics/
# Admin/Resources/
# Modules/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Exercises/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Exercises/Drills/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Lectures/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Projects/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Projects/Instructions/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Projects/Instructions/Example/
# Modules/Module_1_Intro_to_DS_and_Naive_Bayes/Projects/Instructions/Project.1-Transactions/
#
# sent 463 bytes  received 64 bytes  351.33 bytes/sec
# total size is 0  speedup is 0.00
