# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module1/6a_More_Indexing_in_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # More Indexing in Pandas

# %%
import pandas as pd
import numpy as np

# %%
# Create a data frame
my_dict = {
    'Name': ['Mary', 'Joe', 'Roger', 'Sarah', 'Mike', 'Phil'],
    'Age': [20, 45, 32, 58, 39, 42],
    'City': ['Albuquerque', 'Rio Rancho', 'Santa Fe', 'Taos', 'Albuquerque', 'Placitas'],
'Occupation': ['student', 'doctor', 'data scientist', 'general contractor', 'student', 'manager']
}
people_df = pd.DataFrame(my_dict)
people_df
# Out:
#     Name  Age         City          Occupation
# 0   Mary   20  Albuquerque             student
# 1    Joe   45   Rio Rancho              doctor
# 2  Roger   32     Santa Fe      data scientist
# 3  Sarah   58         Taos  general contractor
# 4   Mike   39  Albuquerque             student
# 5   Phil   42     Placitas             manager

# %% [markdown]
# ## Review of column and row indexing

# %% [markdown]
# ### Using column names

# %%
#Column indexing
people_df['Name']
#This is a DataSeries
# Out:
# 0     Mary
# 1      Joe
# 2    Roger
# 3    Sarah
# 4     Mike
# 5     Phil
# Name: Name, dtype: object

# %%
#Column indexing
people_df[['Name']]
#This is a DataFrame recognized by the table icon in the top right corner
# Out:
#     Name
# 0   Mary
# 1    Joe
# 2  Roger
# 3  Sarah
# 4   Mike
# 5   Phil

# %%
list_of_columns = ['Name']
people_df[ list_of_columns ]
# Out:
#     Name
# 0   Mary
# 1    Joe
# 2  Roger
# 3  Sarah
# 4   Mike
# 5   Phil

# %%
#people_df['Name', 'Age']
people_df[['Name', 'Age', 'Name']]
# Out:
#     Name  Age   Name
# 0   Mary   20   Mary
# 1    Joe   45    Joe
# 2  Roger   32  Roger
# 3  Sarah   58  Sarah
# 4   Mike   39   Mike
# 5   Phil   42   Phil

# %%
#Multiple column indexing
people_df[['Name', 'Age']]
# Out:
#     Name  Age
# 0   Mary   20
# 1    Joe   45
# 2  Roger   32
# 3  Sarah   58
# 4   Mike   39
# 5   Phil   42

# %%
#Multiple column indexing
people_df[['Name', 'Age', 'Name']]
# Out:
#     Name  Age   Name
# 0   Mary   20   Mary
# 1    Joe   45    Joe
# 2  Roger   32  Roger
# 3  Sarah   58  Sarah
# 4   Mike   39   Mike
# 5   Phil   42   Phil

# %%
name_index = people_df.columns[::-2]
name_index
# Out:
# Index(['Occupation', 'Age'], dtype='object')

# %%
people_df[name_index]
# Out:
#            Occupation  Age         City
# 0             student   20  Albuquerque
# 1              doctor   45   Rio Rancho
# 2      data scientist   32     Santa Fe
# 3  general contractor   58         Taos
# 4             student   39  Albuquerque
# 5             manager   42     Placitas

# %%
name_index = pd.Series(people_df.columns).sample(n=3)
name_index
# Out:
# 3    Occupation
# 0          Name
# 2          City
# dtype: object

# %%
people_df[name_index]
# Out:
#            Occupation   Name         City
# 0             student   Mary  Albuquerque
# 1              doctor    Joe   Rio Rancho
# 2      data scientist  Roger     Santa Fe
# 3  general contractor  Sarah         Taos
# 4             student   Mike  Albuquerque
# 5             manager   Phil     Placitas

# %% [markdown]
# ### Columns with iloc indices

# %% [markdown]
# iloc = interger locations

# %%
#Column indexing using .iloc - indexing
people_df.iloc[:,0]
# Out:
# 0     Mary
# 1      Joe
# 2    Roger
# 3    Sarah
# 4     Mike
# 5     Phil
# Name: Name, dtype: object

# %%
#Column indexing using .iloc - slicing
people_df.iloc[:,0::2]
# Out:
#     Name         City
# 0   Mary  Albuquerque
# 1    Joe   Rio Rancho
# 2  Roger     Santa Fe
# 3  Sarah         Taos
# 4   Mike  Albuquerque
# 5   Phil     Placitas

# %%
for i in list(enumerate(people_df.columns)):
  print(i)
# Out:
# (0, 'Name')
# (1, 'Age')
# (2, 'City')
# (3, 'Occupation')

# %%
# Column indexing using .iloc - list
people_df.iloc[ : , [1,0,3,2,3]]
# Out:
#    Age   Name          Occupation         City          Occupation
# 0   20   Mary             student  Albuquerque             student
# 1   45    Joe              doctor   Rio Rancho              doctor
# 2   32  Roger      data scientist     Santa Fe      data scientist
# 3   58  Sarah  general contractor         Taos  general contractor
# 4   39   Mike             student  Albuquerque             student
# 5   42   Phil             manager     Placitas             manager

# %% [markdown]
# ### Rows with indices

# %%
#Reassign index
people_df.index =  list("abcdef")
people_df
# Out:
#     Name  Age         City          Occupation
# a   Mary   20  Albuquerque             student
# b    Joe   45   Rio Rancho              doctor
# c  Roger   32     Santa Fe      data scientist
# d  Sarah   58         Taos  general contractor
# e   Mike   39  Albuquerque             student
# f   Phil   42     Placitas             manager

# %%
#Row indexing using .loc
people_df.loc["b"]
# Out:
# Name                 Joe
# Age                   45
# City          Rio Rancho
# Occupation        doctor
# Name: b, dtype: object

# %%
#Row indexing using .iloc
people_df.iloc[1]
# Out:
# Name                 Joe
# Age                   45
# City          Rio Rancho
# Occupation        doctor
# Name: b, dtype: object

# %%
#Multiple rows - slicing
people_df.loc["a":"c"]
# Out:
#     Name  Age         City      Occupation
# a   Mary   20  Albuquerque         student
# b    Joe   45   Rio Rancho          doctor
# c  Roger   32     Santa Fe  data scientist

# %%
people_df.iloc[0:2]
# Out:
#    Name  Age         City Occupation
# a  Mary   20  Albuquerque    student
# b   Joe   45   Rio Rancho     doctor

# %%
#Selecting rows in any order - list
people_df.loc[["a","d","d","c","b"]]
# Out:
#     Name  Age         City          Occupation
# a   Mary   20  Albuquerque             student
# d  Sarah   58         Taos  general contractor
# d  Sarah   58         Taos  general contractor
# c  Roger   32     Santa Fe      data scientist
# b    Joe   45   Rio Rancho              doctor

# %%
idx = [0,3,3,2,1]
idx
# Out:
# [0, 3, 3, 2, 1]

# %%
people_df.iloc[idx, :]
# Out:
#     Name  Age         City          Occupation
# a   Mary   20  Albuquerque             student
# d  Sarah   58         Taos  general contractor
# d  Sarah   58         Taos  general contractor
# c  Roger   32     Santa Fe      data scientist
# b    Joe   45   Rio Rancho              doctor

# %% [markdown]
# ### Indexing for a single entry

# %%
#Row and column indexing
people_df['Name'].iloc[0]
# Out:
# 'Mary'

# %%
#Another way
people_df['Name'].loc["a"]
# Out:
# 'Mary'

# %%
#Another way
people_df.loc["a"]['Name']
# Out:
# 'Mary'

# %%
#Another way
people_df.loc["a"].loc['Name']
# Out:
# 'Mary'

# %%
#Another way
people_df.loc["a",'Name']
# Out:
# 'Mary'

# %%
#Another way
people_df.iloc[0,0]
# Out:
# 'Mary'

# %%
#Another way
people_df.iloc[0].iloc[0]
# Out:
# 'Mary'

# %%
#Another way
people_df.iloc[0].loc["Name"]
# Out:
# 'Mary'

# %% [markdown]
# ## Attribute Access

# %% [markdown]
# > WARNING: Do Not Use This
#
# You can access columns in a dataframe as attributes. Note: there are a few cases when the attribute will not work, such as if your column is named a number (e.g., 1) or if it is named after an existing method (e.g., min).

# %%
people_df
# Out:
#     Name  Age         City          Occupation
# a   Mary   20  Albuquerque             student
# b    Joe   45   Rio Rancho              doctor
# c  Roger   32     Santa Fe      data scientist
# d  Sarah   58         Taos  general contractor
# e   Mike   39  Albuquerque             student
# f   Phil   42     Placitas             manager

# %%
people_df.Name
# Out:
# a     Mary
# b      Joe
# c    Roger
# d    Sarah
# e     Mike
# f     Phil
# Name: Name, dtype: object

# %%
people_df.Name.loc["a"]
# Out:
# 'Mary'

# %%
people_df["shape"] = 10
people_df
# Out:
#     Name  Age         City          Occupation  shape
# a   Mary   20  Albuquerque             student     10
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10
# e   Mike   39  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10

# %%
people_df.shape
# Out:
# (6, 5)

# %%
people_df["shape"]
# Out:
# a    10
# b    10
# c    10
# d    10
# e    10
# f    10
# Name: shape, dtype: int64

# %% [markdown]
# ## Boolean Indexing

# %%
filter = (people_df['Age'] > 40) #Create a filter
filter
# Out:
# a    False
# b     True
# c    False
# d     True
# e    False
# f     True
# Name: Age, dtype: bool

# %%
people_df[filter] #Use that filter to index
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# d  Sarah   58        Taos  general contractor     10
# f   Phil   42    Placitas             manager     10

# %%
#Another example - people from Albuquerque
filter = (people_df['City'] == 'Albuquerque')
filter
# Out:
# a     True
# b    False
# c    False
# d    False
# e     True
# f    False
# Name: City, dtype: bool

# %%
people_df[filter] #Use that filter to index
# Out:
#    Name  Age         City Occupation  shape
# a  Mary   20  Albuquerque    student     10
# e  Mike   39  Albuquerque    student     10

# %%
#A third example! People from albuquerque or people who are doctors
filter1 = (people_df['City'] == 'Albuquerque')
filter1
# Out:
# a     True
# b    False
# c    False
# d    False
# e     True
# f    False
# Name: City, dtype: bool

# %%
filter2 = (people_df['Occupation'] == 'doctor')
filter2
# Out:
# a    False
# b     True
# c    False
# d    False
# e    False
# f    False
# Name: Occupation, dtype: bool

# %%
filter = filter1 | filter2
filter
# Out:
# a     True
# b     True
# c    False
# d    False
# e     True
# f    False
# dtype: bool

# %%
#Verify
pd.concat([filter1, filter2, filter, people_df], axis='columns')
# Out:
#     City Occupation      0   Name  Age         City          Occupation  shape
# a   True      False   True   Mary   20  Albuquerque             student     10
# b  False       True   True    Joe   45   Rio Rancho              doctor     10
# c  False      False  False  Roger   32     Santa Fe      data scientist     10
# d  False      False  False  Sarah   58         Taos  general contractor     10
# e   True      False   True   Mike   39  Albuquerque             student     10
# f  False      False  False   Phil   42     Placitas             manager     10

# %%
people_df[filter] #Use that filter to index
# Out:
#    Name  Age         City Occupation  shape
# a  Mary   20  Albuquerque    student     10
# b   Joe   45   Rio Rancho     doctor     10
# e  Mike   39  Albuquerque    student     10

# %%
#Negating
filter = (people_df['Name'] == 'Mary')
filter
# Out:
# a     True
# b    False
# c    False
# d    False
# e    False
# f    False
# Name: Name, dtype: bool

# %%
#Verify
pd.concat([filter, ~filter, people_df], axis='columns')
# Out:
#     Name   Name   Name  Age         City          Occupation  shape
# a   True  False   Mary   20  Albuquerque             student     10
# b  False   True    Joe   45   Rio Rancho              doctor     10
# c  False   True  Roger   32     Santa Fe      data scientist     10
# d  False   True  Sarah   58         Taos  general contractor     10
# e  False   True   Mike   39  Albuquerque             student     10
# f  False   True   Phil   42     Placitas             manager     10

# %%
people_df[~filter] #Use that filter to index
# Out:
#     Name  Age         City          Occupation  shape
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10
# e   Mike   39  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10

# %%
people_df[people_df['Name'] != 'Mary']
# Out:
#     Name  Age         City          Occupation  shape
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10
# e   Mike   39  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10

# %% [markdown]
# ## Indexing w/ Isin

# %%
people_df['City']
# Out:
# a    Albuquerque
# b     Rio Rancho
# c       Santa Fe
# d           Taos
# e    Albuquerque
# f       Placitas
# Name: City, dtype: object

# %%
filter = (people_df['City'].isin(['Rio Rancho', 'Santa Fe', 'Taos'])) #Create a filter
filter
# Out:
# a    False
# b     True
# c     True
# d     True
# e    False
# f    False
# Name: City, dtype: bool

# %%
#Verify
pd.concat([filter, people_df], axis='columns')
# Out:
#     City   Name  Age         City          Occupation  shape
# a  False   Mary   20  Albuquerque             student     10
# b   True    Joe   45   Rio Rancho              doctor     10
# c   True  Roger   32     Santa Fe      data scientist     10
# d   True  Sarah   58         Taos  general contractor     10
# e  False   Mike   39  Albuquerque             student     10
# f  False   Phil   42     Placitas             manager     10

# %%
people_df[filter] #Use that filter to index
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# c  Roger   32    Santa Fe      data scientist     10
# d  Sarah   58        Taos  general contractor     10

# %% [markdown]
# ## Numpy Where
# The numpy where method can be useful to find rows that correspond to a particular conditional statement.

# %%
import numpy as np

# %%
filter = (people_df['City'] == 'Albuquerque')
filter
# Out:
# a     True
# b    False
# c    False
# d    False
# e     True
# f    False
# Name: City, dtype: bool

# %%
where_index = np.where(filter)
where_index, where_index[0]
# Out:
# ((array([0, 4]),), array([0, 4]))

# %%
where_index[0][1]
# Out:
# np.int64(4)

# %%
people_df
# Out:
#     Name  Age         City          Occupation  shape
# a   Mary   20  Albuquerque             student     10
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10
# e   Mike   39  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10

# %%
people_df.iloc[where_index[0]]
# Out:
#    Name  Age         City Occupation  shape
# a  Mary   20  Albuquerque    student     10
# e  Mike   39  Albuquerque    student     10

# %%
people_df.drop(people_df.index[where_index[0]])
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# c  Roger   32    Santa Fe      data scientist     10
# d  Sarah   58        Taos  general contractor     10
# f   Phil   42    Placitas             manager     10

# %%
people_df_no_abq = people_df.drop(people_df.index[where_index[0]])
people_df_no_abq
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# c  Roger   32    Santa Fe      data scientist     10
# d  Sarah   58        Taos  general contractor     10
# f   Phil   42    Placitas             manager     10

# %%
where_index[0][0]
# Out:
# np.int64(0)

# %%
people_df
# Out:
#     Name  Age         City          Occupation  shape
# a   Mary   20  Albuquerque             student     10
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10
# e   Mike   39  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10

# %%
people_df.iloc[where_index[0][0]]
# Out:
# Name                 Mary
# Age                    20
# City          Albuquerque
# Occupation        student
# shape                  10
# Name: a, dtype: object

# %%
people_df_no_abq
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# c  Roger   32    Santa Fe      data scientist     10
# d  Sarah   58        Taos  general contractor     10
# f   Phil   42    Placitas             manager     10

# %%
people_df_no_abq.iloc[where_index[0][0]]
# Out:
# Name                 Joe
# Age                   45
# City          Rio Rancho
# Occupation        doctor
# shape                 10
# Name: b, dtype: object

# %%
people_df_no_abq.reset_index()
# Out:
#   index   Name  Age        City          Occupation  shape
# 0     b    Joe   45  Rio Rancho              doctor     10
# 1     c  Roger   32    Santa Fe      data scientist     10
# 2     d  Sarah   58        Taos  general contractor     10
# 3     f   Phil   42    Placitas             manager     10

# %%
people_df_no_abq
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# c  Roger   32    Santa Fe      data scientist     10
# d  Sarah   58        Taos  general contractor     10
# f   Phil   42    Placitas             manager     10

# %%
people_df_no_abq.reset_index(drop = True)
# Out:
#     Name  Age        City          Occupation  shape
# 0    Joe   45  Rio Rancho              doctor     10
# 1  Roger   32    Santa Fe      data scientist     10
# 2  Sarah   58        Taos  general contractor     10
# 3   Phil   42    Placitas             manager     10

# %%
people_df_no_abq
# Out:
#     Name  Age        City          Occupation  shape
# b    Joe   45  Rio Rancho              doctor     10
# c  Roger   32    Santa Fe      data scientist     10
# d  Sarah   58        Taos  general contractor     10
# f   Phil   42    Placitas             manager     10

# %%
people_df_no_abq.reset_index(drop = True, inplace = True)
people_df_no_abq
# Out:
#     Name  Age        City          Occupation  shape
# 0    Joe   45  Rio Rancho              doctor     10
# 1  Roger   32    Santa Fe      data scientist     10
# 2  Sarah   58        Taos  general contractor     10
# 3   Phil   42    Placitas             manager     10

# %% [markdown]
# ## Random Sampling in Pandas

# %%
people_df
# Out:
#     Name  Age         City          Occupation  shape
# a   Mary   20  Albuquerque             student     10
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10
# e   Mike   39  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10

# %%
#Take a random sample of size 3
people_df.sample(n = 3)
# Out:
#    Name  Age         City Occupation  shape
# e  Mike   39  Albuquerque    student     10
# a  Mary   20  Albuquerque    student     10
# f  Phil   42     Placitas    manager     10

# %%
#Take a random proportion
people_df.sample(frac = 1/3)
# Out:
#     Name  Age         City          Occupation  shape
# e   Mike   39  Albuquerque             student     10
# d  Sarah   58         Taos  general contractor     10

# %%
people_df.groupby('City').sample(n = 1)
# Out:
#     Name  Age         City          Occupation  shape
# a   Mary   20  Albuquerque             student     10
# f   Phil   42     Placitas             manager     10
# b    Joe   45   Rio Rancho              doctor     10
# c  Roger   32     Santa Fe      data scientist     10
# d  Sarah   58         Taos  general contractor     10

# %%
#Take a randoom sample but set the seed for reproducibility
people_df.sample(n = 3, random_state = 42)
# Out:
#    Name  Age         City Occupation  shape
# a  Mary   20  Albuquerque    student     10
# b   Joe   45   Rio Rancho     doctor     10
# f  Phil   42     Placitas    manager     10

# %%
people_df.sample(n=2, axis="columns")
# Out:
#           City  Age
# a  Albuquerque   20
# b   Rio Rancho   45
# c     Santa Fe   32
# d         Taos   58
# e  Albuquerque   39
# f     Placitas   42

# %%
people_df.sample(n=2, axis="columns").sample(n=2)
# Out:
#    Age Occupation
# b   45     doctor
# f   42    manager
