# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module%204/4b_Docker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Docker
#
# See [Gentle Intro to Docker]( https://rwcitek.github.io/docker/slides/DockerGentleIntro/#/1 )

# %% [markdown]
# ## Build

# %% [markdown]
# 1. create a [personal access token ( PAT )](https://app.docker.com/accounts/rwcitek/settings/personal-access-tokens) on Docker Hub
# 1. Start CodeSpaces from [this repo]( https://github.com/rwcitek/bash.scripting.codespaces/tree/jupyter )
# 1. Login to Docker Hub using your PAT and [these instructions]( https://github.com/rwcitek/bash.scripting.codespaces/blob/jupyter/docker-intro/docker.1-setup.ipynb )
# 1. Build the image using [these instructions]( https://github.com/rwcitek/bash.scripting.codespaces/blob/jupyter/docker-intro/docker.2-intro.ipynb )

# %% [markdown]
# ## Your own webserver

# %% [markdown]
# 1. Start CodeSpaces from [this repo]( https://github.com/rwcitek/bash.scripting.codespaces )
# 1. Start Apache using this command
# ```bash
# docker container run -d --name apache -p 8080:80 ubuntu/apache2
# ```
# 1. View the webserver by clicking on this URL: http://localhost:8080
#
# 1. Create a web page

# %% [markdown]
# ```bash
# cat <<'eof' > hw.html
# <!DOCTYPE html>
# <html>
#   <head>
#     <title>This is a title</title>
#   </head>
#   <body>
#     <div>
#         <p>Hello world!</p>
#     </div>
#   </body>
# </html>
# eof
# ```
# 1. Copy html page into docker container
# ```bash
# docker cp hw.html apache:/var/www/html/
# ```
#
# 1. View new webpage
# - http://localhost:8080/hw.html
#
# 1. View apache logs
# ```bash
# docker container logs apache
# ```
