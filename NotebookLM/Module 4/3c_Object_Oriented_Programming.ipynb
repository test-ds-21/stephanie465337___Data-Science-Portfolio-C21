# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/3c_Object_Oriented_Programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Basics of Object Oriented Programming

# %% [markdown]
# ## Why we care

# %% [markdown]
# Everything in python is an object:
# - strings
# - ints
# - lists
# - DataFrames
# - Numpy Arrays
#
# We want to cover just enough OOP that you understand certain things about Python syntax.

# %% [markdown]
# ## Scope

# %% [markdown]
# ## Manging variables

# %% [markdown]
# ### global, local, nonlocal

# %% [markdown]
# Local scope

# %%
x = 5

# %%
x
# Out:
# 5

# %%
def foo():
  # print(x)
  x = 10
  print(x)

# %%
foo()
# Out:
# 10

# %%
x
# Out:
# 5

# %%
def bar(x):
  print(x)
  x = 10
  print(x)

# %%
x = 5
bar(x)
# Out:
# 5
# 10

# %%
x
# Out:
# 5

# %% [markdown]
# Using `global`

# %%
def foo():
  global x
  print(x)
  x = 10
  print(x)

# %%
x = 5
foo()
# Out:
# 5
# 10

# %%
x
# Out:
# 10

# %% [markdown]
# Enclosed scope, using `nonlocal`

# %%
def foo():
  '''this is foo'''
  x = 15
  print(x)

  def bar(n=20):
    '''this is bar'''
    nonlocal x
    print(x)
    x = n
    print(x)

  return bar

# %%
x = 5
x
# Out:
# 5

# %%
type(foo())
# Out:
# 15
# function

# %%
yow = foo()
# Out:
# 15

# %%
yow?

# %%
type(yow)
# Out:
# function

# %%
yow(8)
# Out:
# 15
# 8

# %%
x
# Out:
# 5

# %%
yow()
# Out:
# 8
# 20

# %%
x
# Out:
# 5

# %%
asdf = foo
print(asdf)

asdf = foo()
print(asdf)
# Out:
# <function foo at 0x7fb5d0f76de0>
# 15
# <function foo.<locals>.bar at 0x7fb5d0f844a0>

# %%
asdf?

# %%
x = 5
asdf = foo()
print("===")
asdf()
# Out:
# 15
# ===
# 15
# 20

# %%
foo()(8)
# Out:
# 15
# 15
# 8

# %%
yow()
# Out:
# 20
# 20

# %%
x
# Out:
# 5

# %% [markdown]
# ### Recursive function

# %% [markdown]
# A function that calls itself.  It has two parts:
# 1. the base condition and result
# 1. the recursive ( or self-referential ) part

# %% [markdown]
# Factorial =
#
# n! = n * (n-1) * (n-2) * ... * 1
#
# = n * (n-1)!
#
# = n * (n-1) * (n-2)!

# %%
def factorial(x):
  if x <= 1:
    print(f"== {x} == DONE!!!!")
    return 1
  else:
    print(f"== {x}")
    return x * factorial(x-1)

# %% [markdown]
# - factorial(1) -> 1
# - factorial(2) -> 2 * factorial(1) -> 2 * 1 -> 2
# - factorial(3) -> 3 * factorial(2) -> 3 * 2 * factorial(1) -> 3 * 2 * 1 -> 6

# %%
factorial(3)
# Out:
# == 3
# == 2
# == 1 == DONE!!!!
# 6

# %% [markdown]
# ### Using a closure

# %% [markdown]
# A closure is when a function "encloses" or contains the definition to another function.  Usually, the enclosing ( or outer ) function contains variables that are used to keep state, i.e. are persistent across calls to the enclosed ( or inner ) function.  The outer function returns a reference to the inner function.

# %% [markdown]
# Fibonacci =  0, 1, 1, 2, 3, 5, 8, 13, ...

# %%
def make_fibonacci():
  #Enclosed variable (closure)
  memo = {}

  #Enclosed function (closure)
  def fibonacci(n):
    if n in memo:
      return memo[n]

    if   n <= 1:
      result = 0
    elif n == 2:
      result = 1
    else:
      result = fibonacci(n - 1) + fibonacci(n - 2)

    memo[n] = result
    return result
  def view():
    return memo

  return fibonacci, memo

# %%
fibc, memo = make_fibonacci()

# %%
type(fibc)
# Out:
# function

# %%
fibc(3)
# Out:
# 1

# %%
memo
# Out:
# {2: 1, 1: 0, 3: 1}

# %%
memo.clear()

# %%
memo
# Out:
# {}

# %% [markdown]
# ## Classes and Objects/Instances
#
# **Classes** are like a blueprint.  They define a type of object and the methods that can be used on that object.
#
# **Objects/Instances** are specific instances of a class.  For example, an actual house.  You could create as many houses as you wanted from one blueprint.
#
# For example, DataFrame is a class in Pandas.  But when you create a DataFrame, that specific DataFrame is an object.
#
# Classes allow us to create functionality that will be available to all objects that we make of that class.
#
# For example,  you are able to use head() with any DataFrame to get the first few entries.

# %% [markdown]
# ##  Methods and Attributes
# **Methods** are like functions, but they run on an object.
# - For example, when you call head() on a dataframe it's df.head() not head(df).
#
#
# **Attributes** are values for variables associated with an object.

# %%
import pandas as pd

# %%
df = pd.DataFrame([[0,2],[5,6],[9,0]])
df
# Out:
#    0  1
# 0  0  2
# 1  5  6
# 2  9  0

# %%
# head() is a method we can call on our dataframe object
df.head(2)
# Out:
#    0  1
# 0  0  2
# 1  5  6

# %%
# shape is an attribute  - notice how it has no ()
df.shape
# Out:
# (3, 2)

# %%
print(df)
# Out:
#    0  1
# 0  0  2
# 1  5  6
# 2  9  0

# %%
print(df.__class__)
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(df.__class__.__name__)
# Out:
# DataFrame

# %% [markdown]
# ##  Making your own class

# %% [markdown]
# Animal **Class**
#
# Attributes:
# - Sound - What sound does it make?
# - Name
# - Color
# - Species
# - \# of legs
# - eye color
# ....
#
# Methods (What can an animal do?  Or what can I do to it?):
# - Talk
# - Walk
# - ...
#
# **Object - Specific instance of the class**
#
# Cat -
#
# Sound - mreeow
#
# Name - Head Cat
#
# Color - White & grey
#
# **Make an animal class & an object of type Animal**

# %%
#Class names - first letter of words are capitalized - no spaces - i.e. pd.DataFrame
class Animal:
  """This is the Animal Class"""

  #This is the constructor.  It is called when we make a new Animal.
  #For example, something like
  # head_cat = Animal('Head Cat', 'cat', 'white and grey', 'meow') goes to
  # head_cat = __init__('Head Cat', 'cat', 'white and grey', 'meow')
  def __init__(self, name, species, color, sound):
    #Here we set the attributes based on the input from the constructor
    self.name = name
    self.species = species
    self.color = color
    self.sound = sound
    self.steps = 0

  #This is a dunder method - it returns a string as a representation of the object.
  #Creating a string that will be returned when print is used on the Animal.
  #We'll make it something pretty and human-readable.
  def __repr__(self):
    return(f"{self.__class__.__name__}(name={self.name}, species={self.species}, color={self.color}, sound={self.sound})")

  #This is a method
  def talk(self):  # head_cat.talk()  ->  talk(head_cat)
    """Print the animal's sound"""
    print(self.sound)  # print(head_cat.sound)

  def walk(self, num_steps):
    self.steps = self.steps + num_steps
    return num_steps

# %%
our_dog = Animal(name = 'Zeus', species = 'dog', color = 'grey', sound = 'bark')
our_dog
# Out:
# Animal(name=Zeus, species=dog, color=grey, sound=bark)

# %%
print(our_dog)
# Out:
# Animal(name=Zeus, species=dog, color=grey, sound=bark)

# %%
our_dog.steps
# Out:
# 0

# %%
our_dog.talk()
# Out:
# bark

# %%
our_dog.walk(5)
# Out:
# 5

# %%
our_dog.steps
# Out:
# 5

# %%
#Animal?
help(Animal)
# Out:
# Help on class Animal in module __main__:
#
# class Animal(builtins.object)
#  |  Animal(name, species, color, sound)
#  |
#  |  This is the Animal Class
#  |
#  |  Methods defined here:
#  |
#  |  __init__(self, name, species, color, sound)
#  |      Initialize self.  See help(type(self)) for accurate signature.
#  |
#  |  __repr__(self)
#  |      Return repr(self).
#  |
#  |  talk(self)
#  |      Print the animal's sound
#  |
#  |  walk(self, num_steps)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
our_dog.__dict__
# Out:
# {'name': 'Zeus',
#  'species': 'dog',
#  'color': 'grey',
#  'sound': 'bark',
#  'steps': 5}

# %%
df = pd.DataFrame([[1, 2, 3], [4, 5, 6]])
df.__dict__
# Out:
# {'_is_copy': None,
#  '_mgr': BlockManager
#  Items: RangeIndex(start=0, stop=3, step=1)
#  Axis 1: RangeIndex(start=0, stop=2, step=1)
#  NumpyBlock: slice(0, 3, 1), 3 x 2, dtype: int64,
#  '_item_cache': {},
#  '_attrs': {},
#  '_flags': <Flags(allows_duplicate_labels=True)>}

# %%
#Head Cat is an Object of Type Animal.  Animal is the class.
head_cat = Animal('Head Cat', 'cat', 'white and grey', 'mrrrrr')
head_cat
# Out:
# Animal(name=Head Cat, species=cat, color=white and grey, sound=mrrrrr)

# %%
head_cat.talk()
# Out:
# mrrrrr

# %%
print(head_cat)

# %%
print(head_cat.species)
# Out:
# cat

# %%
head_cat.color
# Out:
# 'white and grey'

# %%
trip = Animal('Tripping Hazzard', 'cat', 'grey', 'purrr')
trip.talk()
print(f"Trip was a {trip.color} cat")
# Out:
# purrr
# Trip was a grey cat

# %%
print(trip)
# Out:
# Animal(name=Tripping Hazzard, species=cat, color=grey, sound=purrr)

# %%
parrot = Animal("Timothy", "parrot", "blue", "Polly want a cracker!")

# %%
print(parrot)
# Out:
# Animal(name=Timothy, species=parrot, color=blue, sound=Polly want a cracker!)

# %%
parrot.talk()
# Out:
# Polly want a cracker!

# %%
parrot.walk(10)
parrot.steps
# Out:
# 10

# %%
parrot.walk(5)
parrot.steps
# Out:
# 15

# %%
print(parrot)
print(parrot.color)
# Out:
# Animal(name=Timothy, species=parrot, color=blue, sound=Polly want a cracker!)
# blue

# %% [markdown]
# ##  Making a derived class

# %% [markdown]
# ### Creating a [Queue]( https://en.wikipedia.org/wiki/Queue_(abstract_data_type) )

# %% [markdown]
# "A queue has two ends, the top ( or back/tail/rear ), which is the only position at which the **push** ( or enqueue/enter/add ) operation may occur, and the bottom (or front/head), which is the only position at which the **pop** ( or dequeue/leave/remove ) operation may occur."

# %% [markdown]
# ![A queue]( https://media.geeksforgeeks.org/wp-content/cdn-uploads/20221213113312/Queue-Data-Structures.png )

# %% [markdown]
# Why not use a list?

# %%
#Create the list
my_list = [1, 2, 3]
my_list
# Out:
# [1, 2, 3]

# %%
#Show the size
my_list.size
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2701/1817100206.py in <cell line: 0>()
#       1 #Show the size
# ----> 2 my_list.size
#
# AttributeError: 'list' object has no attribute 'size'

# %%
#Pop from the front
my_list.pop()
# Out:
# 3

# %%
#Push a value to the back
my_list.push(3)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2701/2123201394.py in <cell line: 0>()
#       1 #Push a value to the back
# ----> 2 my_list.push(3)
#
# AttributeError: 'list' object has no attribute 'push'

# %%
#Display items in the queue.
my_list.show()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# /tmp/ipykernel_2701/590275978.py in <cell line: 0>()
#       1 #Display items in the queue.
# ----> 2 my_list.show()
#
# AttributeError: 'list' object has no attribute 'show'

# %% [markdown]
# Using a queue.

# %%
class Queue(list):
  '''
  Implements a queue data structure with methods push(), pop(), and show(),
  and attribute size.
  '''

  def __init__(self, initial_list=None):
    '''Initialize a Queue given an optional list'''
    if initial_list is not None:
      super().__init__(initial_list)
      self.size = len(initial_list)
    else:
      super().__init__()
      self.size = 0

  def push(self, item):
    '''Push an element onto the Queue'''
    self.append(item)
    self.size += 1

  def pop(self):
    '''Remove an element from the Queue'''
    if self.size > 0:
      self.size -= 1
      return super().pop(0)
    else:
      return None

  def show(self):
    '''Show the elements in the Queue'''
    return(self)

# %%
#Example usage:
q = Queue([1, 2, 3])
q
# Out:
# [1, 2, 3]

# %%
type(q)
# Out:
# __main__.Queue

# %%
print("Initial queue:", q)
# Out:
# Initial queue: [1, 2, 3]

# %%
print("Size of the queue:", q.size)
# Out:
# Size of the queue: 3

# %%
print("Popped item:", q.pop())
# Out:
# Popped item: 1

# %%
print("Queue after popping:", q)
# Out:
# Queue after popping: [2, 3]

# %%
print("Size after popping:", q.size)
# Out:
# Size after popping: 2

# %%
q.push(100)
q
# Out:
# [2, 3, 100]

# %%
print(q.show())
type(q)
# Out:
# [2, 3, 100]
# __main__.Queue

# %%
q = Queue()
q
# Out:
# []

# %%
q.push("Haji")
q
# Out:
# ['Haji']

# %%
q.push("Lisa")
q
# Out:
# ['Haji', 'Lisa']

# %%
q
# Out:
# ['Haji', 'Lisa']

# %%
q.pop()
# Out:
# 'Haji'

# %%
q
# Out:
# ['Lisa']

# %%
q.push("Abe")

# %%
q
# Out:
# ['Lisa', 'Abe']

# %%
q.size
# Out:
# 2

# %%
q.pop()
# Out:
# 'Lisa'

# %%
q
# Out:
# ['Abe']

# %%
q = Queue([1, 2, 3])
q
# Out:
# [1, 2, 3]

# %%
l = [1, 2, 3]
l
# Out:
# [1, 2, 3]

# %%
q.pop()
# Out:
# 1

# %%
l.pop()
# Out:
# 3

# %% [markdown]
# Introspection

# %%
dir(Queue)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'push',
#  'remove',
#  'reverse',
#  'show',
#  'sort']

# %%
dir(list)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'remove',
#  'reverse',
#  'sort']

# %%
dir(q)
# Out:
# ['__add__',
#  '__class__',
#  '__class_getitem__',
#  '__contains__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__reversed__',
#  '__rmul__',
#  '__setattr__',
#  '__setitem__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'append',
#  'clear',
#  'copy',
#  'count',
#  'extend',
#  'index',
#  'insert',
#  'pop',
#  'push',
#  'remove',
#  'reverse',
#  'show',
#  'size',
#  'sort']

# %%
Queue.__base__, Queue.__base__.__base__, Queue.__base__.__base__.__base__
# Out:
# (list, object, None)

# %% [markdown]
# ## Expanding Pandas

# %%
@pd.api.extensions.register_dataframe_accessor("rwc")
class DataFrameExtension:
  def __init__(self, pandas_obj):
    self._obj = pandas_obj

  def rows(self):
    return len(self._obj)

# %%
dir(DataFrameExtension)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'rows']

# %%
# Create a data frame
data = {'col1': [1, 2, 3, 4, 5], 'col2': ['a', 'b', 'c', 'd', 'e']}
df = pd.DataFrame(data)
df
# Out:
#    col1 col2
# 0     1    a
# 1     2    b
# 2     3    c
# 3     4    d
# 4     5    e

# %%
#Display how many rows
df.rwc.rows()
# Out:
# 5

# %%
dir(df.rwc)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_obj',
#  'rows']

# %% [markdown]
# ## Your turn
# 1. Create your own class.
#   - List a few attributes (>2)
#   - Create at least 3 methods - `__init__`, `__repr__`, and at least 1 method of your own
# 1. Create a new object of your class
# 1. Print your object, print your object's attributes, & run your method
#
#
# ---
# Ideas:
# - Car
# - Person
# - Plant

# %%
#Solution 1

# %%
#Solution 2

# %%
#Solution 3

# %% [markdown]
# ## Memoizing

# %% [markdown]
# ### Persistence with an instance attribute ( variable )

# %%
#Solution
class Fibonacci:

  def __init__(self):
    self.memo = {}

  def fibonacci(self, n):
    if n in self.memo:
      return self.memo[n]
    if n <= 1:
      return n
    else:
      result = self.fibonacci(n - 1) + self.fibonacci(n - 2)
      self.memo[n] = result
      return result

# %%
fib1a = Fibonacci()

#Output: 55
print(fib1a.fibonacci(10))
# Out:
# 55

# %%
fib1a.memo
# Out:
# {2: 1, 3: 2, 4: 3, 5: 5, 6: 8, 7: 13, 8: 21, 9: 34, 10: 55}

# %%
fib1b = Fibonacci()

# %%
fib1b.memo
# Out:
# {}

# %%
fib1a.memo
# Out:
# {2: 1, 3: 2, 4: 3, 5: 5, 6: 8, 7: 13, 8: 21, 9: 34, 10: 55}

# %% [markdown]
# ### Persistence with an class attribute ( variable )

# %%
#Solution
class Fibonacci2:
  memo = {}

  def fibonacci(self, n):
    if n in Fibonacci2.memo:
      return Fibonacci2.memo[n]
    if n <= 1:
      return n
    else:
      result = self.fibonacci(n - 1) + self.fibonacci(n - 2)
      Fibonacci2.memo[n] = result
      return result

# %%
fib2a = Fibonacci2()

#Output: 55
print(fib2a.fibonacci(10))
# Out:
# 55

# %%
fib2a.memo
# Out:
# {2: 1, 3: 2, 4: 3, 5: 5, 6: 8, 7: 13, 8: 21, 9: 34, 10: 55}

# %%
fib2b = Fibonacci2()

# %%
fib2b.memo
# Out:
# {2: 1, 3: 2, 4: 3, 5: 5, 6: 8, 7: 13, 8: 21, 9: 34, 10: 55}

# %%
fib2b.fibonacci(20)
# Out:
# 6765

# %%
fib2a.memo
# Out:
# {2: 1,
#  3: 2,
#  4: 3,
#  5: 5,
#  6: 8,
#  7: 13,
#  8: 21,
#  9: 34,
#  10: 55,
#  11: 89,
#  12: 144,
#  13: 233,
#  14: 377,
#  15: 610,
#  16: 987,
#  17: 1597,
#  18: 2584,
#  19: 4181,
#  20: 6765}

# %%
#Solution
class Fibonacci2:
  memo = {1:1}

  def fibonacci(n):
    if n in Fibonacci2.memo:
      return Fibonacci2.memo[n]
    if n <= 1:
      return n
    else:
      result = Fibonacci2.fibonacci(n - 1) + Fibonacci2.fibonacci(n - 2)
      Fibonacci2.memo[n] = result
      return result

# %%
fib3 = Fibonacci2()

# %%
Fibonacci2.fibonacci(-3)
# Out:
# -3

# %%
Fibonacci2.memo
# Out:
# {1: 1}
