# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module%204/2f_XGBoost.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import xgboost as xgb
from sklearn.model_selection import GridSearchCV

# %%
url = "https://ddc-datascience.s3.amazonaws.com/boston.csv"
boston = pd.read_csv(url, index_col = 0)

# %%
boston.shape
# Out:
# (490, 13)

# %%
boston.head()
# Out:
#    per_cap_crime  res_zoning_prop  business_prop  river_front  \
# 0        0.00632             18.0           2.31          0.0
# 1        0.02731              0.0           7.07          0.0
# 2        0.02729              0.0           7.07          0.0
# 3        0.03237              0.0           2.18          0.0
# 4        0.06905              0.0           2.18          0.0
#
#    nitric_oxide_conc  num_rooms  units_before_1940  distance_to_employment  \
# 0              0.538      6.575               65.2                  4.0900
# 1              0.469      6.421               78.9                  4.9671
# 2              0.469      7.185               61.1                  4.9671
# 3              0.458      6.998               45.8                  6.0622
# 4              0.458      7.147               54.2                  6.0622
#
#    distance_to_hwy  prop_tax  pupil_teacher_ratio  perc_lower_status  \
# 0              1.0     296.0                 15.3               4.98
# 1              2.0     242.0                 17.8               9.14
# 2              2.0     242.0                 17.8               4.03
# 3              3.0     222.0                 18.7               2.94
# 4              3.0     222.0                 18.7               5.33
#
#    med_home_value
# 0            24.0
# 1            21.6
# 2            34.7
# 3            33.4
# 4            36.2

# %%
boston.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 490 entries, 0 to 505
# Data columns (total 13 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   per_cap_crime           490 non-null    float64
#  1   res_zoning_prop         490 non-null    float64
#  2   business_prop           490 non-null    float64
#  3   river_front             490 non-null    float64
#  4   nitric_oxide_conc       490 non-null    float64
#  5   num_rooms               490 non-null    float64
#  6   units_before_1940       490 non-null    float64
#  7   distance_to_employment  490 non-null    float64
#  8   distance_to_hwy         490 non-null    float64
#  9   prop_tax                490 non-null    float64
#  10  pupil_teacher_ratio     490 non-null    float64
#  11  perc_lower_status       490 non-null    float64
#  12  med_home_value          490 non-null    float64
# dtypes: float64(13)
# memory usage: 53.6 KB

# %% [markdown]
# Recall that with a decision tree we got an RMSE of about \$3800, and with a random forest with got an RMSE of about \$2850.

# %% [markdown]
# #XGBoost

# %% [markdown]
# Here we are fitting an XGBoost model without specifying any hyperparameters.

# %%
X = boston.drop('med_home_value', axis = 1)
y = boston['med_home_value']

# %%
numLoops = 100
mse_xgb  = np.zeros(numLoops)

for idx in range(0,numLoops):
  X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.15)
  xgbr = xgb.XGBRegressor(objective ='reg:squarederror', verbosity=0, seed = 10)
  xgbr.fit(X_train,y_train)
  y_pred_xgb = xgbr.predict(X_test)
  mse_xgb[idx] = mean_squared_error(y_test,y_pred_xgb)

print(f'RMSE: {np.sqrt(mse_xgb).mean()*1000}')
# Out:
# RMSE: 2958.3288645604034

# %%
y_pred_xgb[0]
# Out:
# np.float32(7.7341623)

# %%
y_test.to_numpy()[0]
# Out:
# np.float64(7.2)

# %%
my_house = X_test[:3]
my_house
# Out:
#      per_cap_crime  res_zoning_prop  business_prop  river_front  \
# 385       16.81180              0.0          18.10          0.0
# 13         0.62976              0.0           8.14          0.0
# 182        0.09103              0.0           2.46          0.0
#
#      nitric_oxide_conc  num_rooms  units_before_1940  distance_to_employment  \
# 385              0.700      5.277               98.1                  1.4261
# 13               0.538      5.949               61.8                  4.7075
# 182              0.488      7.155               92.2                  2.7006
#
#      distance_to_hwy  prop_tax  pupil_teacher_ratio  perc_lower_status
# 385             24.0     666.0                 20.2              30.81
# 13               4.0     307.0                 21.0               8.26
# 182              3.0     193.0                 17.8               4.82

# %%
xgbr.predict(my_house)
# Out:
# array([ 7.7341623, 19.404144 , 32.62384  ], dtype=float32)

# %%
y_test[:3]
# Out:
# 385     7.2
# 13     20.4
# 182    37.9
# Name: med_home_value, dtype: float64

# %% [markdown]
# ## XGBoost with Parameters

# %% [markdown]
# Now we will see if we can improve performance by changing some parameters.

# %%
#Specify the parameters you want to try and their ranges.
param_test = {
 'max_depth'     : [3, 4, 5, 6, 7],
 'learning_rate' : [0.1, 0.2, 0.3, 0.4],
 'n_estimators'  : [20, 40, 60, 80, 100, 120, 140]
}

#Perform the grid search
gsearch = GridSearchCV(
    estimator = xgb.XGBRegressor(objective = 'reg:squarederror', seed = 10),
    param_grid = param_test,
    scoring = 'neg_mean_squared_error',
    cv = 5,
)

#Fit to training data
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=0.05, random_state = 42)
model = gsearch.fit(X_train,y_train)

#See grid search results
print(model.best_params_)
# Out:
# {'learning_rate': 0.2, 'max_depth': 3, 'n_estimators': 100}

# %% [markdown]
# Now we will fit our XGBoost model with the best parameters

# %%
params = model.best_params_

numLoops = 100
mse_xgb  = np.zeros(numLoops)

for idx in range(0,numLoops):
  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.15)
  xgbr = xgb.XGBRegressor(
      objective ='reg:squarederror',
      verbosity=0,
      **params,
      # learning_rate = 0.2,
      # max_depth = 3,
      # n_estimators = 100,
      seed = 10
  )
  xgbr.fit(X_train,y_train)
  y_pred_xgb = xgbr.predict(X_test)
  mse_xgb[idx] = mean_squared_error(y_test,y_pred_xgb)

print(f'RMSE: {np.sqrt(mse_xgb).mean()*1000}')
# Out:
# RMSE: 2847.317862251651

# %%
feat_imp = pd.Series(xgbr.feature_importances_, index=X.columns).sort_values(ascending=False)
plt.figure(figsize = (10,6))
sns.barplot(x = feat_imp.index, y = feat_imp.values)
plt.xticks(rotation=45, ha='right')
plt.xlabel('Feature')
plt.ylabel('Feature Importance Score');

# %%
(feat_imp.sort_values(ascending=False)*100).cumsum()
# Out:
# perc_lower_status          45.950775
# num_rooms                  62.029518
# pupil_teacher_ratio        77.614174
# prop_tax                   82.509132
# nitric_oxide_conc          86.649704
# per_cap_crime              89.904007
# distance_to_employment     92.664566
# distance_to_hwy            95.236038
# business_prop              97.230675
# units_before_1940          98.466278
# river_front                99.494423
# res_zoning_prop           100.000008
# dtype: float32
