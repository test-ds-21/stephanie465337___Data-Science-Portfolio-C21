# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/1b_Timing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Timing and optimizing code

# %% [markdown]
# Q: Are computers so fast that optimizing code for speed no longer matters?

# %% [markdown]
# ##  The Context

# %% [markdown]
# - It depends
# - Often optimizing isn't important
# - Computers are faster
# - It still can matter
# - Try to learn & use best-practices

# %% [markdown]
# ## Video

# %% [markdown]
# [Modern Data Warehousing with BigQuery](https://www.youtube.com/watch?v=eOQ3YJKgvHE&t=300s)  - Watch from 5:00 to 7:20.

# %% [markdown]
# ### Take-aways

# %% [markdown]
# - You might care about speed when dealing with big data
# - Some of the cutting edge problems to be solved _still_ have to do with optimization
#
# **Considerations**
# - Size of dataset
# - How often a task needs to be done
# - Time it takes to make process faster/time it takes to run it as is.
# -  How much are you going to learn from the process of making your code faster?
# -  Is anybody else going to see your code?

# %% [markdown]
# ## How to speed up your code?
# Below are a few easy ways.

# %% [markdown]
# ### 1. List Comprehensions vs For Loop

# %%
import numpy as np

# %%
r = 1_000

# %%
#For Loop
# %% will turn this into a cell magic
#It will work on multi-line code
#It will run many times and time it.
# %%timeit
squares = []

for n in range(r):
  squares.append(n**2)
# Out:
# 99.4 µs ± 36.9 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
#List Comprehension
# %indicates a magic command
# %timeit will apply to one line
result = %timeit -r3 -n10 -o squares = [n**2 for n in range(r)]
result
# Out:
# 174 µs ± 38.7 µs per loop (mean ± std. dev. of 3 runs, 10 loops each)
# <TimeitResult : 174 µs ± 38.7 µs per loop (mean ± std. dev. of 3 runs, 10 loops each)>

# %%
result.all_runs
# Out:
# [0.0012416879999932462, 0.002184310000018286, 0.0018067469999891728]

# %% [markdown]
# ### 2. Numpy Arrays

# %%
# %timeit squares = (np.arange(r))**2
# Out:
# 3.35 µs ± 96.1 ns per loop (mean ± std. dev. of 7 runs, 100000 loops each)

# %%
# %timeit squares = list((np.arange(r))**2)
# Out:
# 50.4 µs ± 1.02 µs per loop (mean ± std. dev. of 7 runs, 10000 loops each)

# %%
# %timeit?

# %% [markdown]
# ### 3. Multiple Assignments

# %%
# %%timeit
a = 5
b = 10
c = 20
d = 25
# Out:
# 52 ns ± 9.64 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit a,b,c,d = 5,10,20,25
# Out:
# 42.2 ns ± 15.9 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# ### 4. Use F Strings

# %%
name = 'Dwight Schrute'

# %%
# %timeit name + ' loves beets'
# Out:
# 58.8 ns ± 0.842 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit '%s loves beets' % name
# Out:
# 172 ns ± 61.2 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %timeit  '{} loves beets'.format(name)
# Out:
# 225 ns ± 6.89 ns per loop (mean ± std. dev. of 7 runs, 1000000 loops each)

# %%
# %timeit f'{name} loves beets'
# Out:
# 95.9 ns ± 36.3 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# ### 5. Use Built-In Functions
# Built-in functions such as `len()`, `abs()`, `min()`, and `max()` are written in C and are therefore very efficient.

# %%
# %%timeit
k=0
for i in range(1_000_000):
  k += 1
k
# Out:
# 43.3 ms ± 648 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
len(range(1_000_000))
# Out:
# 92.1 ns ± 1 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %%
# %%timeit
n = 1_000_000
(n-1)*n/2
# Out:
# 89 ns ± 1.08 ns per loop (mean ± std. dev. of 7 runs, 10000000 loops each)

# %% [markdown]
# ### 6. Use Enumerate

# %%
our_list = [i**2 for i in range(5)]
our_list
# Out:
# [0, 1, 4, 9, 16]

# %%
#Without enumerate
#Note: using time only runs the script once
# %%time
output = list(range(len(our_list)))
for i in range(len(our_list)):
  output[i] = (f'{i}^2 = {our_list[i]}')

print("\n".join(output))
# Out:
# 0^2 = 0
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# CPU times: user 118 µs, sys: 1e+03 ns, total: 119 µs
# Wall time: 124 µs

# %%
# %%time
for i, item in enumerate(our_list):
  print(f'{i}^2 = {item}')
# Out:
# 0^2 = 0
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# CPU times: user 116 µs, sys: 1e+03 ns, total: 117 µs
# Wall time: 98.9 µs

# %%
# %%time
print("\n".join(f'{i}^2 = {item}' for i, item in enumerate(our_list)))
# Out:
# 0^2 = 0
# 1^2 = 1
# 2^2 = 4
# 3^2 = 9
# 4^2 = 16
# CPU times: user 91 µs, sys: 1e+03 ns, total: 92 µs
# Wall time: 95.4 µs

# %% [markdown]
# There are many other ways to speed up your code, you just have to decide if it is needed for whatever application you are working on.

# %% [markdown]
# ## Metric Prefixes & Scientific Notation

# %% [markdown]
# [Wikipedia Metric Prefixes & Symbols](https://en.wikipedia.org/wiki/Metric_prefix)

# %% [markdown]
# 288.0 ms 10E-3 - decimal place goes over three  -> 0.288 s
#
# 3.59 µs  10E-6 - decimal place goes over six places -> 0.00000359 s
