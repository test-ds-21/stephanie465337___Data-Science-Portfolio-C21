# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module%201/6b2_Pandas_Importing_HTML_tax.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Importing HTML Data with Pandas

# %% [markdown]
# Pandas is capable of reading and writing data in a variety of file formats, including HTML. A list of all data formats that pandas supports is located [here](https://pandas.pydata.org/pandas-docs/stable/user_guide/io.html).

# %%
import pandas as pd

# %% [markdown]
# ## HTML
#
# Reading in html can be useful if there is a table of data on a website that you want to parse. We'll use the [2024 1040 Intructions]( https://www.irs.gov/instructions/i1040gi ) from the IRS.

# %%
url = "https://www.irs.gov/instructions/i1040gi"
tax_tables = pd.read_html(url)
len(tax_tables) # tax_tables contains all of the tables on this webpage
# Out:
# 200

# %%
for index, table in enumerate(tax_tables):
    print(f"== {index}")
    print(table.columns)
    print()
# Out:
# == 0
# Index([0, 1], dtype='int64')
#
# == 1
# Index([0, 1], dtype='int64')
#
# == 2
# Index([0, 1], dtype='int64')
#
# == 3
# Index(['Unnamed: 0', 'IF your filing status is . . .',
#        'AND at the end of 2025 you were* . . .',
#        'THEN file a return if your gross income** was at least . . .',
#        'THEN file a return if your gross income** was at least . . ..1',
#        'Unnamed: 5'],
#       dtype='object')
#
# == 4
# Index([0, 1, 2, 3, 4, 5, 6, 7], dtype='int64')
#
# == 5
# Index([0, 1, 2], dtype='int64')
#
# == 6
# Index([0, 1, 2, 3], dtype='int64')
#
# == 7
# Index([0, 1], dtype='int64')
#
# == 8
# Index([0, 1], dtype='int64')
#
# == 9
# Index([0, 1], dtype='int64')
#
# == 10
# Index([0, 1], dtype='int64')
#
# == 11
# Index([0, 1], dtype='int64')
#
# == 12
# Index([0, 1], dtype='int64')
#
# == 13
# Index([0, 1], dtype='int64')
#
# == 14
# Index([0, 1], dtype='int64')
#
# == 15
# Index([0, 1], dtype='int64')
#
# == 16
# Index([0, 1], dtype='int64')
#
# == 17
# ...

# %% [markdown]
# ### Locate tax table

# %%
tax_tables[173]
# Out:
#      If line 15 (taxable income) is—                     \
#                             At least      But less than
#                   Unnamed: 0_level_2 Unnamed: 1_level_2
# 0                                0.0                5.0
# 1                                5.0               15.0
# 2                               15.0               25.0
# 3                               25.0               50.0
# 4                               50.0               75.0
# ...                              ...                ...
# 2159                         99900.0            99950.0
# 2160                         99950.0           100000.0
# 2161                             NaN                NaN
# 2162                             NaN                NaN
# 2163                             NaN                NaN
#
#                                            And you are—  \
#                                                  Single
#                                            Your tax is—
# ...

# %%
tax_table = tax_tables[173]
tax_table
# Out:
#      If line 15 (taxable income) is—                     \
#                             At least      But less than
#                   Unnamed: 0_level_2 Unnamed: 1_level_2
# 0                                0.0                5.0
# 1                                5.0               15.0
# 2                               15.0               25.0
# 3                               25.0               50.0
# 4                               50.0               75.0
# ...                              ...                ...
# 2159                         99900.0            99950.0
# 2160                         99950.0           100000.0
# 2161                             NaN                NaN
# 2162                             NaN                NaN
# 2163                             NaN                NaN
#
#                                            And you are—  \
#                                                  Single
#                                            Your tax is—
# ...

# %% [markdown]
# ### Rename columns in tax table

# %%
tax_table.columns = "Low High Single Married MFJ HoH".split()

# %%
tax_table
# Out:
#           Low      High                                             Single  \
# 0         0.0       5.0                                                  0
# 1         5.0      15.0                                                  1
# 2        15.0      25.0                                                  2
# 3        25.0      50.0                                                  4
# 4        50.0      75.0                                                  6
# ...       ...       ...                                                ...
# 2159  99900.0   99950.0                                              16898
# 2160  99950.0  100000.0                                              16909
# 2161      NaN       NaN                                                NaN
# 2162      NaN       NaN  $100,000 or over use the Tax Computation Works...
# 2163      NaN       NaN                                                NaN
#
# ...

# %% [markdown]
# ### Clean table
#
# The table is segmented into 10,000, 20,000, 30,0000, etc.  These aren't actual values for the table, but rather dividers between income levels.  Remove segment rows.

# %%
segments = ( tax_table['High'] == tax_table["MFJ"] )
drop_indexes = tax_table[segments].index
tax_table_clean = tax_table.drop( drop_indexes ).dropna(axis = "rows")
tax_table_clean
# Out:
#           Low      High Single Married      MFJ      HoH
# 0         0.0       5.0      0       0      0.0      0.0
# 1         5.0      15.0      1       1      1.0      1.0
# 2        15.0      25.0      2       2      2.0      2.0
# 3        25.0      50.0      4       4      4.0      4.0
# 4        50.0      75.0      6       6      6.0      6.0
# ...       ...       ...    ...     ...      ...      ...
# 2156  99750.0   99800.0  16865   11779  16865.0  15126.0
# 2157  99800.0   99850.0  16876   11790  16876.0  15137.0
# 2158  99850.0   99900.0  16887   11801  16887.0  15148.0
# 2159  99900.0   99950.0  16898   11812  16898.0  15159.0
# 2160  99950.0  100000.0  16909   11823  16909.0  15170.0
#
# [2062 rows x 6 columns]

# %%
tax_table_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2062 entries, 0 to 2160
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Low      2062 non-null   float64
#  1   High     2062 non-null   float64
#  2   Single   2062 non-null   object
#  3   Married  2062 non-null   object
#  4   MFJ      2062 non-null   float64
#  5   HoH      2062 non-null   float64
# dtypes: float64(4), object(2)
# memory usage: 112.8+ KB

# %%
for col in tax_table_clean.columns:
  tax_table_clean[col] = tax_table_clean[col].astype(int)

# %%
tax_table_clean.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2062 entries, 0 to 2160
# Data columns (total 6 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   Low      2062 non-null   int64
#  1   High     2062 non-null   int64
#  2   Single   2062 non-null   int64
#  3   Married  2062 non-null   int64
#  4   MFJ      2062 non-null   int64
#  5   HoH      2062 non-null   int64
# dtypes: int64(6)
# memory usage: 112.8 KB

# %%
df = tax_table_clean
df
# Out:
#         Low    High  Single  Married    MFJ    HoH
# 0         0       5       0        0      0      0
# 1         5      15       1        1      1      1
# 2        15      25       2        2      2      2
# 3        25      50       4        4      4      4
# 4        50      75       6        6      6      6
# ...     ...     ...     ...      ...    ...    ...
# 2156  99750   99800   16865    11779  16865  15126
# 2157  99800   99850   16876    11790  16876  15137
# 2158  99850   99900   16887    11801  16887  15148
# 2159  99900   99950   16898    11812  16898  15159
# 2160  99950  100000   16909    11823  16909  15170
#
# [2062 rows x 6 columns]

# %%
filter = ( (df["Low"] >= 1400) & (df["High"] <= 1600 ) )
df[filter]
# Out:
#      Low  High  Single  Married  MFJ  HoH
# 59  1400  1425     141      141  141  141
# 60  1425  1450     144      144  144  144
# 61  1450  1475     146      146  146  146
# 62  1475  1500     149      149  149  149
# 63  1500  1525     151      151  151  151
# 64  1525  1550     154      154  154  154
# 65  1550  1575     156      156  156  156
# 66  1575  1600     159      159  159  159

# %% [markdown]
# ### Plot Tax Due versus Income

# %%
# Create the plot
subplot = df.plot(x='High', y='Single', kind='line')

# Add title and labels
subplot.set_title('Tax vs Income')
subplot.set_xlabel('Income')
subplot.set_ylabel('Tax')
;
# Out:
# ''

# %% [markdown]
# ### Identify tax bracket changes

# %% [markdown]
# #### Calculate midpoint between High and Low income values

# %%
df["midpoint"] = ( df["High"] + df["Low"] ) / 2
df
# Out:
#         Low    High  Single  Married    MFJ    HoH  midpoint
# 0         0       5       0        0      0      0       2.5
# 1         5      15       1        1      1      1      10.0
# 2        15      25       2        2      2      2      20.0
# 3        25      50       4        4      4      4      37.5
# 4        50      75       6        6      6      6      62.5
# ...     ...     ...     ...      ...    ...    ...       ...
# 2156  99750   99800   16865    11779  16865  15126   99775.0
# 2157  99800   99850   16876    11790  16876  15137   99825.0
# 2158  99850   99900   16887    11801  16887  15148   99875.0
# 2159  99900   99950   16898    11812  16898  15159   99925.0
# 2160  99950  100000   16909    11823  16909  15170   99975.0
#
# [2062 rows x 7 columns]

# %% [markdown]
# #### Calculate tax as a percentage of income
#
# Percent = tax due / income * 100

# %%
df["pct"] = df["Single"].div(df["midpoint"]).mul(100)
df
# Out:
#         Low    High  Single  Married    MFJ    HoH  midpoint        pct
# 0         0       5       0        0      0      0       2.5   0.000000
# 1         5      15       1        1      1      1      10.0  10.000000
# 2        15      25       2        2      2      2      20.0  10.000000
# 3        25      50       4        4      4      4      37.5  10.666667
# 4        50      75       6        6      6      6      62.5   9.600000
# ...     ...     ...     ...      ...    ...    ...       ...        ...
# 2156  99750   99800   16865    11779  16865  15126   99775.0  16.903032
# 2157  99800   99850   16876    11790  16876  15137   99825.0  16.905585
# 2158  99850   99900   16887    11801  16887  15148   99875.0  16.908135
# 2159  99900   99950   16898    11812  16898  15159   99925.0  16.910683
# 2160  99950  100000   16909    11823  16909  15170   99975.0  16.913228
#
# [2062 rows x 8 columns]

# %% [markdown]
# #### Calculate diff in percentage

# %%
df["pct_delta"] = df["pct"].diff()
df
# Out:
#         Low    High  Single  Married    MFJ    HoH  midpoint        pct  \
# 0         0       5       0        0      0      0       2.5   0.000000
# 1         5      15       1        1      1      1      10.0  10.000000
# 2        15      25       2        2      2      2      20.0  10.000000
# 3        25      50       4        4      4      4      37.5  10.666667
# 4        50      75       6        6      6      6      62.5   9.600000
# ...     ...     ...     ...      ...    ...    ...       ...        ...
# 2156  99750   99800   16865    11779  16865  15126   99775.0  16.903032
# 2157  99800   99850   16876    11790  16876  15137   99825.0  16.905585
# 2158  99850   99900   16887    11801  16887  15148   99875.0  16.908135
# 2159  99900   99950   16898    11812  16898  15159   99925.0  16.910683
# 2160  99950  100000   16909    11823  16909  15170   99975.0  16.913228
#
#       pct_delta
# 0           NaN
# 1     10.000000
# 2      0.000000
# 3      0.666667
# ...

# %% [markdown]
# #### Calculate diff of diff

# %%
df["pct_delta_delta"] = df["pct_delta"].diff().mul(10_000)
df
# Out:
#         Low    High  Single  Married    MFJ    HoH  midpoint        pct  \
# 0         0       5       0        0      0      0       2.5   0.000000
# 1         5      15       1        1      1      1      10.0  10.000000
# 2        15      25       2        2      2      2      20.0  10.000000
# 3        25      50       4        4      4      4      37.5  10.666667
# 4        50      75       6        6      6      6      62.5   9.600000
# ...     ...     ...     ...      ...    ...    ...       ...        ...
# 2156  99750   99800   16865    11779  16865  15126   99775.0  16.903032
# 2157  99800   99850   16876    11790  16876  15137   99825.0  16.905585
# 2158  99850   99900   16887    11801  16887  15148   99875.0  16.908135
# 2159  99900   99950   16898    11812  16898  15159   99925.0  16.910683
# 2160  99950  100000   16909    11823  16909  15170   99975.0  16.913228
#
#       pct_delta  pct_delta_delta
# 0           NaN              NaN
# 1     10.000000              NaN
# ...

# %%
# n = 200
# df[n:n+50]
low = ( df["High"] > 11_650 )
high = ( df["High"] < 12_200 )

df[ low & high ]
# Out:
#        Low   High  Single  Married   MFJ   HoH  midpoint        pct  \
# 306  11650  11700    1168     1168  1168  1168   11675.0  10.004283
# 307  11700  11750    1173     1173  1173  1173   11725.0  10.004264
# 308  11750  11800    1178     1178  1178  1178   11775.0  10.004246
# 309  11800  11850    1183     1183  1183  1183   11825.0  10.004228
# 310  11850  11900    1188     1188  1188  1188   11875.0  10.004211
# 311  11900  11950    1193     1193  1193  1193   11925.0  10.004193
# 312  11950  12000    1199     1198  1199  1198   11975.0  10.012526
# 314  12000  12050    1205     1203  1205  1203   12025.0  10.020790
# 315  12050  12100    1211     1208  1211  1208   12075.0  10.028986
# 316  12100  12150    1217     1213  1217  1213   12125.0  10.037113
#
#      pct_delta  pct_delta_delta
# 306  -0.000018         0.001591
# 307  -0.000018         0.001571
# 308  -0.000018         0.001551
# 309  -0.000018         0.001531
# 310  -0.000018         0.001512
# ...

# %%
filter = ( df["pct_delta_delta"] > 1 ) & ( df["Low"] > 3000 )
df[ filter ]
# Out:
#         Low   High  Single  Married   MFJ   HoH  midpoint        pct  \
# 312   11950  12000    1199     1198  1199  1198   11975.0  10.012526
# 1080  48500  48550    5590     5346  5590  5483   48525.0  11.519835
#
#       pct_delta  pct_delta_delta
# 312    0.008333        83.508781
# 1080   0.010810       103.029223

# %% [markdown]
# From [Marginal Tax Rates 2025]( https://www.irs.gov/newsroom/irs-releases-tax-inflation-adjustments-for-tax-year-2025#:~:text=Marginal%20rates.%20For%20tax%20year%202025 )
#
# Historical info: [Marginal Tax Rates]( https://www.irs.gov/newsroom/inflation-adjusted-tax-items-by-tax-year )
#
# - 37% for incomes over \$626,350 (\$751,600 for married couples filing jointly)
# - 35% for incomes over \$250,525 (\$501,050 for married couples filing jointly).
# - 32% for incomes over \$197,300 (\$394,600 for married couples filing jointly).
# - 24% for incomes over \$103,350 (\$206,700 for married couples filing jointly).
# - 22% for incomes over \$48,475 (\$96,950 for married couples filing jointly).
# - 12% for incomes over \$11,925 (\$23,850 for married couples filing jointly).
# - 10% for incomes over \$0 (\$0 for married couples filing jointly)

# %%
import matplotlib.pyplot as plt

subplot = df.plot(
  figsize = (12, 6),
  kind = "line",
  x = "High",
  y = "pct",
  title = "Marginal Tax vs AGI",
  xlabel = "Adjusted Gross Income ($)",
  ylabel = "Marginal Tax (%)",
  legend = False,
  # ylim = [9.5, 10.4],
  # xlim = [10500, 12000],
)

x_positions = [
  0,
  11_925,
  48_475,
  103_350,
]

for x in x_positions:
  subplot.axvline(x=x, color='r', linestyle='--', linewidth=1)

y_positions = [
  0,
  10,
  12,
  22,
  24,
]

for y in y_positions:
  subplot.axhline(y=y, color='r', linestyle='--', linewidth=1)
