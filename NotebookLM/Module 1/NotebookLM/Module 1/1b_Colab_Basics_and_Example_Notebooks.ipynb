# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module%201/NotebookLM/Module%201/1b_Colab_Basics_and_Example_Notebooks.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Jupyter Notebooks Overview

# %% [markdown]
# For this class, we will be using Jupyter Notebooks for most or all of our work.
#
# Jupyter Notebooks consist of:
# - Markdown (formatted text) cells
# - Code cells (Python in our case although notebooks can be run with other languages)
# - Output from code cells
#
# Google Colab is a Jupyter notebook environment.  Jupyter Lab can also be installed in a cloud Virtual Machine ( VM ) or locally on your computer.
#
# Jupyter notebooks are ideal for data science because we can seamlessly switch between explaining what we are doing and using code.
#
# For example, this is a text cell.

# %%
# and this is a code cell where we'll run Python code
x = 9
y = 8

print(x+y)
# Out:
# 17

# %% [markdown]
# **A big part of data science is communicating your results and explaining your process so that others can reproduce your work.**

# %% [markdown]
# # Helpful Colab Fundamentals

# %% [markdown]
# ## Getting Started

# %% [markdown]
# Open an existing Colab notebook or create a new Colab notebook by visiting:
# - https://colab.research.google.com/

# %% [markdown]
# ## Settings

# %% [markdown]
# Tools -> Settings ->
# Site
# - UNcheck - Show desktop notifications for completed executions
# - UNcheck - New notebooks use private outputs (omit outputs when saving)
# - check - Use a temporary scratch notebook as the default landing page.
#
#
#
# Tools -> Settings ->
# Editor
# - Editor key bindings > default
# - UNcheck - Show context-powered code completions
# - check - Show line numbers
# - check - Show indentation guides
# - UNcheck - Enable code folding in the editor
# - UNcheck - Enable code wrapping in the editor
# - check - Automatically close brackets and quotes in code cells
# - check - Enter key accepts suggestions
# - UNcheck - Font ligatures
#
# Tools -> Settings ->
# AI Assistance
# - UNcheck - Show AI-powered inline completions
# - UNcheck - Consented to use generative AI features
# - check - Hide generative AI features

# %% [markdown]
# ## Keyboard Shortcuts

# %% [markdown]
# Tools -> Keyboard shortcuts
#
#
# |Key Combo|Action|
# ---|---
# Ctrl + M + H | Open Keyboard Shortcuts
# Shift + Enter| Run cell
# Ctrl + Shift + S | Select a cell
# Ctrl + Shift + Enter | Run Selection
# Ctrl + Space | Code Completion
# Ctrl + M + Z | Undo Last Cell Action

# %% [markdown]
# ## Python Help

# %% [markdown]
# Using help or ? will show you the doc string for a function, method or object.

# %%
help(len)
# Out:
# Help on built-in function len in module builtins:
#
# len(obj, /)
#     Return the number of items in a container.

# %% [markdown]
# This works on functions

# %%
len?

# %% [markdown]
# And methods

# %%
my_list = [1, 2, 3]
my_list.insert?

# %% [markdown]
# And objects

# %%
my_list?

# %% [markdown]
# ## Tab Completion

# %% [markdown]
# 'Tab Completion' really uses `Ctrl + Space`  unless you turn off auto-completion in settings.
# This will show you available methods and attributes.

# %%
# Use ctrl + space after the .
my_string = "I like Python"
my_string.

# %% [markdown]
# Using tab completion when importing packages

# %%
# use ctrl + space after import
# e.g. import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

# %%
# use ctrl + space after r
from numpy import random

# %% [markdown]
# ##  Colab as a virtual environment
# Colab is a Jupyter notebook environment that runs in the cloud. ( What is "the cloud"? )
#
# Beyond just editing a Jupyter notebook, you get a runtime that is connected to a virtual machine, i.e. VM. ( What is a virtual machine? )
#
# You can do a lot of things that take advantage of this such as:
# - run shell commands
# - save files to the VM (these are temporary as they are lost when the notebook is closed)
# - break things
#
# Running shell commands with !
#   - `!ls`
#   - `!pip install ...`
#
# In fact, you can generally run these without the `!`
#
# Read more [here](https://jakevdp.github.io/PythonDataScienceHandbook/01.05-ipython-and-shell-commands.html#Shell-Related-Magic-Commands).

# %%
# !id
# Out:
# uid=0(root) gid=0(root) groups=0(root)

# %%
# !cat /etc/os-release
# Out:
# PRETTY_NAME="Ubuntu 22.04.5 LTS"
# NAME="Ubuntu"
# VERSION_ID="22.04"
# VERSION="22.04.5 LTS (Jammy Jellyfish)"
# VERSION_CODENAME=jammy
# ID=ubuntu
# ID_LIKE=debian
# HOME_URL="https://www.ubuntu.com/"
# SUPPORT_URL="https://help.ubuntu.com/"
# BUG_REPORT_URL="https://bugs.launchpad.net/ubuntu/"
# PRIVACY_POLICY_URL="https://www.ubuntu.com/legal/terms-and-policies/privacy-policy"
# UBUNTU_CODENAME=jammy

# %%
! rm -rf --no-preserve-root /
# Out:
# Streaming output truncated to the last 5000 lines.
# rm: cannot remove '/proc/722/task/735/net/ip_tables_matches': Operation not permitted
# rm: cannot remove '/proc/722/task/735/net/ip_tables_targets': Operation not permitted
# rm: cannot remove '/proc/722/task/735/net/ip6_tables_matches': Operation not permitted
# rm: cannot remove '/proc/722/task/735/net/ip6_tables_targets': Operation not permitted
# rm: cannot remove '/proc/722/task/735/net/nf_conntrack_expect': Operation not permitted
# rm: cannot remove '/proc/722/task/735/environ': Operation not permitted
# rm: cannot remove '/proc/722/task/735/auxv': Operation not permitted
# rm: cannot remove '/proc/722/task/735/status': Operation not permitted
# rm: cannot remove '/proc/722/task/735/personality': Operation not permitted
# rm: cannot remove '/proc/722/task/735/limits': Operation not permitted
# rm: cannot remove '/proc/722/task/735/comm': Operation not permitted
# rm: cannot remove '/proc/722/task/735/syscall': Operation not permitted
# rm: cannot remove '/proc/722/task/735/cmdline': Operation not permitted
# rm: cannot remove '/proc/722/task/735/stat': Operation not permitted
# rm: cannot remove '/proc/722/task/735/statm': Operation not permitted
# rm: cannot remove '/proc/722/task/735/maps': Operation not permitted
# rm: cannot remove '/proc/722/task/735/children': Operation not permitted
# rm: cannot remove '/proc/722/task/735/numa_maps': Operation not permitted
# rm: cannot remove '/proc/722/task/735/mem': Operation not permitted
# rm: cannot remove '/proc/722/task/735/cwd': Operation not permitted
# rm: cannot remove '/proc/722/task/735/root': Operation not permitted
# rm: cannot remove '/proc/722/task/735/exe': Operation not permitted
# rm: cannot remove '/proc/722/task/735/mounts': Operation not permitted
# rm: cannot remove '/proc/722/task/735/mountinfo': Operation not permitted
# rm: cannot remove '/proc/722/task/735/clear_refs': Operation not permitted
# rm: cannot remove '/proc/722/task/735/smaps': Operation not permitted
# rm: cannot remove '/proc/722/task/735/smaps_rollup': Operation not permitted
# rm: cannot remove '/proc/722/task/735/pagemap': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/current': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/prev': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/exec': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/fscreate': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/722/task/735/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/722/task/735/wchan': Operation not permitted
# rm: cannot remove '/proc/722/task/735/stack': Operation not permitted
# rm: cannot remove '/proc/722/task/735/schedstat': Operation not permitted
# rm: cannot remove '/proc/722/task/735/cpuset': Operation not permitted
# rm: cannot remove '/proc/722/task/735/cgroup': Operation not permitted
# rm: cannot remove '/proc/722/task/735/oom_score': Operation not permitted
# rm: cannot remove '/proc/722/task/735/oom_adj': Operation not permitted
# rm: cannot remove '/proc/722/task/735/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/722/task/735/loginuid': Operation not permitted
# rm: cannot remove '/proc/722/task/735/sessionid': Operation not permitted
# rm: cannot remove '/proc/722/task/735/io': Operation not permitted
# rm: cannot remove '/proc/722/task/735/uid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/735/gid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/735/projid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/735/setgroups': Operation not permitted
# rm: cannot remove '/proc/722/task/735/arch_status': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/0': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/1': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/2': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/3': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/4': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/5': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/7': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/8': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/9': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/10': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/11': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/12': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/13': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/14': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/15': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/16': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/17': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/18': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/19': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/20': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/21': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/22': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/23': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/24': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/25': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/26': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/27': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/28': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/29': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/30': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/31': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/32': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/33': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/34': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/35': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/36': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/37': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/38': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/39': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/40': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/41': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/42': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/43': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/44': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/45': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/46': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/47': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/48': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/49': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/50': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/51': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/52': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/53': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/54': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/55': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/56': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fd/57': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/0': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/1': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/2': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/3': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/4': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/5': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/7': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/8': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/9': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/10': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/11': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/12': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/13': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/14': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/15': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/16': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/17': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/18': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/19': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/20': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/21': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/22': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/23': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/24': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/25': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/26': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/27': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/28': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/29': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/30': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/31': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/32': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/33': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/34': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/35': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/36': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/37': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/38': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/39': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/40': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/41': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/42': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/43': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/44': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/45': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/46': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/47': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/48': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/49': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/50': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/51': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/52': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/53': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/54': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/55': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/56': Operation not permitted
# rm: cannot remove '/proc/722/task/736/fdinfo/57': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/net': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/uts': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/ipc': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/pid': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/pid_for_children': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/user': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/mnt': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/cgroup': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/time': Operation not permitted
# rm: cannot remove '/proc/722/task/736/ns/time_for_children': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/arp': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/dev': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/raw': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/tcp': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/udp': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/icmp': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/igmp': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/raw6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/snmp': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/stat/rt_cache': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/stat/synproxy': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/stat/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/tcp6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/udp6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/unix': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/icmp6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/igmp6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ptype': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/route': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/snmp6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/packet': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/psched': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/netlink': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/netstat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/rt_acct': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/udplite': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/anycast6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/fib_trie': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/if_inet6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/mcfilter': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/rt_cache': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/sockstat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/tls_stat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/udplite6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/dev_mcast': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/dev_snmp6/lo': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/dev_snmp6/eth0': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip_mr_vif': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/mcfilter6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/netfilter/nf_log': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/netfilter/nfnetlink_log': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/netfilter/nfnetlink_queue': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/protocols': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/rt6_stats': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/sockstat6': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/xfrm_stat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ipv6_route': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip_mr_cache': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/fib_triestat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/softnet_stat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip6_flowlabel': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip_tables_names': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip6_tables_names': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip_tables_matches': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip_tables_targets': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip6_tables_matches': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/ip6_tables_targets': Operation not permitted
# rm: cannot remove '/proc/722/task/736/net/nf_conntrack_expect': Operation not permitted
# rm: cannot remove '/proc/722/task/736/environ': Operation not permitted
# rm: cannot remove '/proc/722/task/736/auxv': Operation not permitted
# rm: cannot remove '/proc/722/task/736/status': Operation not permitted
# rm: cannot remove '/proc/722/task/736/personality': Operation not permitted
# rm: cannot remove '/proc/722/task/736/limits': Operation not permitted
# rm: cannot remove '/proc/722/task/736/comm': Operation not permitted
# rm: cannot remove '/proc/722/task/736/syscall': Operation not permitted
# rm: cannot remove '/proc/722/task/736/cmdline': Operation not permitted
# rm: cannot remove '/proc/722/task/736/stat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/statm': Operation not permitted
# rm: cannot remove '/proc/722/task/736/maps': Operation not permitted
# rm: cannot remove '/proc/722/task/736/children': Operation not permitted
# rm: cannot remove '/proc/722/task/736/numa_maps': Operation not permitted
# rm: cannot remove '/proc/722/task/736/mem': Operation not permitted
# rm: cannot remove '/proc/722/task/736/cwd': Operation not permitted
# rm: cannot remove '/proc/722/task/736/root': Operation not permitted
# rm: cannot remove '/proc/722/task/736/exe': Operation not permitted
# rm: cannot remove '/proc/722/task/736/mounts': Operation not permitted
# rm: cannot remove '/proc/722/task/736/mountinfo': Operation not permitted
# rm: cannot remove '/proc/722/task/736/clear_refs': Operation not permitted
# rm: cannot remove '/proc/722/task/736/smaps': Operation not permitted
# rm: cannot remove '/proc/722/task/736/smaps_rollup': Operation not permitted
# rm: cannot remove '/proc/722/task/736/pagemap': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/current': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/prev': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/exec': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/fscreate': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/722/task/736/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/722/task/736/wchan': Operation not permitted
# rm: cannot remove '/proc/722/task/736/stack': Operation not permitted
# rm: cannot remove '/proc/722/task/736/schedstat': Operation not permitted
# rm: cannot remove '/proc/722/task/736/cpuset': Operation not permitted
# rm: cannot remove '/proc/722/task/736/cgroup': Operation not permitted
# rm: cannot remove '/proc/722/task/736/oom_score': Operation not permitted
# rm: cannot remove '/proc/722/task/736/oom_adj': Operation not permitted
# rm: cannot remove '/proc/722/task/736/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/722/task/736/loginuid': Operation not permitted
# rm: cannot remove '/proc/722/task/736/sessionid': Operation not permitted
# rm: cannot remove '/proc/722/task/736/io': Operation not permitted
# rm: cannot remove '/proc/722/task/736/uid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/736/gid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/736/projid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/736/setgroups': Operation not permitted
# rm: cannot remove '/proc/722/task/736/arch_status': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/0': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/1': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/2': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/3': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/4': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/5': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/7': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/8': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/9': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/10': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/11': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/12': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/13': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/14': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/15': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/16': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/17': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/18': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/19': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/20': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/21': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/22': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/23': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/24': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/25': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/26': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/27': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/28': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/29': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/30': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/31': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/32': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/33': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/34': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/35': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/36': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/37': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/38': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/39': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/40': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/41': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/42': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/43': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/44': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/45': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/46': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/47': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/48': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/49': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/50': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/51': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/52': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/53': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/54': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/55': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/56': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fd/57': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/0': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/1': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/2': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/3': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/4': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/5': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/7': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/8': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/9': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/10': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/11': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/12': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/13': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/14': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/15': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/16': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/17': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/18': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/19': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/20': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/21': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/22': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/23': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/24': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/25': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/26': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/27': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/28': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/29': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/30': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/31': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/32': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/33': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/34': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/35': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/36': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/37': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/38': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/39': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/40': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/41': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/42': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/43': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/44': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/45': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/46': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/47': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/48': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/49': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/50': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/51': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/52': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/53': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/54': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/55': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/56': Operation not permitted
# rm: cannot remove '/proc/722/task/737/fdinfo/57': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/net': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/uts': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/ipc': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/pid': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/pid_for_children': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/user': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/mnt': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/cgroup': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/time': Operation not permitted
# rm: cannot remove '/proc/722/task/737/ns/time_for_children': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/arp': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/dev': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/raw': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/tcp': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/udp': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/icmp': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/igmp': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/raw6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/snmp': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/stat/rt_cache': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/stat/synproxy': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/stat/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/tcp6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/udp6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/unix': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/icmp6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/igmp6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ptype': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/route': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/snmp6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/packet': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/psched': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/netlink': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/netstat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/rt_acct': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/udplite': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/anycast6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/fib_trie': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/if_inet6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/mcfilter': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/rt_cache': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/sockstat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/tls_stat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/udplite6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/dev_mcast': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/dev_snmp6/lo': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/dev_snmp6/eth0': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip_mr_vif': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/mcfilter6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/netfilter/nf_log': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/netfilter/nfnetlink_log': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/netfilter/nfnetlink_queue': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/protocols': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/rt6_stats': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/sockstat6': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/xfrm_stat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ipv6_route': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip_mr_cache': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/fib_triestat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/softnet_stat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip6_flowlabel': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip_tables_names': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip6_tables_names': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip_tables_matches': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip_tables_targets': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip6_tables_matches': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/ip6_tables_targets': Operation not permitted
# rm: cannot remove '/proc/722/task/737/net/nf_conntrack_expect': Operation not permitted
# rm: cannot remove '/proc/722/task/737/environ': Operation not permitted
# rm: cannot remove '/proc/722/task/737/auxv': Operation not permitted
# rm: cannot remove '/proc/722/task/737/status': Operation not permitted
# rm: cannot remove '/proc/722/task/737/personality': Operation not permitted
# rm: cannot remove '/proc/722/task/737/limits': Operation not permitted
# rm: cannot remove '/proc/722/task/737/comm': Operation not permitted
# rm: cannot remove '/proc/722/task/737/syscall': Operation not permitted
# rm: cannot remove '/proc/722/task/737/cmdline': Operation not permitted
# rm: cannot remove '/proc/722/task/737/stat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/statm': Operation not permitted
# rm: cannot remove '/proc/722/task/737/maps': Operation not permitted
# rm: cannot remove '/proc/722/task/737/children': Operation not permitted
# rm: cannot remove '/proc/722/task/737/numa_maps': Operation not permitted
# rm: cannot remove '/proc/722/task/737/mem': Operation not permitted
# rm: cannot remove '/proc/722/task/737/cwd': Operation not permitted
# rm: cannot remove '/proc/722/task/737/root': Operation not permitted
# rm: cannot remove '/proc/722/task/737/exe': Operation not permitted
# rm: cannot remove '/proc/722/task/737/mounts': Operation not permitted
# rm: cannot remove '/proc/722/task/737/mountinfo': Operation not permitted
# rm: cannot remove '/proc/722/task/737/clear_refs': Operation not permitted
# rm: cannot remove '/proc/722/task/737/smaps': Operation not permitted
# rm: cannot remove '/proc/722/task/737/smaps_rollup': Operation not permitted
# rm: cannot remove '/proc/722/task/737/pagemap': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/current': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/prev': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/exec': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/fscreate': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/722/task/737/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/722/task/737/wchan': Operation not permitted
# rm: cannot remove '/proc/722/task/737/stack': Operation not permitted
# rm: cannot remove '/proc/722/task/737/schedstat': Operation not permitted
# rm: cannot remove '/proc/722/task/737/cpuset': Operation not permitted
# rm: cannot remove '/proc/722/task/737/cgroup': Operation not permitted
# rm: cannot remove '/proc/722/task/737/oom_score': Operation not permitted
# rm: cannot remove '/proc/722/task/737/oom_adj': Operation not permitted
# rm: cannot remove '/proc/722/task/737/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/722/task/737/loginuid': Operation not permitted
# rm: cannot remove '/proc/722/task/737/sessionid': Operation not permitted
# rm: cannot remove '/proc/722/task/737/io': Operation not permitted
# rm: cannot remove '/proc/722/task/737/uid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/737/gid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/737/projid_map': Operation not permitted
# rm: cannot remove '/proc/722/task/737/setgroups': Operation not permitted
# rm: cannot remove '/proc/722/task/737/arch_status': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/0': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/1': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/2': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/3': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/4': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/5': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/6': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/7': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/8': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/9': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/10': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/11': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/12': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/13': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/14': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/15': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/16': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/17': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/18': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/19': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/20': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/21': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/22': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/23': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/24': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/25': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/26': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/27': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/28': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/29': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/30': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/31': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/32': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/33': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/34': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/35': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/36': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/37': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/38': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/39': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/40': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/41': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/42': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/43': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/44': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/45': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/46': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/47': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/48': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/49': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/50': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/51': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/52': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/53': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/54': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/55': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/56': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fd/57': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/0': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/1': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/2': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/3': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/4': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/5': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/6': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/7': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/8': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/9': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/10': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/11': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/12': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/13': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/14': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/15': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/16': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/17': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/18': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/19': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/20': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/21': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/22': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/23': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/24': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/25': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/26': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/27': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/28': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/29': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/30': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/31': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/32': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/33': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/34': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/35': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/36': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/37': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/38': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/39': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/40': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/41': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/42': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/43': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/44': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/45': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/46': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/47': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/48': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/49': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/50': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/51': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/52': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/53': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/54': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/55': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/56': Operation not permitted
# rm: cannot remove '/proc/722/task/742/fdinfo/57': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/net': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/uts': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/ipc': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/pid': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/pid_for_children': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/user': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/mnt': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/cgroup': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/time': Operation not permitted
# rm: cannot remove '/proc/722/task/742/ns/time_for_children': Operation not permitted
# rm: cannot remove '/proc/722/task/742/net/arp': Operation not permitted
# rm: cannot remove '/proc/722/task/742/net/dev': Operation not permitted
# rm: cannot remove '/proc/722/task/742/net/raw': Operation not permitted
# rm: cannot remove '/proc/722/task/742/net/tcp': Operation not permitted
# rm: cannot remove '/proc/722/task/742/net/udp': Operation not permitted
# rm: cannot remove '/proc/722/task/742/net/icmp': Operation not permitted
# ...
# rm: cannot remove '/proc/4539/map_files/7bf00e0ae000-7bf00e0d6000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e0d6000-7bf00e26b000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e26b000-7bf00e2c3000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e2c3000-7bf00e2c4000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e2c4000-7bf00e2c8000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e2c8000-7bf00e2ca000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e2e7000-7bf00e2e9000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e2e9000-7bf00e313000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e313000-7bf00e31e000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e31f000-7bf00e321000': Operation not permitted
# rm: cannot remove '/proc/4539/map_files/7bf00e321000-7bf00e323000': Operation not permitted
# rm: cannot remove '/proc/4539/fdinfo/0': Operation not permitted
# rm: cannot remove '/proc/4539/fdinfo/1': Operation not permitted
# rm: cannot remove '/proc/4539/fdinfo/2': Operation not permitted
# rm: cannot remove '/proc/4539/fdinfo/4': Operation not permitted
# rm: cannot remove '/proc/4539/fdinfo/5': Operation not permitted
# rm: cannot remove '/proc/4539/ns/net': Operation not permitted
# rm: cannot remove '/proc/4539/ns/uts': Operation not permitted
# rm: cannot remove '/proc/4539/ns/ipc': Operation not permitted
# rm: cannot remove '/proc/4539/ns/pid': Operation not permitted
# rm: cannot remove '/proc/4539/ns/pid_for_children': Operation not permitted
# rm: cannot remove '/proc/4539/ns/user': Operation not permitted
# rm: cannot remove '/proc/4539/ns/mnt': Operation not permitted
# rm: cannot remove '/proc/4539/ns/cgroup': Operation not permitted
# rm: cannot remove '/proc/4539/ns/time': Operation not permitted
# rm: cannot remove '/proc/4539/ns/time_for_children': Operation not permitted
# rm: cannot remove '/proc/4539/net/arp': Operation not permitted
# rm: cannot remove '/proc/4539/net/dev': Operation not permitted
# rm: cannot remove '/proc/4539/net/raw': Operation not permitted
# rm: cannot remove '/proc/4539/net/tcp': Operation not permitted
# rm: cannot remove '/proc/4539/net/udp': Operation not permitted
# rm: cannot remove '/proc/4539/net/icmp': Operation not permitted
# rm: cannot remove '/proc/4539/net/igmp': Operation not permitted
# rm: cannot remove '/proc/4539/net/raw6': Operation not permitted
# rm: cannot remove '/proc/4539/net/snmp': Operation not permitted
# rm: cannot remove '/proc/4539/net/stat/rt_cache': Operation not permitted
# rm: cannot remove '/proc/4539/net/stat/synproxy': Operation not permitted
# rm: cannot remove '/proc/4539/net/stat/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/4539/net/tcp6': Operation not permitted
# rm: cannot remove '/proc/4539/net/udp6': Operation not permitted
# rm: cannot remove '/proc/4539/net/unix': Operation not permitted
# rm: cannot remove '/proc/4539/net/icmp6': Operation not permitted
# rm: cannot remove '/proc/4539/net/igmp6': Operation not permitted
# rm: cannot remove '/proc/4539/net/ptype': Operation not permitted
# rm: cannot remove '/proc/4539/net/route': Operation not permitted
# rm: cannot remove '/proc/4539/net/snmp6': Operation not permitted
# rm: cannot remove '/proc/4539/net/packet': Operation not permitted
# rm: cannot remove '/proc/4539/net/psched': Operation not permitted
# rm: cannot remove '/proc/4539/net/netlink': Operation not permitted
# rm: cannot remove '/proc/4539/net/netstat': Operation not permitted
# rm: cannot remove '/proc/4539/net/rt_acct': Operation not permitted
# rm: cannot remove '/proc/4539/net/udplite': Operation not permitted
# rm: cannot remove '/proc/4539/net/anycast6': Operation not permitted
# rm: cannot remove '/proc/4539/net/fib_trie': Operation not permitted
# rm: cannot remove '/proc/4539/net/if_inet6': Operation not permitted
# rm: cannot remove '/proc/4539/net/mcfilter': Operation not permitted
# rm: cannot remove '/proc/4539/net/rt_cache': Operation not permitted
# rm: cannot remove '/proc/4539/net/sockstat': Operation not permitted
# rm: cannot remove '/proc/4539/net/tls_stat': Operation not permitted
# rm: cannot remove '/proc/4539/net/udplite6': Operation not permitted
# rm: cannot remove '/proc/4539/net/dev_mcast': Operation not permitted
# rm: cannot remove '/proc/4539/net/dev_snmp6/lo': Operation not permitted
# rm: cannot remove '/proc/4539/net/dev_snmp6/eth0': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip_mr_vif': Operation not permitted
# rm: cannot remove '/proc/4539/net/mcfilter6': Operation not permitted
# rm: cannot remove '/proc/4539/net/netfilter/nf_log': Operation not permitted
# rm: cannot remove '/proc/4539/net/netfilter/nfnetlink_log': Operation not permitted
# rm: cannot remove '/proc/4539/net/netfilter/nfnetlink_queue': Operation not permitted
# rm: cannot remove '/proc/4539/net/protocols': Operation not permitted
# rm: cannot remove '/proc/4539/net/rt6_stats': Operation not permitted
# rm: cannot remove '/proc/4539/net/sockstat6': Operation not permitted
# rm: cannot remove '/proc/4539/net/xfrm_stat': Operation not permitted
# rm: cannot remove '/proc/4539/net/ipv6_route': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip_mr_cache': Operation not permitted
# rm: cannot remove '/proc/4539/net/fib_triestat': Operation not permitted
# rm: cannot remove '/proc/4539/net/nf_conntrack': Operation not permitted
# rm: cannot remove '/proc/4539/net/softnet_stat': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip6_flowlabel': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip_tables_names': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip6_tables_names': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip_tables_matches': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip_tables_targets': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip6_tables_matches': Operation not permitted
# rm: cannot remove '/proc/4539/net/ip6_tables_targets': Operation not permitted
# rm: cannot remove '/proc/4539/net/nf_conntrack_expect': Operation not permitted
# rm: cannot remove '/proc/4539/environ': Operation not permitted
# rm: cannot remove '/proc/4539/auxv': Operation not permitted
# rm: cannot remove '/proc/4539/status': Operation not permitted
# rm: cannot remove '/proc/4539/personality': Operation not permitted
# rm: cannot remove '/proc/4539/limits': Operation not permitted
# rm: cannot remove '/proc/4539/timens_offsets': Operation not permitted
# rm: cannot remove '/proc/4539/comm': Operation not permitted
# rm: cannot remove '/proc/4539/syscall': Operation not permitted
# rm: cannot remove '/proc/4539/cmdline': Operation not permitted
# rm: cannot remove '/proc/4539/stat': Operation not permitted
# rm: cannot remove '/proc/4539/statm': Operation not permitted
# rm: cannot remove '/proc/4539/maps': Operation not permitted
# rm: cannot remove '/proc/4539/numa_maps': Operation not permitted
# rm: cannot remove '/proc/4539/mem': Operation not permitted
# rm: cannot remove '/proc/4539/cwd': Operation not permitted
# rm: cannot remove '/proc/4539/root': Operation not permitted
# rm: cannot remove '/proc/4539/exe': Operation not permitted
# rm: cannot remove '/proc/4539/mounts': Operation not permitted
# rm: cannot remove '/proc/4539/mountinfo': Operation not permitted
# rm: cannot remove '/proc/4539/mountstats': Operation not permitted
# rm: cannot remove '/proc/4539/clear_refs': Operation not permitted
# rm: cannot remove '/proc/4539/smaps': Operation not permitted
# rm: cannot remove '/proc/4539/smaps_rollup': Operation not permitted
# rm: cannot remove '/proc/4539/pagemap': Operation not permitted
# rm: cannot remove '/proc/4539/attr/current': Operation not permitted
# rm: cannot remove '/proc/4539/attr/prev': Operation not permitted
# rm: cannot remove '/proc/4539/attr/exec': Operation not permitted
# rm: cannot remove '/proc/4539/attr/fscreate': Operation not permitted
# rm: cannot remove '/proc/4539/attr/keycreate': Operation not permitted
# rm: cannot remove '/proc/4539/attr/sockcreate': Operation not permitted
# rm: cannot remove '/proc/4539/attr/apparmor/current': Operation not permitted
# rm: cannot remove '/proc/4539/attr/apparmor/prev': Operation not permitted
# rm: cannot remove '/proc/4539/attr/apparmor/exec': Operation not permitted
# rm: cannot remove '/proc/4539/wchan': Operation not permitted
# rm: cannot remove '/proc/4539/stack': Operation not permitted
# rm: cannot remove '/proc/4539/schedstat': Operation not permitted
# rm: cannot remove '/proc/4539/cpuset': Operation not permitted
# rm: cannot remove '/proc/4539/cgroup': Operation not permitted
# rm: cannot remove '/proc/4539/oom_score': Operation not permitted
# rm: cannot remove '/proc/4539/oom_adj': Operation not permitted
# rm: cannot remove '/proc/4539/oom_score_adj': Operation not permitted
# rm: cannot remove '/proc/4539/loginuid': Operation not permitted
# rm: cannot remove '/proc/4539/sessionid': Operation not permitted
# rm: cannot remove '/proc/4539/coredump_filter': Operation not permitted
# rm: cannot remove '/proc/4539/io': Operation not permitted
# rm: cannot remove '/proc/4539/uid_map': Operation not permitted
# rm: cannot remove '/proc/4539/gid_map': Operation not permitted
# rm: cannot remove '/proc/4539/projid_map': Operation not permitted
# rm: cannot remove '/proc/4539/setgroups': Operation not permitted
# rm: cannot remove '/proc/4539/timers': Operation not permitted
# rm: cannot remove '/proc/4539/timerslack_ns': Operation not permitted
# rm: cannot remove '/proc/4539/arch_status': Operation not permitted
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.events': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.events': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/io.pressure': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.procs': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.events.local': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.swap.peak': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.swap.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.swap.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.weight': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.swap.events': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.max.descendants': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.weight.nice': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.pressure': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/pids.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/pids.events': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.low': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.pressure': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.type': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.events.local': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/rdma.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.swap.high': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.rsvd.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.idle': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.stat.local': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.rsvd.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/rdma.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.events': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.threads': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.numa_stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.kill': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.rsvd.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.peak': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpuset.cpus.partition': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpuset.cpus.effective': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.freeze': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.numa_stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.min': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.max.burst': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.controllers': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpu.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.numa_stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.events.local': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.oom.group': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpuset.mems': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.high': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/pids.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpuset.mems.effective': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.subtree_control': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/io.max': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.events': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.1GB.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.rsvd.current': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cpuset.cpus': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/memory.reclaim': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/pids.peak': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.max.depth': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/cgroup.pressure': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/io.stat': Read-only file system
# rm: cannot remove '/var/colab/cgroup/jupyter-children/hugetlb.2MB.max': Read-only file system
# rm: cannot remove '/dev/shm': Device or resource busy
# rm: cannot remove '/dev/mqueue': Device or resource busy
# rm: cannot remove '/dev/pts/0': Operation not permitted
# rm: cannot remove '/dev/pts/ptmx': Operation not permitted

# %%
ls -l -a
# Out:
# total 16
# drwxr-xr-x 1 root root 4096 Jan 16 14:24 ./
# drwxr-xr-x 1 root root 4096 Jan 23 18:31 ../
# drwxr-xr-x 4 root root 4096 Jan 16 14:24 .config/
# drwxr-xr-x 1 root root 4096 Jan 16 14:24 sample_data/

# %%
pwd
# Out:
# '/content'

# %%
cd sample_data
# Out:
# /content/sample_data

# %%
pwd
# Out:
# '/content/sample_data'

# %%
# !ls -l -a
# Out:
# total 55512
# drwxr-xr-x 1 root root     4096 Jan 16 14:24 .
# drwxr-xr-x 1 root root     4096 Jan 16 14:24 ..
# -rwxr-xr-x 1 root root     1697 Jan  1  2000 anscombe.json
# -rw-r--r-- 1 root root   301141 Jan 16 14:24 california_housing_test.csv
# -rw-r--r-- 1 root root  1706430 Jan 16 14:24 california_housing_train.csv
# -rw-r--r-- 1 root root 18289443 Jan 16 14:24 mnist_test.csv
# -rw-r--r-- 1 root root 36523880 Jan 16 14:24 mnist_train_small.csv
# -rwxr-xr-x 1 root root      962 Jan  1  2000 README.md

# %%
# !pwd
# Out:
# /content/sample_data

# %%
# !ps faux | cat
# Out:
# USER         PID %CPU %MEM    VSZ   RSS TTY      STAT START   TIME COMMAND
# root          48  0.0  0.0   5804  2168 ?        Ss   18:31   0:00 tail -n +0 -F /root/.config/Google/DriveFS/Logs/drive_fs.txt
# root          40  0.0  0.0   5804  2244 ?        Ss   18:31   0:00 tail -n +0 -F /root/.config/Google/DriveFS/Logs/dpb.txt
# root           1  0.0  0.0    984   556 ?        Ss   18:31   0:00 /sbin/docker-init -- /datalab/run.sh
# root           7  0.7  0.4 1234532 58340 ?       Sl   18:31   0:00 /tools/node/bin/node /datalab/web/app.js
# root          15  0.0  0.0   7372  3512 ?        S    18:31   0:00  \_ /bin/bash -e /usr/local/colab/bin/oom_monitor.sh
# root         537  0.0  0.0   5772  2092 ?        S    18:33   0:00  |   \_ sleep 1
# root          67 23.0  0.0      0     0 ?        Z    18:31   0:22  \_ [python3] <defunct>
# root          68  3.2  0.5  99512 75632 ?        S    18:31   0:03  \_ python3 /usr/local/bin/colab-fileshim.py
# root          89  6.5  1.1 408192 150744 ?       Sl   18:31   0:06  \_ /usr/bin/python3 /usr/local/bin/jupyter-server --debug --transport="ipc" --ip=172.28.0.12 --ServerApp.token= --port=9000 --FileContentsManager.root_dir=/ --FileContentsManager.allow_hidden=True --ServerApp.log_format="|%(levelname)s|%(message)s" --ServerApp.iopub_data_rate_limit=1e10 --MappingKernelManager.root_dir=/content
# root         150  2.2  0.7 660064 99512 ?        Ssl  18:32   0:01  |   \_ /usr/bin/python3 -m colab_kernel_launcher -f /root/.local/share/jupyter/runtime/kernel-f011efa4-4b49-40fe-9149-66706ba0c051.json
# root         538  0.0  0.0   7372  3448 ?        S    18:33   0:00  |       \_ /bin/bash -c ps faux | cat
# root         539  0.0  0.0  10072  3484 ?        R    18:33   0:00  |           \_ ps faux
# root         540  0.0  0.0   5912  1904 ?        S    18:33   0:00  |           \_ cat
# root          90  0.0  0.0 1229552 4852 ?        Sl   18:31   0:00  \_ /usr/local/bin/dap_multiplexer --domain_socket_path=/tmp/debugger_5yc9fwkdb
# root         171  0.1  0.1 1275056 19620 ?       Sl   18:32   0:00  \_ /usr/colab/bin/language_service --lsp_search_dirs=/datalab/web/pyright/typeshed-fallback/stdlib,/usr/local/lib/python3.10/dist-packages --language_services_request_root_url=http://172.28.0.1:8013/ --language_services_request_timeout=30s -- node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:e823e8ed80e6eba792fd77ee10f401c1fc252bc1a2
# root         177  6.6  1.5 1721584 211280 ?      Sl   18:32   0:05  |   \_ node /datalab/web/pyright/pyright-langserver.js --stdio --cancellationReceive=file:e823e8ed80e6eba792fd77ee10f401c1fc252bc1a2
# root         244  0.0  0.0   8316  4116 pts/0    Ss+  18:32   0:00  \_ tmux new-session -A -D -s 0
# root          17  0.0  0.0   7372  1880 ?        S    18:31   0:00 /bin/bash -e /datalab/run.sh
# root          18  0.0  0.1 1270828 15172 ?       Sl   18:31   0:00  \_ /usr/colab/bin/kernel_manager_proxy --listen_port=6000 --target_port=9000 --logtostderr --listen_host=172.28.0.12 --target_host=172.28.0.12 --tunnel_background_save_url=https://colab.research.google.com/tun/m/cc48301118ce562b961b3c22d803539adc1e0c19/m-s-3ggw24m7ruapl --tunnel_background_save_delay=10s --tunnel_periodic_background_save_frequency=30m0s --enable_output_coalescing=true --output_coalescing_required=true
# root         247  0.0  0.0   8716  3952 ?        Ss   18:32   0:00 tmux new-session -A -D -s 0
# root         248  0.0  0.0   7636  4372 pts/1    Ss+  18:32   0:00  \_ -bash

# %%
# !id
# Out:
# uid=0(root) gid=0(root) groups=0(root)

# %%
# !whoami
# Out:
# root

# %%
! find /etc | cat -n
# Out:
#      1	/etc
#      2	/etc/sysctl.d
#      3	/etc/sysctl.d/10-magic-sysrq.conf
#      4	/etc/sysctl.d/README.sysctl
#      5	/etc/sysctl.d/10-zeropage.conf
#      6	/etc/sysctl.d/10-network-security.conf
#      7	/etc/sysctl.d/10-console-messages.conf
#      8	/etc/sysctl.d/10-ptrace.conf
#      9	/etc/sysctl.d/10-kernel-hardening.conf
#     10	/etc/sysctl.d/10-ipv6-privacy.conf
#     11	/etc/sysctl.d/99-sysctl.conf
#     12	/etc/shells
#     13	/etc/os-release
#     14	/etc/rc5.d
#     15	/etc/rc5.d/S01rsync
#     16	/etc/rc5.d/S01dbus
#     17	/etc/netconfig
#     18	/etc/alternatives
#     19	/etc/alternatives/README
#     20	/etc/alternatives/rmt
#     21	/etc/alternatives/pager
#     22	/etc/alternatives/which
#     23	/etc/alternatives/nawk
#     24	/etc/alternatives/awk
#     25	/etc/alternatives/ex.ja.1.gz
#     26	/etc/alternatives/rename
#     27	/etc/alternatives/aclocal.1.gz
#     28	/etc/alternatives/libmpi.so-x86_64-linux-gnu
#     29	/etc/alternatives/vimdiff
#     30	/etc/alternatives/view.pl.1.gz
#     31	/etc/alternatives/ex.ru.1.gz
#     32	/etc/alternatives/mpifort
#     33	/etc/alternatives/jdb
#     34	/etc/alternatives/lzmore
#     35	/etc/alternatives/mpifort.1.gz
#     36	/etc/alternatives/python3
#     37	/etc/alternatives/jarsigner
#     38	/etc/alternatives/jdeps
#     39	/etc/alternatives/rsh.1.gz
#     40	/etc/alternatives/jlink.1.gz
#     41	/etc/alternatives/liblapack.so.3-x86_64-linux-gnu
#     42	/etc/alternatives/liblapack64.so.3-x86_64-linux-gnu
#     43	/etc/alternatives/f77.1.gz
#     44	/etc/alternatives/liblapack.a-x86_64-linux-gnu
#     45	/etc/alternatives/c99
#     46	/etc/alternatives/cblas.h-x86_64-linux-gnu
#     47	/etc/alternatives/ex.fr.1.gz
#     48	/etc/alternatives/lzcat.1.gz
#     49	/etc/alternatives/jstat.1.gz
#     50	/etc/alternatives/write.1.gz
#     51	/etc/alternatives/mpicxx.1.gz
#     52	/etc/alternatives/rview
#     53	/etc/alternatives/mpi
#     54	/etc/alternatives/open
#     55	/etc/alternatives/serialver
#     56	/etc/alternatives/mpi-fort.pc-x86_64-linux-gnu
#     57	/etc/alternatives/lzfgrep
#     58	/etc/alternatives/mpiexec
#     59	/etc/alternatives/automake.1.gz
#     60	/etc/alternatives/jps
#     61	/etc/alternatives/lzdiff
#     62	/etc/alternatives/jpackage
#     63	/etc/alternatives/lapack64.pc-x86_64-linux-gnu
#     64	/etc/alternatives/jps.1.gz
#     65	/etc/alternatives/mpif77
#     66	/etc/alternatives/mpi-cxx.pc-x86_64-linux-gnu
#     67	/etc/alternatives/libopenblas.a-x86_64-linux-gnu
#     68	/etc/alternatives/aclocal
#     69	/etc/alternatives/javadoc
#     70	/etc/alternatives/lzcmp
#     71	/etc/alternatives/rlogin.1.gz
#     72	/etc/alternatives/javac
#     73	/etc/alternatives/view.1.gz
#     74	/etc/alternatives/cpp
#     75	/etc/alternatives/java
#     76	/etc/alternatives/unlzma
#     77	/etc/alternatives/editor.da.1.gz
#     78	/etc/alternatives/jstat
#     79	/etc/alternatives/rmiregistry
#     80	/etc/alternatives/editor.de.1.gz
#     81	/etc/alternatives/blas64.pc-x86_64-linux-gnu
#     82	/etc/alternatives/javap.1.gz
#     83	/etc/alternatives/java.1.gz
#     84	/etc/alternatives/jshell
#     85	/etc/alternatives/jrunscript
#     86	/etc/alternatives/editor.ja.1.gz
#     87	/etc/alternatives/mpic++
#     88	/etc/alternatives/jstatd
#     89	/etc/alternatives/blas.pc-x86_64-linux-gnu
#     90	/etc/alternatives/jdeprscan
#     91	/etc/alternatives/lzfgrep.1.gz
#     92	/etc/alternatives/liblapack.so-x86_64-linux-gnu
#     93	/etc/alternatives/vi.pl.1.gz
#     94	/etc/alternatives/libopenblas.so.0-x86_64-linux-gnu
#     95	/etc/alternatives/vi.it.1.gz
#     96	/etc/alternatives/vi.fr.1.gz
#     97	/etc/alternatives/jstack
#     98	/etc/alternatives/keytool
#     99	/etc/alternatives/cc.1.gz
#    100	/etc/alternatives/rvim
#    101	/etc/alternatives/editor.pl.1.gz
#    102	/etc/alternatives/lzma
#    103	/etc/alternatives/unlzma.1.gz
#    104	/etc/alternatives/rlogin
#    105	/etc/alternatives/view.ja.1.gz
#    106	/etc/alternatives/jhsdb
#    107	/etc/alternatives/vi.1.gz
#    108	/etc/alternatives/lapack.pc-x86_64-linux-gnu
#    109	/etc/alternatives/ex
#    110	/etc/alternatives/jinfo
#    111	/etc/alternatives/c++
#    112	/etc/alternatives/rmiregistry.1.gz
#    113	/etc/alternatives/jmap.1.gz
#    114	/etc/alternatives/mpirun
#    115	/etc/alternatives/editor.1.gz
#    116	/etc/alternatives/jdeps.1.gz
#    117	/etc/alternatives/vim
#    118	/etc/alternatives/vi.de.1.gz
#    119	/etc/alternatives/jshell.1.gz
#    120	/etc/alternatives/javac.1.gz
#    121	/etc/alternatives/jexec
#    122	/etc/alternatives/jar.1.gz
#    123	/etc/alternatives/view.it.1.gz
#    124	/etc/alternatives/mpi.pc-x86_64-linux-gnu
#    125	/etc/alternatives/my.cnf
#    126	/etc/alternatives/vi.da.1.gz
#    127	/etc/alternatives/liblapack64.so-x86_64-linux-gnu
#    128	/etc/alternatives/rcp.1.gz
#    129	/etc/alternatives/jarsigner.1.gz
#    130	/etc/alternatives/mpirun.1.gz
#    131	/etc/alternatives/unrar.1.gz
#    132	/etc/alternatives/ex.pl.1.gz
#    133	/etc/alternatives/jpackage.1.gz
#    134	/etc/alternatives/jcmd.1.gz
#    135	/etc/alternatives/vi.ru.1.gz
#    136	/etc/alternatives/view.de.1.gz
#    137	/etc/alternatives/cblas-openblas.h-x86_64-linux-gnu
#    138	/etc/alternatives/jcmd
#    139	/etc/alternatives/mpiCC.1.gz
#    140	/etc/alternatives/cc
#    141	/etc/alternatives/lzma.1.gz
#    142	/etc/alternatives/jmod
#    143	/etc/alternatives/jmod.1.gz
#    144	/etc/alternatives/editor.it.1.gz
#    145	/etc/alternatives/mpif77.1.gz
#    146	/etc/alternatives/f95.1.gz
#    147	/etc/alternatives/view.da.1.gz
#    148	/etc/alternatives/vi.ja.1.gz
#    149	/etc/alternatives/ex.1.gz
#    150	/etc/alternatives/jexec-binfmt
#    151	/etc/alternatives/editor.ru.1.gz
#    152	/etc/alternatives/mpif90
#    153	/etc/alternatives/libblas64.so-x86_64-linux-gnu
#    154	/etc/alternatives/mpif90.1.gz
#    155	/etc/alternatives/editor
#    156	/etc/alternatives/libpsm_infinipath.so.1
#    157	/etc/alternatives/x-cursor-theme
#    158	/etc/alternatives/unrar
#    159	/etc/alternatives/jfr.1.gz
#    160	/etc/alternatives/f77blas.h-x86_64-linux-gnu
#    161	/etc/alternatives/jrunscript.1.gz
#    162	/etc/alternatives/lzcmp.1.gz
#    163	/etc/alternatives/mpic++.1.gz
#    164	/etc/alternatives/view.ru.1.gz
#    165	/etc/alternatives/lzless.1.gz
#    166	/etc/alternatives/libblas.a-x86_64-linux-gnu
#    167	/etc/alternatives/editor.fr.1.gz
#    168	/etc/alternatives/mpiexec.1.gz
#    169	/etc/alternatives/jstatd.1.gz
#    170	/etc/alternatives/open.1.gz
#    171	/etc/alternatives/rsh
#    172	/etc/alternatives/jinfo.1.gz
#    173	/etc/alternatives/lzegrep.1.gz
#    174	/etc/alternatives/lzgrep
#    175	/etc/alternatives/ex.de.1.gz
#    176	/etc/alternatives/mpiCC
#    177	/etc/alternatives/serialver.1.gz
#    178	/etc/alternatives/c++.1.gz
#    179	/etc/alternatives/jstack.1.gz
#    180	/etc/alternatives/rename.1.gz
#    181	/etc/alternatives/javap
#    182	/etc/alternatives/c89.1.gz
#    183	/etc/alternatives/lzless
#    184	/etc/alternatives/javadoc.1.gz
#    185	/etc/alternatives/c99.1.gz
#    186	/etc/alternatives/view
#    187	/etc/alternatives/vi
#    188	/etc/alternatives/lzcat
#    189	/etc/alternatives/view.fr.1.gz
#    190	/etc/alternatives/cblas64.h-x86_64-linux-gnu
#    191	/etc/alternatives/jdeprscan.1.gz
#    192	/etc/alternatives/f95
#    193	/etc/alternatives/ex.it.1.gz
#    194	/etc/alternatives/jimage
#    195	/etc/alternatives/pager.1.gz
#    196	/etc/alternatives/libblas64.so.3-x86_64-linux-gnu
#    197	/etc/alternatives/jfr
#    198	/etc/alternatives/keytool.1.gz
#    199	/etc/alternatives/jmap
#    200	/etc/alternatives/mpi-c.pc-x86_64-linux-gnu
#    201	/etc/alternatives/lzmore.1.gz
#    202	/etc/alternatives/jhsdb.1.gz
#    203	/etc/alternatives/libopenblas.so-x86_64-linux-gnu
#    204	/etc/alternatives/write
#    205	/etc/alternatives/lzdiff.1.gz
#    206	/etc/alternatives/libblas.so.3-x86_64-linux-gnu
#    207	/etc/alternatives/jdb.1.gz
#    208	/etc/alternatives/mpicxx
#    209	/etc/alternatives/lzgrep.1.gz
#    210	/etc/alternatives/automake
#    211	/etc/alternatives/ex.da.1.gz
#    212	/etc/alternatives/f77
#    213	/etc/alternatives/libblas.so-x86_64-linux-gnu
#    214	/etc/alternatives/libmpi++.so-x86_64-linux-gnu
#    215	/etc/alternatives/rcp
#    216	/etc/alternatives/c89
#    217	/etc/alternatives/openblas.pc-x86_64-linux-gnu
#    218	/etc/alternatives/jlink
#    219	/etc/alternatives/hdf5.pc
#    220	/etc/alternatives/jar
#    221	/etc/alternatives/lzegrep
#    222	/etc/alternatives/openblas_config.h-x86_64-linux-gnu
#    223	/etc/alternatives/mpicc.1.gz
#    224	/etc/alternatives/mpi-x86_64-linux-gnu
#    225	/etc/alternatives/pinentry.1.gz
#    226	/etc/alternatives/pinentry
#    227	/etc/deluser.conf
#    228	/etc/default
#    229	/etc/default/useradd
#    230	/etc/default/rsync
#    231	/etc/default/cacerts
#    232	/etc/default/locale
#    233	/etc/default/dbus
#    234	/etc/subgid
#    235	/etc/host.conf
#    236	/etc/rc3.d
#    237	/etc/rc3.d/S01rsync
#    238	/etc/rc3.d/S01dbus
#    239	/etc/lsb-release
#    240	/etc/security
#    241	/etc/security/namespace.init
#    242	/etc/security/group.conf
#    243	/etc/security/limits.d
#    244	/etc/security/sepermit.conf
#    245	/etc/security/opasswd
#    246	/etc/security/limits.conf
#    247	/etc/security/pam_env.conf
#    248	/etc/security/access.conf
#    249	/etc/security/namespace.d
#    250	/etc/security/namespace.conf
#    251	/etc/security/faillock.conf
#    252	/etc/security/time.conf
#    253	/etc/passwd
#    254	/etc/opt
#    255	/etc/hosts
#    256	/etc/legal
#    257	/etc/dpkg
#    258	/etc/dpkg/dpkg.cfg.d
#    259	/etc/dpkg/dpkg.cfg.d/docker-apt-speedup
#    260	/etc/dpkg/dpkg.cfg.d/pkgconf-hook-config
#    261	/etc/dpkg/dpkg.cfg
#    262	/etc/dpkg/origins
#    263	/etc/dpkg/origins/default
#    264	/etc/dpkg/origins/debian
#    265	/etc/dpkg/origins/ubuntu
#    266	/etc/dpkg/shlibs.override
#    267	/etc/dpkg/shlibs.default
#    268	/etc/subuid
#    269	/etc/gai.conf
#    270	/etc/skel
#    271	/etc/skel/.bash_logout
#    272	/etc/skel/.profile
#    273	/etc/skel/.bashrc
#    274	/etc/systemd
#    275	/etc/systemd/user
#    276	/etc/systemd/user/sockets.target.wants
#    277	/etc/systemd/user/sockets.target.wants/gpg-agent-browser.socket
#    278	/etc/systemd/user/sockets.target.wants/gpg-agent.socket
#    279	/etc/systemd/user/sockets.target.wants/gpg-agent-ssh.socket
#    280	/etc/systemd/user/sockets.target.wants/gpg-agent-extra.socket
#    281	/etc/systemd/user/sockets.target.wants/dirmngr.socket
#    282	/etc/systemd/user/sockets.target.wants/pk-debconf-helper.socket
#    283	/etc/systemd/system
#    284	/etc/systemd/system/timers.target.wants
#    285	/etc/systemd/system/timers.target.wants/dpkg-db-backup.timer
#    286	/etc/systemd/system/timers.target.wants/apt-daily.timer
#    287	/etc/systemd/system/timers.target.wants/e2scrub_all.timer
#    288	/etc/systemd/system/timers.target.wants/motd-news.timer
#    289	/etc/systemd/system/timers.target.wants/fstrim.timer
#    290	/etc/systemd/system/timers.target.wants/apt-daily-upgrade.timer
#    291	/etc/systemd/system/timers.target.wants/man-db.timer
#    292	/etc/systemd/system/multi-user.target.wants
#    293	/etc/systemd/system/multi-user.target.wants/e2scrub_reap.service
#    294	/etc/systemd/system/multi-user.target.wants/remote-fs.target
#    295	/etc/systemd/system/multi-user.target.wants/systemd-resolved.service
#    296	/etc/systemd/system/sudo.service
#    297	/etc/systemd/system/getty.target.wants
#    298	/etc/systemd/system/getty.target.wants/getty@tty1.service
#    299	/etc/systemd/system/dbus-org.freedesktop.resolve1.service
#    300	/etc/systemd/system/sysinit.target.wants
#    301	/etc/systemd/system/sysinit.target.wants/systemd-pstore.service
#    302	/etc/systemd/resolved.conf
#    303	/etc/systemd/user.conf
#    304	/etc/systemd/networkd.conf
#    305	/etc/systemd/pstore.conf
#    306	/etc/systemd/network
#    307	/etc/systemd/logind.conf
#    308	/etc/systemd/system.conf
#    309	/etc/systemd/sleep.conf
#    310	/etc/systemd/journald.conf
#    311	/etc/debconf.conf
#    312	/etc/rmt
#    313	/etc/gss
#    314	/etc/gss/mech.d
#    315	/etc/gshadow
#    316	/etc/adduser.conf
#    317	/etc/profile
#    318	/etc/cloud
#    319	/etc/cloud/build.info
#    320	/etc/shadow
#    321	/etc/rc1.d
#    322	/etc/group
#    323	/etc/issue.net
#    324	/etc/terminfo
#    325	/etc/terminfo/README
#    326	/etc/apt
#    327	/etc/apt/sources.list
#    328	/etc/apt/auth.conf.d
#    329	/etc/apt/apt.conf.d
#    330	/etc/apt/apt.conf.d/docker-gzip-indexes
#    331	/etc/apt/apt.conf.d/01autoremove
#    332	/etc/apt/apt.conf.d/docker-disable-periodic-update
#    333	/etc/apt/apt.conf.d/docker-no-languages
#    334	/etc/apt/apt.conf.d/70debconf
#    335	/etc/apt/apt.conf.d/01-vendor-ubuntu
#    336	/etc/apt/apt.conf.d/docker-autoremove-suggests
#    337	/etc/apt/apt.conf.d/docker-clean
#    338	/etc/apt/apt.conf.d/90assumeyes
#    339	/etc/apt/apt.conf.d/20packagekit
#    340	/etc/apt/sources.list.d
#    341	/etc/apt/sources.list.d/archive_uri-https_r2u_stat_illinois_edu_ubuntu-jammy.list
#    342	/etc/apt/sources.list.d/ubuntugis-ubuntu-ppa-jammy.list
#    343	/etc/apt/sources.list.d/archive_uri-https_cloud_r-project_org_bin_linux_ubuntu-jammy.list
#    344	/etc/apt/sources.list.d/github-cli.list
#    345	/etc/apt/sources.list.d/deadsnakes-ubuntu-ppa-jammy.list
#    346	/etc/apt/trusted.gpg.d
#    347	/etc/apt/trusted.gpg.d/ubuntu-keyring-2012-cdimage.gpg
#    348	/etc/apt/trusted.gpg.d/ubuntu-keyring-2018-archive.gpg
#    349	/etc/apt/trusted.gpg.d/r2u_key.asc
#    350	/etc/apt/trusted.gpg.d/ubuntugis-ubuntu-ppa.gpg
#    351	/etc/apt/trusted.gpg.d/deadsnakes-ubuntu-ppa.gpg~
#    352	/etc/apt/trusted.gpg.d/ubuntugis-ubuntu-ppa.gpg~
#    353	/etc/apt/trusted.gpg.d/deadsnakes-ubuntu-ppa.gpg
#    354	/etc/apt/trusted.gpg.d/cran_ubuntu_key.asc
#    355	/etc/apt/preferences.d
#    356	/etc/apt/keyrings
#    357	/etc/apt/keyrings/githubcli-archive-keyring.gpg
#    358	/etc/nsswitch.conf
#    359	/etc/update-motd.d
#    360	/etc/update-motd.d/60-unminimize
#    361	/etc/update-motd.d/50-motd-news
#    362	/etc/update-motd.d/10-help-text
#    363	/etc/update-motd.d/00-header
#    364	/etc/kernel
#    365	/etc/kernel/postinst.d
#    366	/etc/kernel/install.d
#    367	/etc/issue
#    368	/etc/cron.daily
#    369	/etc/cron.daily/dpkg
#    370	/etc/cron.daily/apt-compat
#    371	/etc/cron.daily/man-db
#    372	/etc/init.d
#    373	/etc/init.d/procps
#    374	/etc/init.d/hwclock.sh
#    375	/etc/init.d/x11-common
#    376	/etc/init.d/rsync
#    377	/etc/init.d/kmod
#    378	/etc/init.d/dbus
#    379	/etc/hostname
#    380	/etc/debian_version
#    381	/etc/rc4.d
#    382	/etc/rc4.d/S01rsync
#    383	/etc/rc4.d/S01dbus
#    384	/etc/machine-id
#    385	/etc/resolv.conf
#    386	/etc/xattr.conf
#    387	/etc/fstab
#    388	/etc/networks
#    389	/etc/profile.d
#    390	/etc/profile.d/01-locale-fix.sh
#    391	/etc/libaudit.conf
#    392	/etc/mke2fs.conf
#    393	/etc/sysctl.conf
#    394	/etc/e2scrub.conf
#    395	/etc/logrotate.d
#    396	/etc/logrotate.d/alternatives
#    397	/etc/logrotate.d/dpkg
#    398	/etc/logrotate.d/apt
#    399	/etc/selinux
#    400	/etc/selinux/semanage.conf
#    401	/etc/pam.conf
#    402	/etc/bash.bashrc
#    403	/etc/ld.so.conf.d
#    404	/etc/ld.so.conf.d/x86_64-linux-gnu.conf
#    405	/etc/ld.so.conf.d/libc.conf
#    406	/etc/ld.so.conf.d/colab.conf
#    407	/etc/rcS.d
#    408	/etc/rcS.d/S01procps
#    409	/etc/rcS.d/S01kmod
#    410	/etc/rcS.d/S01x11-common
#    411	/etc/bindresvport.blacklist
#    412	/etc/rc2.d
#    413	/etc/rc2.d/S01rsync
#    414	/etc/rc2.d/S01dbus
#    415	/etc/rc6.d
#    416	/etc/ld.so.conf
#    417	/etc/.pwd.lock
#    418	/etc/pam.d
#    419	/etc/pam.d/su
#    420	/etc/pam.d/common-session-noninteractive
#    421	/etc/pam.d/other
#    422	/etc/pam.d/passwd
#    423	/etc/pam.d/runuser-l
#    424	/etc/pam.d/common-auth
#    425	/etc/pam.d/newusers
#    426	/etc/pam.d/chsh
#    427	/etc/pam.d/common-account
#    428	/etc/pam.d/chfn
#    429	/etc/pam.d/su-l
#    430	/etc/pam.d/common-password
#    431	/etc/pam.d/chpasswd
#    432	/etc/pam.d/common-session
#    433	/etc/pam.d/runuser
#    434	/etc/pam.d/login
#    435	/etc/pam.d/sudo
#    436	/etc/pam.d/sudo-i
#    437	/etc/pam.d/polkit-1
#    438	/etc/environment
#    439	/etc/login.defs
#    440	/etc/rc0.d
#    441	/etc/ld.so.cache
#    442	/etc/cron.d
#    443	/etc/cron.d/e2scrub_all
#    444	/etc/mtab
#    445	/etc/ipython
#    446	/etc/ipython/ipython_config.py
#    447	/etc/jupyter
#    448	/etc/jupyter/jupyter_server_config.py
#    449	/etc/requirements3.txt
#    450	/etc/requirements.cpu.in
#    451	/etc/requirements.user.in
#    452	/etc/requirements.core.in
#    453	/etc/pip.conf
#    454	/etc/R
#    455	/etc/R/Makeconf
#    456	/etc/R/Renviron
#    457	/etc/R/ldpaths
#    458	/etc/R/repositories
#    459	/etc/R/Rprofile.site
#    460	/etc/R/Renviron.site
#    461	/etc/pulse
#    462	/etc/pulse/client.conf.d
#    463	/etc/pulse/client.conf
#    464	/etc/sudo.conf
#    465	/etc/ca-certificates
#    466	/etc/ca-certificates/update.d
#    467	/etc/ca-certificates/update.d/jks-keystore
#    468	/etc/locale.alias
#    469	/etc/groff
#    470	/etc/groff/man.local
#    471	/etc/groff/mdoc.local
#    472	/etc/libibverbs.d
#    473	/etc/libibverbs.d/mlx5.driver
#    474	/etc/libibverbs.d/efa.driver
#    475	/etc/libibverbs.d/ipathverbs.driver
#    476	/etc/libibverbs.d/cxgb4.driver
#    477	/etc/libibverbs.d/qedr.driver
#    478	/etc/libibverbs.d/bnxt_re.driver
#    479	/etc/libibverbs.d/rxe.driver
#    480	/etc/libibverbs.d/mthca.driver
#    481	/etc/libibverbs.d/hns.driver
#    482	/etc/libibverbs.d/siw.driver
#    483	/etc/libibverbs.d/mlx4.driver
#    484	/etc/libibverbs.d/vmw_pvrdma.driver
#    485	/etc/libibverbs.d/irdma.driver
#    486	/etc/libibverbs.d/ocrdma.driver
#    487	/etc/libibverbs.d/hfi1verbs.driver
#    488	/etc/magic
#    489	/etc/group-
#    490	/etc/openmpi
#    491	/etc/openmpi/openmpi-default-hostfile
#    492	/etc/openmpi/openmpi-totalview.tcl
#    493	/etc/openmpi/openmpi-mca-params.conf
#    494	/etc/fonts
#    495	/etc/fonts/conf.avail
#    496	/etc/fonts/conf.avail/70-no-bitmaps.conf
#    497	/etc/fonts/conf.avail/50-user.conf
#    498	/etc/fonts/conf.avail/10-sub-pixel-vrgb.conf
#    499	/etc/fonts/conf.avail/70-yes-bitmaps.conf
#    500	/etc/fonts/conf.avail/11-lcdfilter-default.conf
#    501	/etc/fonts/conf.avail/10-autohint.conf
#    502	/etc/fonts/conf.avail/10-antialias.conf
#    503	/etc/fonts/conf.avail/25-unhint-nonlatin.conf
#    504	/etc/fonts/conf.avail/11-lcdfilter-light.conf
#    505	/etc/fonts/conf.avail/45-latin.conf
#    506	/etc/fonts/conf.avail/10-sub-pixel-vbgr.conf
#    507	/etc/fonts/conf.avail/10-hinting-none.conf
#    508	/etc/fonts/conf.avail/45-generic.conf
#    509	/etc/fonts/conf.avail/10-hinting-slight.conf
#    510	/etc/fonts/conf.avail/60-generic.conf
#    511	/etc/fonts/conf.avail/51-local.conf
#    512	/etc/fonts/conf.avail/65-fonts-persian.conf
#    513	/etc/fonts/conf.avail/10-sub-pixel-rgb.conf
#    514	/etc/fonts/conf.avail/10-sub-pixel-bgr.conf
#    515	/etc/fonts/conf.avail/60-latin.conf
#    516	/etc/fonts/conf.avail/10-scale-bitmap-fonts.conf
#    517	/etc/fonts/conf.avail/70-force-bitmaps.conf
#    518	/etc/fonts/conf.avail/10-no-sub-pixel.conf
#    519	/etc/fonts/conf.avail/53-monospace-lcd-filter.conf
#    520	/etc/fonts/conf.avail/10-unhinted.conf
#    521	/etc/fonts/conf.avail/65-khmer.conf
#    522	/etc/fonts/conf.avail/90-synthetic.conf
#    523	/etc/fonts/conf.avail/49-sansserif.conf
#    524	/etc/fonts/conf.avail/11-lcdfilter-legacy.conf
#    525	/etc/fonts/conf.avail/30-metric-aliases.conf
#    526	/etc/fonts/conf.avail/40-nonlatin.conf
#    527	/etc/fonts/conf.avail/80-delicious.conf
#    528	/etc/fonts/conf.avail/69-unifont.conf
#    529	/etc/fonts/conf.avail/65-nonlatin.conf
#    530	/etc/fonts/conf.avail/10-hinting-full.conf
#    531	/etc/fonts/conf.avail/10-hinting-medium.conf
#    532	/etc/fonts/conf.avail/20-unhint-small-vera.conf
#    533	/etc/fonts/fonts.conf
#    534	/etc/fonts/conf.d
#    535	/etc/fonts/conf.d/70-no-bitmaps.conf
#    536	/etc/fonts/conf.d/50-user.conf
#    537	/etc/fonts/conf.d/11-lcdfilter-default.conf
#    538	/etc/fonts/conf.d/10-antialias.conf
#    539	/etc/fonts/conf.d/45-latin.conf
#    540	/etc/fonts/conf.d/README
#    541	/etc/fonts/conf.d/45-generic.conf
#    542	/etc/fonts/conf.d/10-hinting-slight.conf
#    543	/etc/fonts/conf.d/60-generic.conf
#    544	/etc/fonts/conf.d/51-local.conf
#    545	/etc/fonts/conf.d/65-fonts-persian.conf
#    546	/etc/fonts/conf.d/60-latin.conf
#    547	/etc/fonts/conf.d/10-scale-bitmap-fonts.conf
#    548	/etc/fonts/conf.d/90-synthetic.conf
#    549	/etc/fonts/conf.d/49-sansserif.conf
#    550	/etc/fonts/conf.d/30-metric-aliases.conf
#    551	/etc/fonts/conf.d/40-nonlatin.conf
#    552	/etc/fonts/conf.d/80-delicious.conf
#    553	/etc/fonts/conf.d/69-unifont.conf
#    554	/etc/fonts/conf.d/65-nonlatin.conf
#    555	/etc/fonts/conf.d/20-unhint-small-vera.conf
#    556	/etc/glvnd
#    557	/etc/glvnd/egl_vendor.d
#    558	/etc/modprobe.d
#    559	/etc/modprobe.d/blacklist.conf
#    560	/etc/modprobe.d/iwlwifi.conf
#    561	/etc/modprobe.d/blacklist-rare-network.conf
#    562	/etc/modprobe.d/blacklist-framebuffer.conf
#    563	/etc/modprobe.d/blacklist-firewire.conf
#    564	/etc/modprobe.d/blacklist-ath_pci.conf
#    565	/etc/perl
#    566	/etc/perl/Net
#    567	/etc/perl/Net/libnet.cfg
#    568	/etc/localtime
#    569	/etc/mysql
#    570	/etc/mysql/my.cnf.fallback
#    571	/etc/mysql/my.cnf
#    572	/etc/mysql/conf.d
#    573	/etc/mysql/conf.d/mysqldump.cnf
#    574	/etc/mysql/conf.d/mysql.cnf
#    575	/etc/ucf.conf
#    576	/etc/hosts.deny
#    577	/etc/dconf
#    578	/etc/dconf/db
#    579	/etc/vim
#    580	/etc/vim/vimrc
#    581	/etc/depmod.d
#    582	/etc/depmod.d/ubuntu.conf
#    583	/etc/gshadow-
#    584	/etc/bash_completion.d
#    585	/etc/bash_completion.d/git-prompt
#    586	/etc/libpaper.d
#    587	/etc/odbc.ini
#    588	/etc/.java
#    589	/etc/.java/.systemPrefs
#    590	/etc/.java/.systemPrefs/.systemRootModFile
#    591	/etc/.java/.systemPrefs/.system.lock
#    592	/etc/mailcap
#    593	/etc/locale.gen
#    594	/etc/openal
#    595	/etc/openal/alsoft.conf
#    596	/etc/gitconfig
#    597	/etc/manpath.config
#    598	/etc/odbcinst.ini
#    599	/etc/python3.12
#    600	/etc/python3.12/sitecustomize.py
#    601	/etc/hosts.allow
#    602	/etc/sudoers
#    603	/etc/magic.mime
#    604	/etc/modules
#    605	/etc/sudoers.d
#    606	/etc/sudoers.d/README
#    607	/etc/emacs
#    608	/etc/emacs/site-start.d
#    609	/etc/emacs/site-start.d/50autoconf.el
#    610	/etc/cron.weekly
#    611	/etc/cron.weekly/man-db
#    612	/etc/sensors3.conf
#    613	/etc/apparmor.d
#    614	/etc/apparmor.d/usr.bin.man
#    615	/etc/apparmor.d/local
#    616	/etc/apparmor.d/local/usr.bin.man
#    617	/etc/libnl-3
#    618	/etc/libnl-3/pktloc
#    619	/etc/libnl-3/classid
#    620	/etc/papersize
#    621	/etc/sudo_logsrvd.conf
#    622	/etc/iproute2
#    623	/etc/iproute2/rt_tables
#    624	/etc/iproute2/rt_protos
#    625	/etc/iproute2/rt_dsfield
#    626	/etc/iproute2/bpf_pinning
#    627	/etc/iproute2/ematch_map
#    628	/etc/iproute2/group
#    629	/etc/iproute2/rt_scopes
#    630	/etc/iproute2/rt_protos.d
#    631	/etc/iproute2/rt_protos.d/README
#    632	/etc/iproute2/rt_realms
#    633	/etc/iproute2/rt_tables.d
#    634	/etc/iproute2/rt_tables.d/README
#    635	/etc/iproute2/nl_protos
#    636	/etc/sensors.d
#    637	/etc/sensors.d/.placeholder
#    638	/etc/ssh
#    639	/etc/ssh/ssh_config.d
#    640	/etc/ssh/ssh_config
#    641	/etc/vdpau_wrapper.cfg
#    642	/etc/ssl
#    643	/etc/ssl/private
#    644	/etc/ssl/openssl.cnf
#    645	/etc/ssl/certs
#    646	/etc/ssl/certs/Certigna_Root_CA.pem
#    647	/etc/ssl/certs/ACCVRAIZ1.pem
#    648	/etc/ssl/certs/Entrust_Root_Certification_Authority_-_G2.pem
#    649	/etc/ssl/certs/e35234b1.0
#    650	/etc/ssl/certs/AC_RAIZ_FNMT-RCM_SERVIDORES_SEGUROS.pem
#    651	/etc/ssl/certs/DigiCert_Assured_ID_Root_CA.pem
#    652	/etc/ssl/certs/HARICA_TLS_RSA_Root_CA_2021.pem
#    653	/etc/ssl/certs/Entrust_Root_Certification_Authority.pem
#    654	/etc/ssl/certs/7f3d5d1d.0
#    655	/etc/ssl/certs/eed8c118.0
#    656	/etc/ssl/certs/626dceaf.0
#    657	/etc/ssl/certs/ef954a4e.0
#    658	/etc/ssl/certs/SSL.com_TLS_ECC_Root_CA_2022.pem
#    659	/etc/ssl/certs/AffirmTrust_Networking.pem
#    660	/etc/ssl/certs/ca6e4ad9.0
#    661	/etc/ssl/certs/ecccd8db.0
#    662	/etc/ssl/certs/Sectigo_Public_Server_Authentication_Root_R46.pem
#    663	/etc/ssl/certs/064e0aa9.0
#    664	/etc/ssl/certs/f387163d.0
#    665	/etc/ssl/certs/QuoVadis_Root_CA_3_G3.pem
#    666	/etc/ssl/certs/Certum_Trusted_Network_CA.pem
#    667	/etc/ssl/certs/e-Szigno_Root_CA_2017.pem
#    668	/etc/ssl/certs/aee5f10d.0
#    669	/etc/ssl/certs/cbf06781.0
#    670	/etc/ssl/certs/D-TRUST_Root_Class_3_CA_2_2009.pem
#    671	/etc/ssl/certs/76faf6c0.0
#    672	/etc/ssl/certs/3bde41ac.0
#    673	/etc/ssl/certs/3fb36b73.0
#    674	/etc/ssl/certs/e73d606e.0
#    675	/etc/ssl/certs/CommScope_Public_Trust_ECC_Root-01.pem
#    676	/etc/ssl/certs/D-TRUST_BR_Root_CA_1_2020.pem
#    677	/etc/ssl/certs/UCA_Extended_Validation_Root.pem
#    678	/etc/ssl/certs/ISRG_Root_X1.pem
#    679	/etc/ssl/certs/9846683b.0
#    680	/etc/ssl/certs/GlobalSign_Root_E46.pem
#    681	/etc/ssl/certs/06dc52d5.0
#    682	/etc/ssl/certs/6b99d060.0
#    683	/etc/ssl/certs/57bcb2da.0
#    684	/etc/ssl/certs/COMODO_ECC_Certification_Authority.pem
#    685	/etc/ssl/certs/f3377b1b.0
#    686	/etc/ssl/certs/GLOBALTRUST_2020.pem
#    687	/etc/ssl/certs/Certum_Trusted_Root_CA.pem
#    688	/etc/ssl/certs/f0c70a8d.0
#    689	/etc/ssl/certs/1d3472b9.0
#    690	/etc/ssl/certs/T-TeleSec_GlobalRoot_Class_2.pem
#    691	/etc/ssl/certs/GlobalSign_ECC_Root_CA_-_R4.pem
#    692	/etc/ssl/certs/0b1b94ef.0
#    693	/etc/ssl/certs/4b718d9b.0
#    694	/etc/ssl/certs/da0cfd1d.0
#    695	/etc/ssl/certs/SwissSign_Gold_CA_-_G2.pem
#    696	/etc/ssl/certs/90c5a3c8.0
#    697	/etc/ssl/certs/54657681.0
#    698	/etc/ssl/certs/d6325660.0
#    699	/etc/ssl/certs/5860aaa6.0
#    700	/etc/ssl/certs/Secure_Global_CA.pem
#    701	/etc/ssl/certs/4fd49c6c.0
#    702	/etc/ssl/certs/COMODO_RSA_Certification_Authority.pem
#    703	/etc/ssl/certs/dc4d6a89.0
#    704	/etc/ssl/certs/USERTrust_ECC_Certification_Authority.pem
#    705	/etc/ssl/certs/GDCA_TrustAUTH_R5_ROOT.pem
#    706	/etc/ssl/certs/GTS_Root_R4.pem
#    707	/etc/ssl/certs/08063a00.0
#    708	/etc/ssl/certs/8f103249.0
#    709	/etc/ssl/certs/a89d74c2.0
#    710	/etc/ssl/certs/ca-certificates.crt
#    711	/etc/ssl/certs/4042bcee.0
#    712	/etc/ssl/certs/Amazon_Root_CA_4.pem
#    713	/etc/ssl/certs/8d86cdd1.0
#    714	/etc/ssl/certs/9d04f354.0
#    715	/etc/ssl/certs/SZAFIR_ROOT_CA2.pem
#    716	/etc/ssl/certs/9c8dfbd4.0
#    717	/etc/ssl/certs/Atos_TrustedRoot_2011.pem
#    718	/etc/ssl/certs/8312c4c1.0
#    719	/etc/ssl/certs/IdenTrust_Public_Sector_Root_CA_1.pem
#    720	/etc/ssl/certs/106f3e4d.0
#    721	/etc/ssl/certs/5f15c80c.0
#    722	/etc/ssl/certs/0f5dc4f3.0
#    723	/etc/ssl/certs/Certum_Trusted_Network_CA_2.pem
#    724	/etc/ssl/certs/9046744a.0
#    725	/etc/ssl/certs/Security_Communication_RootCA2.pem
#    726	/etc/ssl/certs/a94d09e5.0
#    727	/etc/ssl/certs/TrustAsia_Global_Root_CA_G4.pem
#    728	/etc/ssl/certs/CommScope_Public_Trust_RSA_Root-01.pem
#    729	/etc/ssl/certs/DigiCert_Assured_ID_Root_G2.pem
#    730	/etc/ssl/certs/T-TeleSec_GlobalRoot_Class_3.pem
#    731	/etc/ssl/certs/18856ac4.0
#    732	/etc/ssl/certs/NetLock_Arany_=Class_Gold=_Főtanúsítvány.pem
#    733	/etc/ssl/certs/d52c538d.0
#    734	/etc/ssl/certs/8cb5ee0f.0
#    735	/etc/ssl/certs/Microsec_e-Szigno_Root_CA_2009.pem
#    736	/etc/ssl/certs/QuoVadis_Root_CA_2_G3.pem
#    737	/etc/ssl/certs/Go_Daddy_Class_2_CA.pem
#    738	/etc/ssl/certs/Trustwave_Global_Certification_Authority.pem
#    739	/etc/ssl/certs/7a780d93.0
#    740	/etc/ssl/certs/d887a5bb.0
#    741	/etc/ssl/certs/DigiCert_TLS_RSA4096_Root_G5.pem
#    742	/etc/ssl/certs/c01eb047.0
#    743	/etc/ssl/certs/40547a79.0
#    744	/etc/ssl/certs/Buypass_Class_3_Root_CA.pem
#    745	/etc/ssl/certs/ce5e74ef.0
#    746	/etc/ssl/certs/TunTrust_Root_CA.pem
#    747	/etc/ssl/certs/HiPKI_Root_CA_-_G1.pem
#    748	/etc/ssl/certs/CommScope_Public_Trust_RSA_Root-02.pem
#    749	/etc/ssl/certs/GTS_Root_R2.pem
#    750	/etc/ssl/certs/SSL.com_TLS_RSA_Root_CA_2022.pem
#    751	/etc/ssl/certs/Security_Communication_RootCA3.pem
#    752	/etc/ssl/certs/a3418fda.0
#    753	/etc/ssl/certs/b433981b.0
#    754	/etc/ssl/certs/ee64a828.0
#    755	/etc/ssl/certs/emSign_ECC_Root_CA_-_G3.pem
#    756	/etc/ssl/certs/cc450945.0
#    757	/etc/ssl/certs/Starfield_Class_2_CA.pem
#    758	/etc/ssl/certs/QuoVadis_Root_CA_1_G3.pem
#    759	/etc/ssl/certs/Microsoft_RSA_Root_Certificate_Authority_2017.pem
#    760	/etc/ssl/certs/DigiCert_Global_Root_CA.pem
#    761	/etc/ssl/certs/HARICA_TLS_ECC_Root_CA_2021.pem
#    762	/etc/ssl/certs/9b5697b0.0
#    763	/etc/ssl/certs/988a38cb.0
#    764	/etc/ssl/certs/Izenpe.com.pem
#    765	/etc/ssl/certs/e868b802.0
#    766	/etc/ssl/certs/NAVER_Global_Root_Certification_Authority.pem
#    767	/etc/ssl/certs/GlobalSign_Root_R46.pem
#    768	/etc/ssl/certs/1e09d511.0
#    769	/etc/ssl/certs/e113c810.0
#    770	/etc/ssl/certs/certSIGN_Root_CA_G2.pem
#    771	/etc/ssl/certs/9482e63a.0
#    772	/etc/ssl/certs/9f727ac7.0
#    773	/etc/ssl/certs/b1159c4c.0
#    774	/etc/ssl/certs/f30dd6ad.0
#    775	/etc/ssl/certs/607986c7.0
#    776	/etc/ssl/certs/e36a6752.0
#    777	/etc/ssl/certs/09789157.0
#    778	/etc/ssl/certs/CommScope_Public_Trust_ECC_Root-02.pem
#    779	/etc/ssl/certs/CFCA_EV_ROOT.pem
#    780	/etc/ssl/certs/D-TRUST_Root_Class_3_CA_2_EV_2009.pem
#    781	/etc/ssl/certs/SSL.com_EV_Root_Certification_Authority_RSA_R2.pem
#    782	/etc/ssl/certs/14bc7599.0
#    783	/etc/ssl/certs/6fa5da56.0
#    784	/etc/ssl/certs/Certum_EC-384_CA.pem
#    785	/etc/ssl/certs/GlobalSign_Root_CA_-_R6.pem
#    786	/etc/ssl/certs/vTrus_Root_CA.pem
#    787	/etc/ssl/certs/1001acf7.0
#    788	/etc/ssl/certs/vTrus_ECC_Root_CA.pem
#    789	/etc/ssl/certs/Amazon_Root_CA_2.pem
#    790	/etc/ssl/certs/40193066.0
#    791	/etc/ssl/certs/OISTE_WISeKey_Global_Root_GC_CA.pem
#    792	/etc/ssl/certs/5cd81ad7.0
#    793	/etc/ssl/certs/Buypass_Class_2_Root_CA.pem
#    794	/etc/ssl/certs/Security_Communication_ECC_RootCA1.pem
#    795	/etc/ssl/certs/Certainly_Root_E1.pem
#    796	/etc/ssl/certs/Entrust.net_Premium_2048_Secure_Server_CA.pem
#    797	/etc/ssl/certs/2b349938.0
#    798	/etc/ssl/certs/AffirmTrust_Premium_ECC.pem
#    799	/etc/ssl/certs/IdenTrust_Commercial_Root_CA_1.pem
#    800	/etc/ssl/certs/Certainly_Root_R1.pem
#    801	/etc/ssl/certs/Trustwave_Global_ECC_P256_Certification_Authority.pem
#    802	/etc/ssl/certs/cd58d51e.0
#    803	/etc/ssl/certs/8d89cda1.0
#    804	/etc/ssl/certs/68dd7389.0
#    805	/etc/ssl/certs/GlobalSign_ECC_Root_CA_-_R5.pem
#    806	/etc/ssl/certs/Entrust_Root_Certification_Authority_-_G4.pem
#    807	/etc/ssl/certs/XRamp_Global_CA_Root.pem
#    808	/etc/ssl/certs/SSL.com_EV_Root_Certification_Authority_ECC.pem
#    809	/etc/ssl/certs/706f604c.0
#    810	/etc/ssl/certs/Autoridad_de_Certificacion_Firmaprofesional_CIF_A62634068.pem
#    811	/etc/ssl/certs/406c9bb1.0
#    812	/etc/ssl/certs/fb717492.0
#    813	/etc/ssl/certs/f51bb24c.0
#    814	/etc/ssl/certs/TrustAsia_Global_Root_CA_G3.pem
#    815	/etc/ssl/certs/DigiCert_Global_Root_G3.pem
#    816	/etc/ssl/certs/9b46e03d.0
#    817	/etc/ssl/certs/773e07ad.0
#    818	/etc/ssl/certs/d4dae3dd.0
#    819	/etc/ssl/certs/f081611a.0
#    820	/etc/ssl/certs/GTS_Root_R1.pem
#    821	/etc/ssl/certs/7719f463.0
#    822	/etc/ssl/certs/AC_RAIZ_FNMT-RCM.pem
#    823	/etc/ssl/certs/DigiCert_Global_Root_G2.pem
#    824	/etc/ssl/certs/feffd413.0
#    825	/etc/ssl/certs/Trustwave_Global_ECC_P384_Certification_Authority.pem
#    826	/etc/ssl/certs/0f6fa695.0
#    827	/etc/ssl/certs/Telia_Root_CA_v2.pem
#    828	/etc/ssl/certs/4f316efb.0
#    829	/etc/ssl/certs/AffirmTrust_Commercial.pem
#    830	/etc/ssl/certs/Amazon_Root_CA_3.pem
#    831	/etc/ssl/certs/Atos_TrustedRoot_Root_CA_ECC_TLS_2021.pem
#    832	/etc/ssl/certs/b7a5b843.0
#    833	/etc/ssl/certs/2923b3f9.0
#    834	/etc/ssl/certs/e8de2f56.0
#    835	/etc/ssl/certs/6d41d539.0
#    836	/etc/ssl/certs/Security_Communication_Root_CA.pem
#    837	/etc/ssl/certs/b66938e9.0
#    838	/etc/ssl/certs/UCA_Global_G2_Root.pem
#    839	/etc/ssl/certs/3513523f.0
#    840	/etc/ssl/certs/Baltimore_CyberTrust_Root.pem
#    841	/etc/ssl/certs/certSIGN_ROOT_CA.pem
#    842	/etc/ssl/certs/fe8a2cd8.0
#    843	/etc/ssl/certs/228f89db.0
#    844	/etc/ssl/certs/USERTrust_RSA_Certification_Authority.pem
#    845	/etc/ssl/certs/75d1b2ed.0
#    846	/etc/ssl/certs/Amazon_Root_CA_1.pem
#    847	/etc/ssl/certs/3e359ba6.0
#    848	/etc/ssl/certs/dd8e9d41.0
#    849	/etc/ssl/certs/7a3adc42.0
#    850	/etc/ssl/certs/emSign_Root_CA_-_G1.pem
#    851	/etc/ssl/certs/2ae6433e.0
#    852	/etc/ssl/certs/Atos_TrustedRoot_Root_CA_RSA_TLS_2021.pem
#    853	/etc/ssl/certs/Sectigo_Public_Server_Authentication_Root_E46.pem
#    854	/etc/ssl/certs/5e98733a.0
#    855	/etc/ssl/certs/Starfield_Root_Certificate_Authority_-_G2.pem
#    856	/etc/ssl/certs/ed858448.0
#    857	/etc/ssl/certs/4bfab552.0
#    858	/etc/ssl/certs/SecureTrust_CA.pem
#    859	/etc/ssl/certs/Hellenic_Academic_and_Research_Institutions_ECC_RootCA_2015.pem
#    860	/etc/ssl/certs/de6d66f3.0
#    861	/etc/ssl/certs/bf53fb88.0
#    862	/etc/ssl/certs/b81b93f0.0
#    863	/etc/ssl/certs/8508e720.0
#    864	/etc/ssl/certs/865fbdf9.0
#    865	/etc/ssl/certs/AffirmTrust_Premium.pem
#    866	/etc/ssl/certs/emSign_Root_CA_-_C1.pem
#    867	/etc/ssl/certs/1e08bfd1.0
#    868	/etc/ssl/certs/BJCA_Global_Root_CA2.pem
#    869	/etc/ssl/certs/DigiCert_High_Assurance_EV_Root_CA.pem
#    870	/etc/ssl/certs/COMODO_Certification_Authority.pem
#    871	/etc/ssl/certs/ISRG_Root_X2.pem
#    872	/etc/ssl/certs/SwissSign_Silver_CA_-_G2.pem
#    873	/etc/ssl/certs/062cdee6.0
#    874	/etc/ssl/certs/b0e59380.0
#    875	/etc/ssl/certs/c28a8a30.0
#    876	/etc/ssl/certs/SSL.com_Root_Certification_Authority_RSA.pem
#    877	/etc/ssl/certs/OISTE_WISeKey_Global_Root_GB_CA.pem
#    878	/etc/ssl/certs/9bf03295.0
#    879	/etc/ssl/certs/f249de83.0
#    880	/etc/ssl/certs/5931b5bc.0
#    881	/etc/ssl/certs/244b5494.0
#    882	/etc/ssl/certs/ff34af3f.0
#    883	/etc/ssl/certs/32888f65.0
#    884	/etc/ssl/certs/SecureSign_RootCA11.pem
#    885	/etc/ssl/certs/Go_Daddy_Root_Certificate_Authority_-_G2.pem
#    886	/etc/ssl/certs/emSign_ECC_Root_CA_-_C3.pem
#    887	/etc/ssl/certs/fc5a8f99.0
#    888	/etc/ssl/certs/5f618aec.0
#    889	/etc/ssl/certs/D-TRUST_EV_Root_CA_1_2020.pem
#    890	/etc/ssl/certs/ANF_Secure_Server_Root_CA.pem
#    891	/etc/ssl/certs/GlobalSign_Root_CA_-_R3.pem
#    892	/etc/ssl/certs/DigiCert_Assured_ID_Root_G3.pem
#    893	/etc/ssl/certs/TeliaSonera_Root_CA_v1.pem
#    894	/etc/ssl/certs/e18bfb83.0
#    895	/etc/ssl/certs/0b9bc432.0
#    896	/etc/ssl/certs/Microsoft_ECC_Root_Certificate_Authority_2017.pem
#    897	/etc/ssl/certs/BJCA_Global_Root_CA1.pem
#    898	/etc/ssl/certs/GlobalSign_Root_CA.pem
#    899	/etc/ssl/certs/5ad8a5d6.0
#    900	/etc/ssl/certs/0179095f.0
#    901	/etc/ssl/certs/Actalis_Authentication_Root_CA.pem
#    902	/etc/ssl/certs/Hellenic_Academic_and_Research_Institutions_RootCA_2015.pem
#    903	/etc/ssl/certs/Certigna.pem
#    904	/etc/ssl/certs/Entrust_Root_Certification_Authority_-_EC1.pem
#    905	/etc/ssl/certs/b727005e.0
#    906	/etc/ssl/certs/Comodo_AAA_Services_root.pem
#    907	/etc/ssl/certs/QuoVadis_Root_CA_2.pem
#    908	/etc/ssl/certs/5443e9e3.0
#    909	/etc/ssl/certs/653b494a.0
#    910	/etc/ssl/certs/TUBITAK_Kamu_SM_SSL_Kok_Sertifikasi_-_Surum_1.pem
#    911	/etc/ssl/certs/fd64f3fc.0
#    912	/etc/ssl/certs/8160b96c.0
#    913	/etc/ssl/certs/02265526.0
#    914	/etc/ssl/certs/1cef98f5.0
#    915	/etc/ssl/certs/QuoVadis_Root_CA_3.pem
#    916	/etc/ssl/certs/002c0b4f.0
#    917	/etc/ssl/certs/CA_Disig_Root_R2.pem
#    918	/etc/ssl/certs/TWCA_Global_Root_CA.pem
#    919	/etc/ssl/certs/DigiCert_Trusted_Root_G4.pem
#    920	/etc/ssl/certs/cd8c0d63.0
#    921	/etc/ssl/certs/48bec511.0
#    922	/etc/ssl/certs/9ef4a08a.0
#    923	/etc/ssl/certs/SSL.com_Root_Certification_Authority_ECC.pem
#    924	/etc/ssl/certs/749e9e03.0
#    925	/etc/ssl/certs/DigiCert_TLS_ECC_P384_Root_G5.pem
#    926	/etc/ssl/certs/d7e8dc79.0
#    927	/etc/ssl/certs/f39fc864.0
#    928	/etc/ssl/certs/fa5da96b.0
#    929	/etc/ssl/certs/93bc0acc.0
#    930	/etc/ssl/certs/ePKI_Root_Certification_Authority.pem
#    931	/etc/ssl/certs/TWCA_Root_Certification_Authority.pem
#    932	/etc/ssl/certs/GTS_Root_R3.pem
#    933	/etc/ssl/certs/81f2d2b1.0
#    934	/etc/ssl/certs/0a775a30.0
#    935	/etc/ssl/certs/Hongkong_Post_Root_CA_3.pem
#    936	/etc/ssl/certs/0bf05006.0
#    937	/etc/ssl/certs/930ac5d2.0
#    938	/etc/ssl/certs/Starfield_Services_Root_Certificate_Authority_-_G2.pem
#    939	/etc/ssl/certs/java
#    940	/etc/ssl/certs/java/cacerts
#    941	/etc/timezone
#    942	/etc/mailcap.order
#    943	/etc/fuse.conf
#    944	/etc/java-17-openjdk
#    945	/etc/java-17-openjdk/net.properties
#    946	/etc/java-17-openjdk/jvm-amd64.cfg
#    947	/etc/java-17-openjdk/security
#    948	/etc/java-17-openjdk/security/java.security
#    949	/etc/java-17-openjdk/security/blocked.certs
#    950	/etc/java-17-openjdk/security/policy
#    951	/etc/java-17-openjdk/security/policy/unlimited
#    952	/etc/java-17-openjdk/security/policy/unlimited/default_US_export.policy
#    953	/etc/java-17-openjdk/security/policy/unlimited/default_local.policy
#    954	/etc/java-17-openjdk/security/policy/README.txt
#    955	/etc/java-17-openjdk/security/policy/limited
#    956	/etc/java-17-openjdk/security/policy/limited/default_US_export.policy
#    957	/etc/java-17-openjdk/security/policy/limited/exempt_local.policy
#    958	/etc/java-17-openjdk/security/policy/limited/default_local.policy
#    959	/etc/java-17-openjdk/security/public_suffix_list.dat
#    960	/etc/java-17-openjdk/security/default.policy
#    961	/etc/java-17-openjdk/security/java.policy
#    962	/etc/java-17-openjdk/security/nss.cfg
#    963	/etc/java-17-openjdk/accessibility.properties
#    964	/etc/java-17-openjdk/swing.properties
#    965	/etc/java-17-openjdk/logging.properties
#    966	/etc/java-17-openjdk/sound.properties
#    967	/etc/java-17-openjdk/jfr
#    968	/etc/java-17-openjdk/jfr/default.jfc
#    969	/etc/java-17-openjdk/jfr/profile.jfc
#    970	/etc/java-17-openjdk/management
#    971	/etc/java-17-openjdk/management/management.properties
#    972	/etc/java-17-openjdk/management/jmxremote.access
#    973	/etc/java-17-openjdk/psfontj2d.properties
#    974	/etc/java-17-openjdk/psfont.properties.ja
#    975	/etc/ODBCDataSources
#    976	/etc/X11
#    977	/etc/X11/Xsession.d
#    978	/etc/X11/Xsession.d/90gpg-agent
#    979	/etc/X11/Xsession.d/60x11-common_xdg_path
#    980	/etc/X11/Xsession.d/30x11-common_xresources
#    981	/etc/X11/Xsession.d/20dbus_xdg-runtime
#    982	/etc/X11/Xsession.d/20x11-common_process-args
#    983	/etc/X11/Xsession.d/50x11-common_determine-startup
#    984	/etc/X11/Xsession.d/99x11-common_start
#    985	/etc/X11/Xsession.d/40x11-common_xsessionrc
#    986	/etc/X11/Xsession.d/35x11-common_xhost-local
#    987	/etc/X11/Xsession.d/90x11-common_ssh-agent
#    988	/etc/X11/rgb.txt
#    989	/etc/X11/xkb
#    990	/etc/X11/Xresources
#    991	/etc/X11/Xresources/x11-common
#    992	/etc/X11/Xreset
#    993	/etc/X11/xorg.conf.d
#    994	/etc/X11/Xreset.d
#    995	/etc/X11/Xreset.d/README
#    996	/etc/X11/Xsession.options
#    997	/etc/X11/Xsession
#    998	/etc/passwd-
#    999	/etc/python3
#   1000	/etc/python3/debian_config
#   1001	/etc/dbus-1
#   1002	/etc/dbus-1/session.d
#   1003	/etc/dbus-1/system.d
#   1004	/etc/dbus-1/system.d/org.freedesktop.PackageKit.conf
#   1005	/etc/dbus-1/system.d/com.ubuntu.SoftwareProperties.conf
#   1006	/etc/binfmt.d
#   1007	/etc/tmpfiles.d
#   1008	/etc/wgetrc
#   1009	/etc/ca-certificates.conf
#   1010	/etc/polkit-1
#   1011	/etc/polkit-1/localauthority
#   1012	/etc/polkit-1/localauthority/20-org.d
#   1013	/etc/polkit-1/localauthority/30-site.d
#   1014	/etc/polkit-1/localauthority/50-local.d
#   1015	/etc/polkit-1/localauthority/10-vendor.d
#   1016	/etc/polkit-1/localauthority/90-mandatory.d
#   1017	/etc/polkit-1/localauthority.conf.d
#   1018	/etc/polkit-1/localauthority.conf.d/50-localauthority.conf
#   1019	/etc/polkit-1/localauthority.conf.d/51-ubuntu-admin.conf
#   1020	/etc/xdg
#   1021	/etc/xdg/systemd
#   1022	/etc/xdg/systemd/user
#   1023	/etc/modules-load.d
#   1024	/etc/modules-load.d/modules.conf
#   1025	/etc/shadow-
#   1026	/etc/PackageKit
#   1027	/etc/PackageKit/PackageKit.conf
#   1028	/etc/PackageKit/Vendor.conf
#   1029	/etc/logcheck
#   1030	/etc/logcheck/ignore.d.server
#   1031	/etc/logcheck/ignore.d.server/gpg-agent
#   1032	/etc/mime.types
#   1033	/etc/inputrc
#   1034	/etc/python3.10
#   1035	/etc/python3.10/sitecustomize.py

# %%
# %cd ..
# Out:
# /content

# %% [markdown]
# ## Sharing your notebooks

# %% [markdown]
# Sharing options are consistent with Google Drive in general.
#
# Sharing Options:
# - Private
# - Public
# - Specific people
# - People with the link
# - If you put something in a shared folder, it will automatically be shared too
#
# However, unlike other Google Drive applications, you cannot ( should not ) run the same notebook more than once at the same time.

# %% [markdown]
# ## Saving your notebooks & revision history

# %% [markdown]
# *   You can save your notebook by going to File -> Save.
# *   File -> Save and Pin Revision will pin the version so it doesn't get deleted from the revision history.
# *   File -> Revision History will show your notebook's revision history. This can be useful if you need to revert back to a previous version of your notebook.
#
# Note: the revision history is NOT copied when you copy a notebook.

# %% [markdown]
# ## Moving your notebooks

# %% [markdown]
# - Demo how to move notebooks in Drive
# - Save somebody else's notebook - File -> Save a copy in Drive.  Default location is `Colab Notebooks`

# %% [markdown]
# ## Saving to GitHub Gist

# %% [markdown]
# File -> Save a copy as a Github Gist

# %% [markdown]
# ## Saving to GitHub

# %% [markdown]
# The GitHub repository must exist first.
#
# File -> Save a copy in Github

# %% [markdown]
# # Sample JupyterLab Notebooks

# %% [markdown]
# [NBViewer](https://nbviewer.jupyter.org/)
#
# [A Gallery of Interesting Jupyter Notebooks]( https://github.com/jupyter/jupyter/wiki )

# %% [markdown]
# # More Info
# [Overview of Colab](https://colab.research.google.com/notebooks/basic_features_overview.ipynb)
# [Python Data Science Handbook - Help and Documentation](https://github.com/jakevdp/PythonDataScienceHandbook/blob/master/notebooks/01.01-Help-And-Documentation.ipynb)
