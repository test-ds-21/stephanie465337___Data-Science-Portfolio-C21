# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/NotebookLM/Module%201/3b_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Pandas Data Frames

# %%
import pandas as pd

# %% [markdown]
# ## Building a data frame

# %%
# We can build a data frame using a dictionary
my_dict = {'dogs' : [1,0,4,3,2],
           'cats' : [3,2,0,1,1]}
my_dict
# Out:
# {'dogs': [1, 0, 4, 3, 2], 'cats': [3, 2, 0, 1, 1]}

# %%
animals = pd.DataFrame(my_dict)
display(animals)
# Out:
#    dogs  cats
# 0     1     3
# 1     0     2
# 2     4     0
# 3     3     1
# 4     2     1

# %%
type(animals)
# Out:
# pandas.core.frame.DataFrame

# %%
animals?

# %%
# fetch second row
animals.iloc[1]
# Out:
# dogs    0
# cats    2
# Name: 1, dtype: int64

# %%
animals.loc[1]
# Out:
# dogs    0
# cats    2
# Name: 1, dtype: int64

# %%
type(animals.iloc[1])
# Out:
# pandas.core.series.Series

# %%
(
  animals
.iloc[2]
.iloc[0]
 )
# Out:
# np.int64(4)

# %%
animals
# Out:
#    dogs  cats
# 0     1     3
# 1     0     2
# 2     4     0
# 3     3     1
# 4     2     1

# %%
# Change the index
animals = pd.DataFrame(my_dict, index = ['Joe', 'Mary', 'Roger', 'David', 'Mikey'])
print(animals)
# Out:
#        dogs  cats
# Joe       1     3
# Mary      0     2
# Roger     4     0
# David     3     1
# Mikey     2     1

# %%
animals.iloc[-1]
# Out:
# dogs    2
# cats    1
# Name: Mikey, dtype: int64

# %%
animals.loc["Mikey"]
# Out:
# dogs    2
# cats    1
# Name: Mikey, dtype: int64

# %% [markdown]
# ### Your Turn
# Create a data frame that looks like the table below. Name this data frame `movies`. Use the `Movie` column as your index.
#
# Movie | Lead Actor | Times Watched
# ------|------------|--------------
# Titanic|Leo DiCaprio|3
# Die Hard|Bruce Willis|5
# Back to the Future | Michael J. Fox | 15
# Forrest Gump | Tom Hanks | NaN
#
# Note: to add a `NaN` to your dataframe, you will need to do the following:
# 1. Run `import numpy as np`
# 2. Use `np.nan` in your dataframe.

# %%
# Solution
import numpy as np

movies_dict = {'Lead Actor' : ['Leo DiCaprio', 'Bruce Willis', 'Michael J. Fox', 'Tom Hanks'],
           'Times Watched' : [3, 5, 15, np.nan]}
movies_dict
# Out:
# {'Lead Actor': ['Leo DiCaprio', 'Bruce Willis', 'Michael J. Fox', 'Tom Hanks'],
#  'Times Watched': [3, 5, 15, nan]}

# %%
movies = pd.DataFrame(movies_dict, index = ('Titanic', 'Die Hard', 'Back to the Future', 'Forrest Gump'))
movies
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %% [markdown]
# ## Creating a data frame by reading in a CSV

# %%
# Read in CSV
url = "http://ddc-datascience.s3.amazonaws.com/Home_Data.csv"
home_data = pd.read_csv(url, usecols=range(9))

# Look at first 5 rows
home_data.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour
# 0         Lvl
# 1         Lvl
# 2         Lvl
# 3         Lvl
# 4         Lvl

# %% [markdown]
# ## Viewing/Understanding Data

# %%
# View the first 5 rows
home_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour
# 0         Lvl
# 1         Lvl
# 2         Lvl
# 3         Lvl
# 4         Lvl

# %%
home_data.tail()
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
#      LandContour
# 1455         Lvl
# 1456         Lvl
# 1457         Lvl
# 1458         Lvl
# 1459         Lvl

# %%
# See the dimension of your data frame
home_data.shape
# Out:
# (1460, 9)

# %%
# See the information about each column in your data frame
home_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 9 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Id           1460 non-null   int64
#  1   MSSubClass   1460 non-null   int64
#  2   MSZoning     1460 non-null   object
#  3   LotFrontage  1201 non-null   float64
#  4   LotArea      1460 non-null   int64
#  5   Street       1460 non-null   object
#  6   Alley        91 non-null     object
#  7   LotShape     1460 non-null   object
#  8   LandContour  1460 non-null   object
# dtypes: float64(1), int64(3), object(5)
# memory usage: 102.8+ KB

# %%
# Get summary statistics about your data frame
home_data.describe(include = "all" )
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
#        Alley LotShape LandContour
# count     91     1460        1460
# unique     2        4           4
# top     Grvl      Reg         Lvl
# freq      50      925        1311
# mean     NaN      NaN         NaN
# std      NaN      NaN         NaN
# min      NaN      NaN         NaN
# 25%      NaN      NaN         NaN
# 50%      NaN      NaN         NaN
# 75%      NaN      NaN         NaN
# max      NaN      NaN         NaN

# %%
# See the names of the columns
home_data.columns
# Out:
# Index(['Id', 'MSSubClass', 'MSZoning', 'LotFrontage', 'LotArea', 'Street',
#        'Alley', 'LotShape', 'LandContour'],
#       dtype='object')

# %%
home_data.columns.to_list()
# Out:
# ['Id',
#  'MSSubClass',
#  'MSZoning',
#  'LotFrontage',
#  'LotArea',
#  'Street',
#  'Alley',
#  'LotShape',
#  'LandContour']

# %% [markdown]
# ### Your Turn
# 1. Use the `info()` and `describe()` methods on `movies` data frame.
# 2. Find another method that can be used on dataframes. Look at the help documentation for that method. Write a brief description of what that method does.

# %%
# Solution
movies.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4 entries, Titanic to Forrest Gump
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Lead Actor     4 non-null      object
#  1   Times Watched  3 non-null      float64
# dtypes: float64(1), object(1)
# memory usage: 268.0+ bytes

# %%
# Solution
movies.describe()
# Out:
#        Times Watched
# count       3.000000
# mean        7.666667
# std         6.429101
# min         3.000000
# 25%         4.000000
# 50%         5.000000
# 75%        10.000000
# max        15.000000

# %%
# Solution
movies.applymap
# Out:
# <bound method DataFrame.applymap of                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN>

# %%
# Solution
movies.map
# Out:
# <bound method DataFrame.map of                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN>

# %%
movies.at_time
# Out:
# <bound method NDFrame.at_time of                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN>

# %% [markdown]
# ## Cleaning Data

# %%
home_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour
# 0         Lvl
# 1         Lvl
# 2         Lvl
# 3         Lvl
# 4         Lvl

# %%
# Dealing with Missing Values
home_data.isnull().head()
# Out:
#       Id  MSSubClass  MSZoning  LotFrontage  LotArea  Street  Alley  LotShape  \
# 0  False       False     False        False    False   False   True     False
# 1  False       False     False        False    False   False   True     False
# 2  False       False     False        False    False   False   True     False
# 3  False       False     False        False    False   False   True     False
# 4  False       False     False        False    False   False   True     False
#
#    LandContour
# 0        False
# 1        False
# 2        False
# 3        False
# 4        False

# %%
home_data.isnull().sum()
# Out:
# Id                0
# MSSubClass        0
# MSZoning          0
# LotFrontage     259
# LotArea           0
# Street            0
# Alley          1369
# LotShape          0
# LandContour       0
# dtype: int64

# %%
# Let's drop the columns with NaNs.
# First, we need to create a copy of our data frame
home_data_clean = home_data.copy()
home_data_clean.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour
# 0         Lvl
# 1         Lvl
# 2         Lvl
# 3         Lvl
# 4         Lvl

# %%
# axis = 1 tells the function to drop a column instead of a row
# in place tells the function to alter home_data_clean instead of returning a new data frame
# home_data_clean.dropna(axis = "columns", inplace=True)
home_data_clean.dropna(axis = 1, inplace=True)
home_data_clean.head()
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour
# 0   1          60       RL     8450   Pave      Reg         Lvl
# 1   2          20       RL     9600   Pave      Reg         Lvl
# 2   3          60       RL    11250   Pave      IR1         Lvl
# 3   4          70       RL     9550   Pave      IR1         Lvl
# 4   5          60       RL    14260   Pave      IR1         Lvl

# %%
home_data.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour
# 0         Lvl
# 1         Lvl
# 2         Lvl
# 3         Lvl
# 4         Lvl

# %% [markdown]
# ### Your Turn
# Make a copy of your `movies` data frame. Save it as `movies_clean`.
# Drop the **row** that contains a NaN.

# %%
# Solution
movies_clean = movies.copy()
movies_clean.head()
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
# Solution
movies_clean.dropna(axis = 'rows', inplace=True)
#movies_clean.dropna(axis = , inplace=True)
movies_clean.head()
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0

# %% [markdown]
# ## Imputation
# Let's say we didn't want to just drop the LotFrontage column as it only had 259 NaNs.

# %%
# Make a copy
home_data_impute = home_data.copy()
home_data_impute.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour
# 0         Lvl
# 1         Lvl
# 2         Lvl
# 3         Lvl
# 4         Lvl

# %%
# Remove only the Alley column
# home_data_impute.drop(labels ='Alley', axis = "columns", inplace = True)
home_data_impute.drop(labels ='Alley', axis = 1, inplace = True)
home_data_impute.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street LotShape LandContour
# 0   1          60       RL         65.0     8450   Pave      Reg         Lvl
# 1   2          20       RL         80.0     9600   Pave      Reg         Lvl
# 2   3          60       RL         68.0    11250   Pave      IR1         Lvl
# 3   4          70       RL         60.0     9550   Pave      IR1         Lvl
# 4   5          60       RL         84.0    14260   Pave      IR1         Lvl

# %%
# Check to see our NaNs
home_data_impute.isnull().sum().sort_values()
# Out:
# Id               0
# MSSubClass       0
# MSZoning         0
# LotArea          0
# LotShape         0
# Street           0
# LandContour      0
# LotFrontage    259
# dtype: int64

# %%
home_data_impute['LotFrontage']
# Out:
# 0       65.0
# 1       80.0
# 2       68.0
# 3       60.0
# 4       84.0
#         ...
# 1455    62.0
# 1456    85.0
# 1457    66.0
# 1458    68.0
# 1459    75.0
# Name: LotFrontage, Length: 1460, dtype: float64

# %%
# Replace the NaNs in LotFrontage with the mean lot frontage amount
lot_frontage_mean = home_data_impute['LotFrontage'].mean()
lot_frontage_mean
# Out:
# np.float64(70.04995836802665)

# %%
home_data_impute.fillna(lot_frontage_mean, inplace = True)
home_data_impute.isnull().sum()
# Out:
# Id             0
# MSSubClass     0
# MSZoning       0
# LotFrontage    0
# LotArea        0
# Street         0
# LotShape       0
# LandContour    0
# dtype: int64

# %%
home_data_impute.describe( include = "all")
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1460.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    22.024023    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    60.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    70.049958    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    79.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
#        LotShape LandContour
# count      1460        1460
# unique        4           4
# top         Reg         Lvl
# freq        925        1311
# mean        NaN         NaN
# std         NaN         NaN
# min         NaN         NaN
# 25%         NaN         NaN
# 50%         NaN         NaN
# 75%         NaN         NaN
# max         NaN         NaN

# %% [markdown]
# ### Your Turn
# Make another copy of your original `movies` data frame and save it as `movies_impute`. Replace the NaN with a 0.

# %%
# Solution
movies_impute = movies.copy()
movies_impute.head()
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
movies_impute.isnull().sum().sort_values()
# Out:
# Lead Actor       0
# Times Watched    1
# dtype: int64

# %%
movies_impute['Times Watched']
# Out:
# Titanic                3.0
# Die Hard               5.0
# Back to the Future    15.0
# Forrest Gump           NaN
# Name: Times Watched, dtype: float64

# %%
times_watched_mean = movies_impute['Times Watched'].mean()
times_watched_mean
# Out:
# np.float64(7.666666666666667)

# %%
movies_impute.fillna(0, inplace = True)
movies_impute.isnull().sum()
# Out:
# Lead Actor       0
# Times Watched    0
# dtype: int64

# %% [markdown]
# ## Indexing by Column

# %%
# We can index a column using square brackets and the column name
street_col = home_data_impute['Street']
street_col.head()
# Out:
# 0    Pave
# 1    Pave
# 2    Pave
# 3    Pave
# 4    Pave
# Name: Street, dtype: object

# %%
type(street_col)
# Out:
# pandas.core.series.Series

# %%
# We can index multiple columns using a list of column names
multiple_cols = home_data_impute[['Street', 'LotShape']]
multiple_cols.head()
# Out:
#   Street LotShape
# 0   Pave      Reg
# 1   Pave      Reg
# 2   Pave      IR1
# 3   Pave      IR1
# 4   Pave      IR1

# %%
type(multiple_cols)
# Out:
# pandas.core.frame.DataFrame

# %%
street_col = home_data_impute[['Street']]
street_col.head()
# Out:
#   Street
# 0   Pave
# 1   Pave
# 2   Pave
# 3   Pave
# 4   Pave

# %%
type(street_col)
# Out:
# pandas.core.frame.DataFrame

# %% [markdown]
# ### Your Turn
# Index the `Lead Actor` column of your `movies_impute` data frame. Save it to a variable called `actors`. Print out `actors`. Also, display the data type of `actors`.

# %%
# Solution
movies_impute = movies.copy()
movies_impute.head()
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
actors = movies_impute['Lead Actor'] #[] is a Series
actors
# Out:
# Titanic                 Leo DiCaprio
# Die Hard                Bruce Willis
# Back to the Future    Michael J. Fox
# Forrest Gump               Tom Hanks
# Name: Lead Actor, dtype: object

# %%
type(actors)
# Out:
# pandas.core.series.Series

# %%
actors = movies_impute[['Lead Actor']] #[[]] is a DataFrame
actors
# Out:
#                         Lead Actor
# Titanic               Leo DiCaprio
# Die Hard              Bruce Willis
# Back to the Future  Michael J. Fox
# Forrest Gump             Tom Hanks

# %%
type(actors)
# Out:
# pandas.core.frame.DataFrame

# %%
# Solution
movies_impute.dropna(axis = 'rows', inplace=True)
#movies_clean.dropna(axis = , inplace=True)
movies_impute.head()
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0

# %% [markdown]
# ## Indexing by Row
# We can index rows in two ways:
#
# - .loc - locates by name
# - .iloc- locates by numerical index

# %%
# Let's take a look at the animals data frame we created earlier
animals
# Out:
#        dogs  cats
# Joe       1     3
# Mary      0     2
# Roger     4     0
# David     3     1
# Mikey     2     1

# %%
# Index using loc
animals.loc['Roger']
# Out:
# dogs    4
# cats    0
# Name: Roger, dtype: int64

# %%
# Index using iloc
animals.iloc[2]
# Out:
# dogs    4
# cats    0
# Name: Roger, dtype: int64

# %%
# We can also slice!
animals.loc['Roger':'Mikey'] # Note - the stop point in .loc is inclusive
# Out:
#        dogs  cats
# Roger     4     0
# David     3     1
# Mikey     2     1

# %%
animals.iloc[2:4] # The stop point in .iloc is not inclusive
# Out:
#        dogs  cats
# Roger     4     0
# David     3     1

# %%
animals.iloc[2:4]['dogs']
# Out:
# Roger    4
# David    3
# Name: dogs, dtype: int64

# %%
( animals.iloc[2:4] )['dogs']
# Out:
# Roger    4
# David    3
# Name: dogs, dtype: int64

# %%
( ( animals ).iloc[2:4] )['dogs']
# Out:
# Roger    4
# David    3
# Name: dogs, dtype: int64

# %%
animals['dogs'].iloc[2:4]
# Out:
# Roger    4
# David    3
# Name: dogs, dtype: int64

# %%
pd.DataFrame(animals['dogs'].iloc[2:4])
# Out:
#        dogs
# Roger     4
# David     3

# %%
animals[['dogs']].iloc[2:4]
# Out:
#        dogs
# Roger     4
# David     3

# %% [markdown]
# ### Your Turn
# 1. Index the row for `Back to the Future` from the `movies` data frame using .loc and iloc.
# 2. Use a slice to index the rows for `Back to the Future` and `Forrest Gump`.

# %%
# Solution
movies.loc['Back to the Future']
#Dictionary way of indexing
# Out:
# Lead Actor       Michael J. Fox
# Times Watched              15.0
# Name: Back to the Future, dtype: object

# %%
movies.loc['Back to the Future':'Forrest Gump']
# Out:
#                         Lead Actor  Times Watched
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
# Solution
movies.iloc[2]
#List way of indexing
# Out:
# Lead Actor       Michael J. Fox
# Times Watched              15.0
# Name: Back to the Future, dtype: object

# %%
movies.iloc[2:4]
# Out:
#                         Lead Actor  Times Watched
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %% [markdown]
# ## Conditional Selections

# %%
animals
# Out:
#        dogs  cats
# Joe       1     3
# Mary      0     2
# Roger     4     0
# David     3     1
# Mikey     2     1

# %%
# We can use conditional statements to return booleans
animals['dogs'] == 4
# Out:
# Joe      False
# Mary     False
# Roger     True
# David    False
# Mikey    False
# Name: dogs, dtype: bool

# %%
# We can then use those booleans to index our data frame
filter = ( animals['dogs'] == 4 )
animals[ filter ]
# Out:
#        dogs  cats
# Roger     4     0

# %%
# Another example
animals[ animals['cats'] > 1 ]
# Out:
#       dogs  cats
# Joe      1     3
# Mary     0     2

# %%
# A third example!
# Two things to note - we have to put parenthesis around each conditional statement
# and we have to use the '&' symbol instead of the word 'and'
animals[(animals['cats'] > 1) & (animals['dogs'] < 1)]
# Out:
#       dogs  cats
# Mary     0     2

# %%
filter1 = (animals['cats'] > 1)
filter1
filter2 = (animals['dogs'] < 1)
filter2
filter3 = filter1 & filter2
filter3

animals[filter3]
# Out:
#       dogs  cats
# Mary     0     2

# %% [markdown]
# ### Your Turn
# Use a conditional statement to return the following from your `movies_impute` data frame:
# 1. Movies with Bruce Willis as the lead actor
# 2. Movies that have been watched more than 4 times

# %%
movies_impute
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
# Solution
filter = (movies_impute['Lead Actor'] == 'Bruce Willis')
filter
movies_impute[filter]
# Out:
#             Lead Actor  Times Watched
# Die Hard  Bruce Willis            5.0

# %%
# Solution
filter = (movies_impute['Times Watched'] > 4)
filter

movies_impute[filter]
# Out:
#                         Lead Actor  Times Watched
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0

# %% [markdown]
# ## Adding a Column

# %%
animals
# Out:
#        dogs  cats
# Joe       1     3
# Mary      0     2
# Roger     4     0
# David     3     1
# Mikey     2     1

# %%
# We can easily add a column to our data frame
animals['chickens'] = [1,0,0,4,5]
animals
# Out:
#        dogs  cats  chickens
# Joe       1     3         1
# Mary      0     2         0
# Roger     4     0         0
# David     3     1         4
# Mikey     2     1         5

# %%
# Add a single value to all rows, i.e. broadcasting
animals['ducks'] = 20
animals
# Out:
#        dogs  cats  chickens  ducks
# Joe       1     3         1     20
# Mary      0     2         0     20
# Roger     4     0         0     20
# David     3     1         4     20
# Mikey     2     1         5     20

# %%
# Calculations
animals["Total"] = animals["dogs"] + animals["cats"] + animals["chickens"] + animals["ducks"]
animals
# Out:
#        dogs  cats  chickens  ducks  Total
# Joe       1     3         1     20     25
# Mary      0     2         0     20     22
# Roger     4     0         0     20     24
# David     3     1         4     20     28
# Mikey     2     1         5     20     28

# %%
animals["all"] = animals.sum(axis = 1)
animals
# Out:
#        dogs  cats  chickens  ducks  Total  all
# Joe       1     3         1     20     25   50
# Mary      0     2         0     20     22   44
# Roger     4     0         0     20     24   48
# David     3     1         4     20     28   56
# Mikey     2     1         5     20     28   56

# %%
animals.sum(axis = "columns")
# Out:
# Joe      100
# Mary      88
# Roger     96
# David    112
# Mikey    112
# dtype: int64

# %% [markdown]
# ## Adding a Row

# %%
# Similarly, we can add a row to our data frame
animals.loc['Nevin'] = [1,0,0,4,5,10]
animals
# Out:
#        dogs  cats  chickens  ducks  Total  all
# Joe       1     3         1     20     25   50
# Mary      0     2         0     20     22   44
# Roger     4     0         0     20     24   48
# David     3     1         4     20     28   56
# Mikey     2     1         5     20     28   56
# Nevin     1     0         0      4      5   10

# %% [markdown]
# ### Your Turn
# 1. Add a column named `Rating` to your `movies_impute` data frame that gives your rating of the movie on a scale from 1-10 (where 10 is the best).
# 2. Add a row to your `movies_impute` data frame with the information for another movie.

# %%
movies_impute_backup = movies_impute.copy()
movies_impute_backup
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
# Solution
movies['Rating'] = [9,2,7,7]
movies
# Out:
#                         Lead Actor  Times Watched  Rating
# Titanic               Leo DiCaprio            3.0       9
# Die Hard              Bruce Willis            5.0       2
# Back to the Future  Michael J. Fox           15.0       7
# Forrest Gump             Tom Hanks            NaN       7

# %%
# Solution
movies.loc['Mission Impossible'] = ['Tom Cruise', 10.0, 8]
movies
# Out:
#                         Lead Actor  Times Watched  Rating
# Titanic               Leo DiCaprio            3.0       9
# Die Hard              Bruce Willis            5.0       2
# Back to the Future  Michael J. Fox           15.0       7
# Forrest Gump             Tom Hanks            NaN       7
# Mission Impossible      Tom Cruise           10.0       8

# %% [markdown]
# ## A Quick Intro to Plotting Using Pandas

# %%
home_data.plot(
  kind = 'scatter',
     x = 'LotArea',
     y = 'LotFrontage',
) ;

# %%
home_data['LotFrontage'].plot(kind = 'hist', title = 'Lot Frontage') ;

# %%
# Note positive skew, i.e mean > median ( 50% )
home_data[['LotFrontage']].describe().transpose()
# Out:
#               count       mean        std   min   25%   50%   75%    max
# LotFrontage  1201.0  70.049958  24.284752  21.0  59.0  69.0  80.0  313.0

# %%
home_data['LotFrontage'].plot(kind = 'box', title = 'Lot Frontage') ;

# %% [markdown]
# ### Your Turn
# Create a scatter plot of your `Rating` column versus your `Times Watched` column from you `movies_impute` data frame.

# %%
# Solution
movies_impute_backup = movies_impute.copy()
movies_impute_backup
# Out:
#                         Lead Actor  Times Watched
# Titanic               Leo DiCaprio            3.0
# Die Hard              Bruce Willis            5.0
# Back to the Future  Michael J. Fox           15.0
# Forrest Gump             Tom Hanks            NaN

# %%
movies.plot(
  kind = 'scatter',
     x = 'Rating',
     y = 'Times Watched',
) ;
