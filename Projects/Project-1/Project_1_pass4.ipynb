# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Transaction Predictions

# %% [markdown]
# ##Data Questions? How Many?
#
# Columns
# - identifier columns:
# - target columns:
# 	-  rows with nulls in each:
# - feature columns:
# 	- rows with nulls in each:
# - numerical columns:
# 	- discrete columns:
# 		- rows with nulls in each:
# 	-continuous columns:
# 		- rows with nulls in each:
# - categorical columns:
# 	-nominal columns:
# 		- rows with nulls in each:
# 		- categories in each:
# 	-ordinal columns:
# 		- rows with nulls in each:
# 		- categories in each:
# - Nested columns:
#
# ROWS
# - rows with nulls:
# - duplicate rows:
# - missing rows:

# %% [markdown]
# ###Imports

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###File Path

# %%
url = 'https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.train.big.csv'
url
# Out:
# 'https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.train.big.csv'

# %%
df = pd.read_csv(url)
df
# Out:
#          Unnamed: 0        ID_code  target    var_0    var_1    var_2  var_3  \
# 0                 0        train_0     NaN      NaN      NaN      NaN    NaN
# 1                 1        train_1     NaN      NaN      NaN      NaN    NaN
# 2                 2        train_2     NaN      NaN      NaN      NaN    NaN
# 3                 3        train_3     0.0   4.6739  22.3915  15.6015    NaN
# 4                 4        train_4     NaN      NaN      NaN      NaN    NaN
# ...             ...            ...     ...      ...      ...      ...    ...
# 1049995     1049995  train_1049995     1.0  11.3251  16.4148  20.5955    NaN
# 1049996     1049996  train_1049996     NaN      NaN      NaN      NaN    NaN
# 1049997     1049997  train_1049997     0.0   8.9941  13.4127   3.9567    NaN
# 1049998     1049998  train_1049998     NaN      NaN      NaN      NaN    NaN
# 1049999     1049999  train_1049999     0.0   2.1828  12.3805  17.5654    NaN
#
# ...

# %% [markdown]
# ### Columns

# %% [markdown]
# ####Identifier columns

# %%
#ID_code is the unique identifier. Each value is different and does not contribute to explain/predict the target.
df.columns
# Out:
# Index(['Unnamed: 0', 'ID_code', 'target', 'var_0', 'var_1', 'var_2', 'var_3',
#        'var_4', 'var_5', 'var_6',
#        ...
#        'var_91', 'var_92', 'var_93', 'var_94', 'var_95', 'var_96', 'var_97',
#        'var_98', 'var_99', 'var_100'],
#       dtype='object', length=104)

# %%
#Must match len(df)
df['ID_code'].nunique()
# Out:
# 1050000

# %%
#Must match df['ID_code'].nunique
len(df)
# Out:
# 1050000

# %% [markdown]
# ####Target columns

# %%
#The 'target' column that I am trying to predict, explain or understand.
#Rows with nulls in each
df['target'].head()
# Out:
# 0    NaN
# 1    NaN
# 2    NaN
# 3    0.0
# 4    NaN
# Name: target, dtype: float64

# %%
df['target'].value_counts()
#Separates into two classes:
# 0 = Customer WILL make a transaction
# 1 = Customer will NOT make a transaction
# Out:
# target
# 0.0    161960
# 1.0     18040
# Name: count, dtype: int64

# %%
#Rows with nulls in target
df['target'].isnull().sum()
# Out:
# np.int64(870000)

# %%
#Feature columns
feature_columns = [col for col in df.columns if col.startswith ('var_')]

df[feature_columns].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Columns: 101 entries, var_0 to var_100
# dtypes: float64(101)
# memory usage: 809.1 MB

# %%
#Rows with nulls in each
#Minus 3 columns for 2 identifier and 1 target column
df.isnull().sum()
# Out:
# var_0       870000
# var_1       870000
# var_2       870000
# var_3      1050000
# var_4       870000
#             ...
# var_96     1050000
# var_97     1050000
# var_98     1050000
# var_99     1050000
# var_100     870000
# Length: 101, dtype: int64

# %% [markdown]
# ####Numerical columns

# %%
len(df.select_dtypes(include = 'number').columns)
# Out:
# 103

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Columns: 104 entries, Unnamed: 0 to var_100
# dtypes: float64(102), int64(1), object(1)
# memory usage: 833.1+ MB

# %%
#Discrete columns (int): is the Unnamed column
df['Unnamed: 0'].isnull().sum()
# Out:
# np.int64(0)

# %%
#Continuous columns (flt): are the 'Var_' columns
df[feature_columns].isnull().sum()
# Out:
# var_0       870000
# var_1       870000
# var_2       870000
# var_3      1050000
# var_4       870000
#             ...
# var_96     1050000
# var_97     1050000
# var_98     1050000
# var_99     1050000
# var_100     870000
# Length: 101, dtype: int64

# %% [markdown]
# ####Categorical columns
# Nominal columns: none
#
# Ordinal columns: none
#
# The object column is not considered categorical.

# %%
df.select_dtypes(include='object').head()
# Out:
#    ID_code
# 0  train_0
# 1  train_1
# 2  train_2
# 3  train_3
# 4  train_4

# %%
df['ID_code'].head()
# Out:
# 0    train_0
# 1    train_1
# 2    train_2
# 3    train_3
# 4    train_4
# Name: ID_code, dtype: object

# %% [markdown]
# ####Nested columns

# %%
df.head()
# Out:
#    Unnamed: 0  ID_code  target   var_0    var_1    var_2  var_3   var_4  \
# 0           0  train_0     NaN     NaN      NaN      NaN    NaN     NaN
# 1           1  train_1     NaN     NaN      NaN      NaN    NaN     NaN
# 2           2  train_2     NaN     NaN      NaN      NaN    NaN     NaN
# 3           3  train_3     0.0  4.6739  22.3915  15.6015    NaN  0.0464
# 4           4  train_4     NaN     NaN      NaN      NaN    NaN     NaN
#
#    var_5  var_6  ...  var_91   var_92  var_93   var_94  var_95  var_96  \
# 0    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 1    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 2    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 3    NaN    NaN  ...     NaN  11.1077     NaN -12.6465     NaN     NaN
# 4    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
#
#    var_97  var_98  var_99  var_100
# 0     NaN     NaN     NaN      NaN
# ...

# %% [markdown]
# ###Rows

# %%
#Rows with nulls
df.isnull().any(axis = 1).sum()
# Out:
# np.int64(1050000)

# %%
#Duplicate rows
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
#Missing rows
df.isnull().sum()
# Out:
# Unnamed: 0          0
# ID_code             0
# target         870000
# var_0          870000
# var_1          870000
#                ...
# var_96        1050000
# var_97        1050000
# var_98        1050000
# var_99        1050000
# var_100        870000
# Length: 104, dtype: int64

# %% [markdown]
# ## Problem Definition
#
# 1. Write a concise problem definition for the project. Put it in a text field at the top of your Jupyter notebook.
#
# In this project we want to predic whether or not a future customer will make a transaction based on their transaction data.
# - unsupervised or supervised: supervised - we have a target
# - what is the target? the target column is named 'target'
# - is target categorical or numerical?

# %% [markdown]
# The goal of this project is to predict whether a customer will make a future transaction based on historical transaction data. This is a supervised binary classification problem since the customer either made a transaction or no transaction.This project will use Gaussian Naive Bayes classification as the machine learning model.

# %% [markdown]
# ## Data Collection/Sources

# %% [markdown]
# ###Imports

# %% [markdown]
# 2. Load Pandas, Numpy, and Matplotlib.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###File Paths

# %% [markdown]
# 3. Load data Train.csv from AWS S3.

# %%
#Creates variable called base_path that contains the part of the URL that never changes.
#This is because the ex started with URL and combined the csv's
#So they assined the csv
#base_path = 'https://ddc-datascience.s3.amazonaws.com/Projects/Example/Data/'
#train_path = base_path + 'Titanic.train.csv'
#test_path = base_path + 'Titanic.test.csv'

#We already have the csv so no need to combine
url = 'https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.train.big.csv'
url
# Out:
# 'https://ddc-datascience.s3.amazonaws.com/Projects/Project.1-Transactions/Data/Transaction.train.big.csv'

# %%
#This will load the data into a DataFrame
#View and make sure everything looks good.
df = pd.read_csv(url)
df
# Out:
#          Unnamed: 0        ID_code  target    var_0    var_1    var_2  var_3  \
# 0                 0        train_0     NaN      NaN      NaN      NaN    NaN
# 1                 1        train_1     NaN      NaN      NaN      NaN    NaN
# 2                 2        train_2     NaN      NaN      NaN      NaN    NaN
# 3                 3        train_3     0.0   4.6739  22.3915  15.6015    NaN
# 4                 4        train_4     NaN      NaN      NaN      NaN    NaN
# ...             ...            ...     ...      ...      ...      ...    ...
# 1049995     1049995  train_1049995     1.0  11.3251  16.4148  20.5955    NaN
# 1049996     1049996  train_1049996     NaN      NaN      NaN      NaN    NaN
# 1049997     1049997  train_1049997     0.0   8.9941  13.4127   3.9567    NaN
# 1049998     1049998  train_1049998     NaN      NaN      NaN      NaN    NaN
# 1049999     1049999  train_1049999     0.0   2.1828  12.3805  17.5654    NaN
#
# ...

# %% [markdown]
# ###info()

# %% [markdown]
# A quick summary of the data types in the data frame. Look for the data type of the target and how many of each type you have ( see the summary at the bottom. ) Look for obvious large number of nulls ( isna() is a better tool. )

# %%
df.info()
#Looks different from Titanic.pass05 because columns are unnamed?
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1050000 entries, 0 to 1049999
# Columns: 104 entries, Unnamed: 0 to var_100
# dtypes: float64(102), int64(1), object(1)
# memory usage: 833.1+ MB

# %%
df.isnull().sum()*1000
# Out:
# Unnamed: 0             0
# ID_code                0
# target         870000000
# var_0          870000000
# var_1          870000000
#                  ...
# var_96        1050000000
# var_97        1050000000
# var_98        1050000000
# var_99        1050000000
# var_100        870000000
# Length: 104, dtype: int64

# %%
df.isnull().sum().sort_values()
# Out:
# Unnamed: 0          0
# ID_code             0
# target         870000
# var_0          870000
# var_1          870000
#                ...
# var_93        1050000
# var_96        1050000
# var_97        1050000
# var_98        1050000
# var_99        1050000
# Length: 104, dtype: int64

# %% [markdown]
# ###describe()

# %% [markdown]
# Summary statistics give you a quick overview of the data. Some items to spot check:
#
# - the Target:
#   - look for nulls
#     - null will be culled
# look at min, max, median, and mean
# is it a categorical field masquerading as a number
# - the Features:
#   - numerical
#     - look at min, max, median, and mean
#       - a min=1 and max=count suggests an ID
#   - categorical
#     - look at unique and freq
#       - freq=1, unique=count suggests an ID
#       - freq=count suggests a meaningless feature

# %%
df.describe(include = "all").transpose()
# Out:
#                 count   unique            top freq       mean            std  \
# Unnamed: 0  1050000.0      NaN            NaN  NaN   524999.5  303109.035663
# ID_code       1050000  1050000  train_1049983    1        NaN            NaN
# target       180000.0      NaN            NaN  NaN   0.100222       0.300297
# var_0        180000.0      NaN            NaN  NaN   7.440715       3.021636
# var_1        180000.0      NaN            NaN  NaN  15.870166       3.010492
# ...               ...      ...            ...  ...        ...            ...
# var_96            0.0      NaN            NaN  NaN        NaN            NaN
# var_97            0.0      NaN            NaN  NaN        NaN            NaN
# var_98            0.0      NaN            NaN  NaN        NaN            NaN
# var_99            0.0      NaN            NaN  NaN        NaN            NaN
# var_100      180000.0      NaN            NaN  NaN  14.224538       0.171058
#
# ...

# %% [markdown]
# ###head()

# %%
#First rows. Make sure column names look right and the first few rows are data and not carry over from column names.
#What does the second half mean? What are we looking for?
df.head()
# Out:
#    Unnamed: 0  ID_code  target   var_0    var_1    var_2  var_3   var_4  \
# 0           0  train_0     NaN     NaN      NaN      NaN    NaN     NaN
# 1           1  train_1     NaN     NaN      NaN      NaN    NaN     NaN
# 2           2  train_2     NaN     NaN      NaN      NaN    NaN     NaN
# 3           3  train_3     0.0  4.6739  22.3915  15.6015    NaN  0.0464
# 4           4  train_4     NaN     NaN      NaN      NaN    NaN     NaN
#
#    var_5  var_6  ...  var_91   var_92  var_93   var_94  var_95  var_96  \
# 0    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 1    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 2    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
# 3    NaN    NaN  ...     NaN  11.1077     NaN -12.6465     NaN     NaN
# 4    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN     NaN
#
#    var_97  var_98  var_99  var_100
# 0     NaN     NaN     NaN      NaN
# ...

# %% [markdown]
# ###tail()

# %%
#Look at the last few rows to make sure totals and subtotals are not included.
#What does this mean?
df.tail()
# Out:
#          Unnamed: 0        ID_code  target    var_0    var_1    var_2  var_3  \
# 1049995     1049995  train_1049995     1.0  11.3251  16.4148  20.5955    NaN
# 1049996     1049996  train_1049996     NaN      NaN      NaN      NaN    NaN
# 1049997     1049997  train_1049997     0.0   8.9941  13.4127   3.9567    NaN
# 1049998     1049998  train_1049998     NaN      NaN      NaN      NaN    NaN
# 1049999     1049999  train_1049999     0.0   2.1828  12.3805  17.5654    NaN
#
#           var_4  var_5  var_6  ...  var_91   var_92  var_93   var_94  var_95  \
# 1049995 -6.3011    NaN    NaN  ...     NaN   1.3921     NaN -16.4925     NaN
# 1049996     NaN    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN
# 1049997  3.5744    NaN    NaN  ...     NaN   2.0836     NaN -18.6168     NaN
# 1049998     NaN    NaN    NaN  ...     NaN      NaN     NaN      NaN     NaN
# 1049999  8.1795    NaN    NaN  ...     NaN -12.1108     NaN  10.7608     NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'ID_code', 'target', 'var_0', 'var_1', 'var_2', 'var_3',
#        'var_4', 'var_5', 'var_6',
#        ...
#        'var_91', 'var_92', 'var_93', 'var_94', 'var_95', 'var_96', 'var_97',
#        'var_98', 'var_99', 'var_100'],
#       dtype='object', length=104)

# %% [markdown]
# ###dtypes()

# %%
df.dtypes()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_429/2157385015.py in <cell line: 0>()
# ----> 1 df.dtypes()
#
# TypeError: 'Series' object is not callable

# %% [markdown]
# ###target value_couts()

# %% [markdown]
# The target should be the first field that you look at. Its data type will tell you what kind of machine learning problem this is ( classification or regression. ) Any nulls should be culled. You can check for any skew in the data set.

# %%
#Enter targts
df['target'].value_counts(dropna= False)
# Out:
# target
# NaN    870000
# 0.0    161960
# 1.0     18040
# Name: count, dtype: int64

# %% [markdown]
# ## Data Cleaning
# 4. Examine the data using tools we have used in class.
#
# 5. If there are data cleaning issues, develop recommendations for how to deal with them.

# %%
project_data = pd.read_csv(url)
project_data
# Out:
#          Unnamed: 0        ID_code  target    var_0    var_1    var_2  var_3  \
# 0                 0        train_0     NaN      NaN      NaN      NaN    NaN
# 1                 1        train_1     NaN      NaN      NaN      NaN    NaN
# 2                 2        train_2     NaN      NaN      NaN      NaN    NaN
# 3                 3        train_3     0.0   4.6739  22.3915  15.6015    NaN
# 4                 4        train_4     NaN      NaN      NaN      NaN    NaN
# ...             ...            ...     ...      ...      ...      ...    ...
# 1049995     1049995  train_1049995     1.0  11.3251  16.4148  20.5955    NaN
# 1049996     1049996  train_1049996     NaN      NaN      NaN      NaN    NaN
# 1049997     1049997  train_1049997     0.0   8.9941  13.4127   3.9567    NaN
# 1049998     1049998  train_1049998     NaN      NaN      NaN      NaN    NaN
# 1049999     1049999  train_1049999     0.0   2.1828  12.3805  17.5654    NaN
#
# ...

# %%
project_data.shape
# Out:
# (1050000, 104)

# %%
project_data.isnull().sum()*1000
# Out:
# Unnamed: 0             0
# ID_code                0
# target         870000000
# var_0          870000000
# var_1          870000000
#                  ...
# var_96        1050000000
# var_97        1050000000
# var_98        1050000000
# var_99        1050000000
# var_100        870000000
# Length: 104, dtype: int64

# %%
project_data.isnull().sum().sort_values()
# Out:
# Unnamed: 0          0
# ID_code             0
# target         870000
# var_0          870000
# var_1          870000
#                ...
# var_93        1050000
# var_96        1050000
# var_97        1050000
# var_98        1050000
# var_99        1050000
# Length: 104, dtype: int64

# %%
project_data.describe()
# Out:
#          Unnamed: 0         target          var_0          var_1  \
# count  1.050000e+06  180000.000000  180000.000000  180000.000000
# mean   5.249995e+05       0.100222       7.440715      15.870166
# std    3.031090e+05       0.300297       3.021636       3.010492
# min    0.000000e+00       0.000000      -2.691700       6.299300
# 25%    2.624998e+05       0.000000       5.160325      13.830400
# 50%    5.249995e+05       0.000000       7.350950      15.934600
# 75%    7.874992e+05       0.000000       9.511125      18.061425
# max    1.049999e+06       1.000000      16.716500      26.079100
#
#                var_2  var_3          var_4  var_5  var_6          var_7  ...  \
# count  180000.000000    0.0  180000.000000    0.0    0.0  180000.000000  ...
# mean       12.735619    NaN      -0.668334    NaN    NaN       1.190419  ...
# std         4.185923    NaN       5.968300    NaN    NaN       5.169343  ...
# ...

# %% [markdown]
# ###Drop Columns

# %% [markdown]
# ## Exploratory Data Analysis
# 6. Produce some visual analysis of the data – like plots showing the distributions of all variables. Recall that Gaussian Naive Bayes assumes the predictors are normally distributed. Note: you might have to do multiple plots in groups.
#
# 1. NOTE: the ‘target’ column indicates a successful transaction (‘1’) or a no-transaction (‘0’). Verify these are the only values in that column.
#
# 1. Check the correlation values between all **predictor columns** to ensure there are no substantial correlations between predictors. This is important to support the decision to classify the ‘target’ using Naïve Bayes.
#
# 1. Create two data frames: one with all successful transactions, one with all unsuccessful transactions. **Make sure they are copies and not slices**.

# %% [markdown]
# ## Processing
# 10. Create two data frames: one with all the predictor columns (everything except for Unnamed: 0, ID_code and target) and one with just the target. Make sure they are copies and not slices.
#
# 1. Define a Gaussian Naïve Bayes model using Sklearn.
#
# 1. Divide the two data frames you created in step #10 into training and testing subsets.
#
# 1. Train the model using the training subset of the dataset.
#
# 1. Test the model using the testing subset of the dataset. Calculate and report the accuracy.
#
# 1. Perform a cross-validation loop to calculate the accuracy of your model. Report that accuracy. How does it compare to the accuracy you calculated in #14?
#
# 1. Plot a histogram of the accuracy scores you generated in your cross-validation loop. What do you notice about the distribution of accuracy scores?
#
# 1.  Present the confusion matrix and the results of your Classification Report (sklearn.metrics.classification_report). What do you notice?
#
# 1. The training data is very skewed towards non-successful transactions (about 90% of the training data has ‘target’==0). Remove enough non-successful transaction rows so that your remaining training data is 50%/50% split between successful and non-successful transactions. Hint: you can use the data frames you created in step #9.
#
# 1. Repeat the cross-validation process on this data set. Report what your cross-validation accuracy is in this 50/50 case.

# %% [markdown]
# ## Data Visualization/Communication of Results
# 20. Compare the results of your cross-validation with the whole training data and the reduced 50/50 training data
#
# 1. Present the confusion matrix and the results of your Classification Report (sklearn.metrics.classification_report)

# %% [markdown]
# ##Communication of Results
# 22. Communicate the results of your analysis.

# %% [markdown]
# ## Submit Final Project
#
# 23. Upload your finished Jupyter notebook to your Project 1 student folder.
