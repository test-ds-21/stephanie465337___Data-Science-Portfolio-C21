# %% [markdown]
# <a href="https://colab.research.google.com/github/stephanie465337/Data-Science-Portfolio-C21/blob/main/1b_Intro_Python_Exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Introduction to Python

# %% [markdown]
# ## Getting started
# - Save this notebook to your Google Drive
# - Move it to your Exercises folder for the current module
# - Some code cells have a little bit to get you started

# %% [markdown]
# ## Numbers

# %% [markdown]
# Pick your own numbers to perform the following operations:

# %% [markdown]
# - addition

# %%
1+1
# Out:
# 2

# %% [markdown]
# - subtraction

# %%
1-1
# Out:
# 0

# %% [markdown]
# - multiplication

# %%
1*1
# Out:
# 1

# %% [markdown]
# - division

# %%
1/1
# Out:
# 1.0

# %%
1//1
# Out:
# 1

# %% [markdown]
# - exponentiation

# %%
1**1
# Out:
# 1

# %% [markdown]
# - modulo

# %%
5%2
# Out:
# 1

# %% [markdown]
# ## Numbers in variables

# %% [markdown]
# Pick two numbers (one integer and one float) and assign them to the variables `first_number` and `second_number`.

# %%
first_number = int(1)
first_number
# Out:
# 1

# %%
second_number = float(1.0)
second_number
# Out:
# 1.0

# %% [markdown]
# Make a variable called `product` that is the product of your two variables from above.

# %%
product = first_number * second_number
print(product)
# Out:
# 1.0

# %% [markdown]
# ## Strings in variables

# %% [markdown]
# Come up with your own fun sentence to use a string and assign it to a variable name.  (Make sure to pick a variable name that follows the naming conventions.)

# %%
steph = 'Stephanie'
wings = 'chicken wings'

love = f'{steph} loves {wings}!'
print(love)
# Out:
# Stephanie loves chicken wings!

# %% [markdown]
# ## Printing

# %% [markdown]
# Make print statements for each of your variables

# %% [markdown]
# - first_number

# %%
f'The first number is {first_number}.'
# Out:
# 'The first number is 1.'

# %% [markdown]
# - second_number

# %%
f'The second number is {second_number}.'
# Out:
# 'The second number is 1.0.'

# %% [markdown]
# - product

# %%
f'The product is {product}.'
# Out:
# 'The product is 1.0.'

# %% [markdown]
# - your string

# %%
f'{love}'
# Out:
# 'Stephanie loves chicken wings!'

# %% [markdown]
# ## Displaying types

# %% [markdown]
# Print the type of each of your variables

# %% [markdown]
# - first_number

# %%
type(first_number)
# Out:
# int

# %% [markdown]
# - second_number

# %%
type(second_number)
# Out:
# float

# %% [markdown]
# - product

# %%
type(product)
# Out:
# float

# %% [markdown]
# - your string

# %%
print(type(love))
# Out:
# <class 'str'>

# %% [markdown]
# ## Exploring

# %%
# @title Python string methods ( from W3Schools )
import pandas as pd

pd.read_html( "https://www.w3schools.com/python/python_ref_string.asp" )[0].style.hide(axis='index')

# %% [markdown]
# Find a string method that we did not go over in class to use on your string. You can also find a list of string methods by checking the [documentation]( https://docs.python.org/3.10/library/stdtypes.html#string-methods ).

# %%
mySiblings = ("James", "Samantha", "Jared")

x = ", ".join(mySiblings)

print(x)
# Out:
# James, Samantha, Jared
